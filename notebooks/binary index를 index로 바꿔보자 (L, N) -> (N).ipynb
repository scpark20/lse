# %%
import torch

# %%
L = 9
N = 1000
zi = torch.randint(0, 2, size=(L, N))
dec = 2 ** torch.arange(0, 9)
(zi * dec[:, None]).sum(0)
# Out:
# tensor([ 68, 391, 292, 124, 145, 121, 258, 346, 101, 281, 426, 413, 327, 400,
#         305,  36, 432, 174, 360, 108,  52, 261, 425, 254, 318, 169, 265, 271,
#         184, 202, 193, 249, 333, 424, 485, 261, 459, 509, 221, 389, 508, 352,
#         256, 492, 373, 194,  82,  67,  18, 427, 144, 507, 160, 226, 342,  51,
#         162,  60, 315, 315, 235, 271, 141,  93, 499, 145, 462, 433,  78, 343,
#         330,  66, 219,  17, 155, 106, 368, 405, 511, 299, 292,  33, 453,  21,
#         351, 278, 379, 231, 254, 243, 299, 401,  37, 292, 299,  50, 506, 369,
#         184, 227, 121, 490,  74, 130,  29, 401, 421,  76, 105, 506, 162, 180,
#         177, 426, 363, 116, 166, 351, 181, 503,  13, 352, 159, 263,  88, 203,
#         131,  91, 337, 449, 351, 361, 491, 118, 262, 172, 381, 146, 177, 262,
#         413, 307, 177, 344, 253,  68, 221, 412, 483, 140, 232, 486, 162, 260,
#           3,  41, 495, 199, 310, 465,  11, 388, 112, 507, 400, 210, 118,  87,
# ...
