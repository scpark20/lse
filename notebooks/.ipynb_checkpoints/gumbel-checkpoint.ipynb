# %%
import numpy as np
import torch

# %%
N = 10
eps = 1e-8
p = 0.5

# %%
u = torch.rand(N)
g = -torch.log(-torch.log(u+eps)+eps)
samples = torch.sigmoid((np.log(p) - np.log(1-p) + g) / 1e-4)

import matplotlib.pyplot as plt
plt.figure(figsize=[18, 4])
plt.plot(samples.numpy())
plt.show()
