# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Mon Feb 12 21:53:53 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.154.05             Driver Version: 535.154.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off | 00000000:19:00.0 Off |                  Off |
# | 42%   60C    P8              42W / 450W |     11MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce RTX 4090        Off | 00000000:68:00.0 Off |                  Off |
# |  0%   53C    P8              28W / 450W |     28MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1047      G   /usr/lib/xorg/Xorg                            4MiB |
# |    1   N/A  N/A      1047      G   /usr/lib/xorg/Xorg                            9MiB |
# |    1   N/A  N/A      1346      G   /usr/bin/gnome-shell                          8MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### Hyper-Parameters

# %%
from easydict import EasyDict
hp = EasyDict()

# Data
hp.dataset = 'ffhq_256'
hp.data_root = '/home/scpark/data'
hp.test_eval = True
hp.image_channels = 3
hp.n_batch = 32

# Model
hp.custom_width_str = ""
hp.bottleneck_multiple = 0.25
hp.no_bias_above = 64
hp.num_mixtures = 10
hp.width = 384
hp.zdim = 16
hp.dec_blocks = "1x1,4m1,4x2,8m4,8x2,16m8,16x2,32m16,32x2"
hp.enc_blocks = "32x2,32d2,16x2,16d2,8x2,8d2,4x2,4d4,1x2"

# Train
hp.lr = 0.0002
hp.wd = 0.01
hp.adam_beta1 = 0.9
hp.adam_beta2 = 0.9
hp.warmup_iters = 100
hp.ema_rate = 0.9999
hp.grad_clip = 200.0
hp.skip_threshold = 400.0

# %% [markdown]
# ### Model

# %%
from model.main.vdvae import Model
from model.encoder.vdvae_encoder import Encoder
from model.decoder.vdvae_decoder import Decoder
from model.loss.dmol import Loss

from tensorboardX import SummaryWriter
from util.util import *

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(hp), Decoder(hp), Loss(hp)).to(device)
ema_model = None
optimizer = torch.optim.AdamW(model.parameters(), weight_decay=hp.wd, lr=hp.lr, betas=(hp.adam_beta1, hp.adam_beta2))

for name, module in model.named_modules():
    if len(name.split('.')) <= 1 and len(name) > 0:
        print(name, get_size(module))

print('done')
# Out:
# encoder 11.748779296875
# decoder 36.6700439453125
# loss 0.1468658447265625
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/save/lse/train_vdvae/train02.12-7/'

# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, model, optimizer = load(save_dir, 60000, model, optimizer)
# Out:
# total 149788
# -rw-rw-r-- 1 scpark scpark     31041  2월 12 21:57 events.out.tfevents.1707742437.scpark-X299-WU8
# -rw-rw-r-- 1 scpark scpark 153331870  2월 12 21:54 save_0
# -rw-rw-r-- 1 scpark scpark     15358  2월 12 21:53 events.out.tfevents.1707741946.scpark-X299-WU8

# %%
# checkpoint_path = '/data/save/lse/train_vdvae/train02.04-2/save_60000'
# checkpoint = torch.load(checkpoint_path, map_location='cpu')['model_state_dict']
# model_state_dict = model.state_dict()

# for name, param in checkpoint.items():
#     if name in model_state_dict and model_state_dict[name].shape == param.shape:
#         print(name)
#         model_state_dict[name].copy_(param)

# model.load_state_dict(model_state_dict, strict=False)
# print('done')
# Out:
# encoder.encoder.in_conv.weight
# encoder.encoder.in_conv.bias
# encoder.encoder.enc_blocks.0.c1.weight
# encoder.encoder.enc_blocks.0.c1.bias
# encoder.encoder.enc_blocks.0.c2.weight
# encoder.encoder.enc_blocks.0.c2.bias
# encoder.encoder.enc_blocks.0.c3.weight
# encoder.encoder.enc_blocks.0.c3.bias
# encoder.encoder.enc_blocks.0.c4.weight
# encoder.encoder.enc_blocks.0.c4.bias
# encoder.encoder.enc_blocks.1.c1.weight
# encoder.encoder.enc_blocks.1.c1.bias
# encoder.encoder.enc_blocks.1.c2.weight
# encoder.encoder.enc_blocks.1.c2.bias
# encoder.encoder.enc_blocks.1.c3.weight
# decoder.decoder.dec_blocks.0.enc.c3.weight
# decoder.decoder.dec_blocks.0.enc.c3.bias
# decoder.decoder.dec_blocks.0.enc.c4.weight
# decoder.decoder.dec_blocks.0.enc.c4.bias
# decoder.decoder.dec_blocks.0.prior.c1.weight
# decoder.decoder.dec_blocks.0.prior.c1.bias
# decoder.decoder.dec_blocks.0.prior.c2.weight
# decoder.decoder.dec_blocks.0.prior.c2.bias
# decoder.decoder.dec_blocks.0.prior.c3.weight
# decoder.decoder.dec_blocks.0.prior.c3.bias
# decoder.decoder.dec_blocks.0.prior.c4.weight
# decoder.decoder.dec_blocks.0.prior.c4.bias
# decoder.decoder.dec_blocks.0.z_proj.weight
# decoder.decoder.dec_blocks.0.z_proj.bias
# decoder.decoder.dec_blocks.0.resnet.c1.weight
# decoder.decoder.dec_blocks.0.resnet.c1.bias
# decoder.decoder.dec_blocks.0.resnet.c2.weight
# decoder.decoder.dec_blocks.0.resnet.c2.bias
# decoder.decoder.dec_blocks.0.resnet.c3.weight
# decoder.decoder.dec_blocks.0.resnet.c3.bias
# decoder.decoder.dec_blocks.0.resnet.c4.weight
# decoder.decoder.dec_blocks.0.resnet.c4.bias
# decoder.decoder.dec_blocks.1.enc.c1.weight
# decoder.decoder.dec_blocks.1.enc.c1.bias
# decoder.decoder.dec_blocks.1.enc.c2.weight
# decoder.decoder.dec_blocks.1.enc.c2.bias
# decoder.decoder.dec_blocks.1.enc.c3.weight
# decoder.decoder.dec_blocks.1.enc.c3.bias
# decoder.decoder.dec_blocks.1.enc.c4.weight
# decoder.decoder.dec_blocks.1.enc.c4.bias
# decoder.decoder.dec_blocks.1.prior.c1.weight
# decoder.decoder.dec_blocks.1.prior.c1.bias
# decoder.decoder.dec_blocks.1.prior.c2.weight
# decoder.decoder.dec_blocks.1.prior.c2.bias
# decoder.decoder.dec_blocks.1.prior.c3.weight
# decoder.decoder.dec_blocks.1.prior.c3.bias
# decoder.decoder.dec_blocks.1.prior.c4.weight
# decoder.decoder.dec_blocks.1.prior.c4.bias
# decoder.decoder.dec_blocks.1.z_proj.weight
# decoder.decoder.dec_blocks.1.z_proj.bias
# decoder.decoder.dec_blocks.1.resnet.c1.weight
# decoder.decoder.dec_blocks.1.resnet.c1.bias
# decoder.decoder.dec_blocks.1.resnet.c2.weight
# decoder.decoder.dec_blocks.1.resnet.c2.bias
# decoder.decoder.dec_blocks.1.resnet.c3.weight
# decoder.decoder.dec_blocks.1.resnet.c3.bias
# decoder.decoder.dec_blocks.1.resnet.c4.weight
# decoder.decoder.dec_blocks.1.resnet.c4.bias
# decoder.decoder.dec_blocks.2.enc.c1.weight
# decoder.decoder.dec_blocks.2.enc.c1.bias
# decoder.decoder.dec_blocks.2.enc.c2.weight
# decoder.decoder.dec_blocks.2.enc.c2.bias
# decoder.decoder.dec_blocks.2.enc.c3.weight
# decoder.decoder.dec_blocks.2.enc.c3.bias
# decoder.decoder.dec_blocks.2.enc.c4.weight
# decoder.decoder.dec_blocks.2.enc.c4.bias
# decoder.decoder.dec_blocks.2.prior.c1.weight
# decoder.decoder.dec_blocks.2.prior.c1.bias
# decoder.decoder.dec_blocks.2.prior.c2.weight
# decoder.decoder.dec_blocks.2.prior.c2.bias
# decoder.decoder.dec_blocks.2.prior.c3.weight
# decoder.decoder.dec_blocks.2.prior.c3.bias
# decoder.decoder.dec_blocks.2.prior.c4.weight
# decoder.decoder.dec_blocks.2.prior.c4.bias
# decoder.decoder.dec_blocks.2.z_proj.weight
# decoder.decoder.dec_blocks.2.z_proj.bias
# decoder.decoder.dec_blocks.2.resnet.c1.weight
# decoder.decoder.dec_blocks.2.resnet.c1.bias
# decoder.decoder.dec_blocks.2.resnet.c2.weight
# decoder.decoder.dec_blocks.2.resnet.c2.bias
# decoder.decoder.dec_blocks.2.resnet.c3.weight
# decoder.decoder.dec_blocks.2.resnet.c3.bias
# decoder.decoder.dec_blocks.2.resnet.c4.weight
# decoder.decoder.dec_blocks.2.resnet.c4.bias
# decoder.decoder.dec_blocks.3.enc.c1.weight
# decoder.decoder.dec_blocks.3.enc.c1.bias
# decoder.decoder.dec_blocks.3.enc.c2.weight
# decoder.decoder.dec_blocks.3.enc.c2.bias
# decoder.decoder.dec_blocks.3.enc.c3.weight
# decoder.decoder.dec_blocks.3.enc.c3.bias
# decoder.decoder.dec_blocks.3.enc.c4.weight
# decoder.decoder.dec_blocks.3.enc.c4.bias
# decoder.decoder.dec_blocks.3.prior.c1.weight
# decoder.decoder.dec_blocks.3.prior.c1.bias
# decoder.decoder.dec_blocks.3.prior.c2.weight
# decoder.decoder.dec_blocks.3.prior.c2.bias
# decoder.decoder.dec_blocks.3.prior.c3.weight
# decoder.decoder.dec_blocks.3.prior.c3.bias
# decoder.decoder.dec_blocks.3.prior.c4.weight
# decoder.decoder.dec_blocks.3.prior.c4.bias
# decoder.decoder.dec_blocks.3.z_proj.weight
# decoder.decoder.dec_blocks.3.z_proj.bias
# decoder.decoder.dec_blocks.3.resnet.c1.weight
# decoder.decoder.dec_blocks.3.resnet.c1.bias
# decoder.decoder.dec_blocks.3.resnet.c2.weight
# decoder.decoder.dec_blocks.3.resnet.c2.bias
# decoder.decoder.dec_blocks.3.resnet.c3.weight
# decoder.decoder.dec_blocks.3.resnet.c3.bias
# decoder.decoder.dec_blocks.3.resnet.c4.weight
# decoder.decoder.dec_blocks.3.resnet.c4.bias
# decoder.decoder.dec_blocks.4.enc.c1.weight
# decoder.decoder.dec_blocks.4.enc.c1.bias
# decoder.decoder.dec_blocks.4.enc.c2.weight
# decoder.decoder.dec_blocks.4.enc.c2.bias
# decoder.decoder.dec_blocks.4.enc.c3.weight
# decoder.decoder.dec_blocks.4.enc.c3.bias
# decoder.decoder.dec_blocks.4.enc.c4.weight
# decoder.decoder.dec_blocks.4.enc.c4.bias
# decoder.decoder.dec_blocks.4.prior.c1.weight
# decoder.decoder.dec_blocks.4.prior.c1.bias
# decoder.decoder.dec_blocks.4.prior.c2.weight
# decoder.decoder.dec_blocks.4.prior.c2.bias
# decoder.decoder.dec_blocks.4.prior.c3.weight
# decoder.decoder.dec_blocks.4.prior.c3.bias
# decoder.decoder.dec_blocks.4.prior.c4.weight
# decoder.decoder.dec_blocks.4.prior.c4.bias
# decoder.decoder.dec_blocks.4.z_proj.weight
# decoder.decoder.dec_blocks.4.z_proj.bias
# decoder.decoder.dec_blocks.4.resnet.c1.weight
# decoder.decoder.dec_blocks.4.resnet.c1.bias
# decoder.decoder.dec_blocks.4.resnet.c2.weight
# decoder.decoder.dec_blocks.4.resnet.c2.bias
# decoder.decoder.dec_blocks.4.resnet.c3.weight
# decoder.decoder.dec_blocks.4.resnet.c3.bias
# decoder.decoder.dec_blocks.4.resnet.c4.weight
# decoder.decoder.dec_blocks.4.resnet.c4.bias
# decoder.decoder.dec_blocks.5.enc.c1.weight
# decoder.decoder.dec_blocks.5.enc.c1.bias
# decoder.decoder.dec_blocks.5.enc.c2.weight
# decoder.decoder.dec_blocks.5.enc.c2.bias
# decoder.decoder.dec_blocks.5.enc.c3.weight
# decoder.decoder.dec_blocks.5.enc.c3.bias
# decoder.decoder.dec_blocks.5.enc.c4.weight
# decoder.decoder.dec_blocks.5.enc.c4.bias
# decoder.decoder.dec_blocks.5.prior.c1.weight
# decoder.decoder.dec_blocks.5.prior.c1.bias
# decoder.decoder.dec_blocks.5.prior.c2.weight
# decoder.decoder.dec_blocks.5.prior.c2.bias
# decoder.decoder.dec_blocks.5.prior.c3.weight
# decoder.decoder.dec_blocks.5.prior.c3.bias
# decoder.decoder.dec_blocks.5.prior.c4.weight
# decoder.decoder.dec_blocks.5.prior.c4.bias
# decoder.decoder.dec_blocks.5.z_proj.weight
# decoder.decoder.dec_blocks.5.z_proj.bias
# decoder.decoder.dec_blocks.5.resnet.c1.weight
# decoder.decoder.dec_blocks.5.resnet.c1.bias
# decoder.decoder.dec_blocks.5.resnet.c2.weight
# decoder.decoder.dec_blocks.5.resnet.c2.bias
# decoder.decoder.dec_blocks.5.resnet.c3.weight
# decoder.decoder.dec_blocks.5.resnet.c3.bias
# decoder.decoder.dec_blocks.5.resnet.c4.weight
# decoder.decoder.dec_blocks.5.resnet.c4.bias
# decoder.decoder.dec_blocks.6.enc.c1.weight
# decoder.decoder.dec_blocks.6.enc.c1.bias
# decoder.decoder.dec_blocks.6.enc.c2.weight
# decoder.decoder.dec_blocks.6.enc.c2.bias
# decoder.decoder.dec_blocks.6.enc.c3.weight
# decoder.decoder.dec_blocks.6.enc.c3.bias
# decoder.decoder.dec_blocks.6.enc.c4.weight
# decoder.decoder.dec_blocks.6.enc.c4.bias
# decoder.decoder.dec_blocks.6.prior.c1.weight
# decoder.decoder.dec_blocks.6.prior.c1.bias
# decoder.decoder.dec_blocks.6.prior.c2.weight
# decoder.decoder.dec_blocks.6.prior.c2.bias
# decoder.decoder.dec_blocks.6.prior.c3.weight
# decoder.decoder.dec_blocks.6.prior.c3.bias
# decoder.decoder.dec_blocks.6.prior.c4.weight
# decoder.decoder.dec_blocks.6.prior.c4.bias
# decoder.decoder.dec_blocks.6.z_proj.weight
# decoder.decoder.dec_blocks.6.z_proj.bias
# decoder.decoder.dec_blocks.6.resnet.c1.weight
# decoder.decoder.dec_blocks.6.resnet.c1.bias
# decoder.decoder.dec_blocks.6.resnet.c2.weight
# decoder.decoder.dec_blocks.6.resnet.c2.bias
# decoder.decoder.dec_blocks.6.resnet.c3.weight
# decoder.decoder.dec_blocks.6.resnet.c3.bias
# decoder.decoder.dec_blocks.6.resnet.c4.weight
# decoder.decoder.dec_blocks.6.resnet.c4.bias
# decoder.decoder.dec_blocks.7.enc.c1.weight
# decoder.decoder.dec_blocks.7.enc.c1.bias
# decoder.decoder.dec_blocks.7.enc.c2.weight
# decoder.decoder.dec_blocks.7.enc.c2.bias
# decoder.decoder.dec_blocks.7.enc.c3.weight
# decoder.decoder.dec_blocks.7.enc.c3.bias
# decoder.decoder.dec_blocks.7.enc.c4.weight
# decoder.decoder.dec_blocks.7.enc.c4.bias
# decoder.decoder.dec_blocks.7.prior.c1.weight
# decoder.decoder.dec_blocks.7.prior.c1.bias
# decoder.decoder.dec_blocks.7.prior.c2.weight
# decoder.decoder.dec_blocks.7.prior.c2.bias
# decoder.decoder.dec_blocks.7.prior.c3.weight
# decoder.decoder.dec_blocks.7.prior.c3.bias
# decoder.decoder.dec_blocks.7.prior.c4.weight
# decoder.decoder.dec_blocks.7.prior.c4.bias
# decoder.decoder.dec_blocks.7.z_proj.weight
# decoder.decoder.dec_blocks.7.z_proj.bias
# decoder.decoder.dec_blocks.7.resnet.c1.weight
# decoder.decoder.dec_blocks.7.resnet.c1.bias
# decoder.decoder.dec_blocks.7.resnet.c2.weight
# decoder.decoder.dec_blocks.7.resnet.c2.bias
# decoder.decoder.dec_blocks.7.resnet.c3.weight
# decoder.decoder.dec_blocks.7.resnet.c3.bias
# decoder.decoder.dec_blocks.7.resnet.c4.weight
# decoder.decoder.dec_blocks.7.resnet.c4.bias
# decoder.decoder.dec_blocks.8.enc.c1.weight
# decoder.decoder.dec_blocks.8.enc.c1.bias
# decoder.decoder.dec_blocks.8.enc.c2.weight
# decoder.decoder.dec_blocks.8.enc.c2.bias
# decoder.decoder.dec_blocks.8.enc.c3.weight
# decoder.decoder.dec_blocks.8.enc.c3.bias
# decoder.decoder.dec_blocks.8.enc.c4.weight
# decoder.decoder.dec_blocks.8.enc.c4.bias
# decoder.decoder.dec_blocks.8.prior.c1.weight
# decoder.decoder.dec_blocks.8.prior.c1.bias
# decoder.decoder.dec_blocks.8.prior.c2.weight
# decoder.decoder.dec_blocks.8.prior.c2.bias
# decoder.decoder.dec_blocks.8.prior.c3.weight
# decoder.decoder.dec_blocks.8.prior.c3.bias
# decoder.decoder.dec_blocks.8.prior.c4.weight
# decoder.decoder.dec_blocks.8.prior.c4.bias
# decoder.decoder.dec_blocks.8.z_proj.weight
# decoder.decoder.dec_blocks.8.z_proj.bias
# decoder.decoder.dec_blocks.8.resnet.c1.weight
# decoder.decoder.dec_blocks.8.resnet.c1.bias
# decoder.decoder.dec_blocks.8.resnet.c2.weight
# decoder.decoder.dec_blocks.8.resnet.c2.bias
# decoder.decoder.dec_blocks.8.resnet.c3.weight
# decoder.decoder.dec_blocks.8.resnet.c3.bias
# decoder.decoder.dec_blocks.8.resnet.c4.weight
# decoder.decoder.dec_blocks.8.resnet.c4.bias
# decoder.decoder.dec_blocks.9.enc.c1.weight
# decoder.decoder.dec_blocks.9.enc.c1.bias
# decoder.decoder.dec_blocks.9.enc.c2.weight
# decoder.decoder.dec_blocks.9.enc.c2.bias
# decoder.decoder.dec_blocks.9.enc.c3.weight
# decoder.decoder.dec_blocks.9.enc.c3.bias
# decoder.decoder.dec_blocks.9.enc.c4.weight
# decoder.decoder.dec_blocks.9.enc.c4.bias
# decoder.decoder.dec_blocks.9.prior.c1.weight
# decoder.decoder.dec_blocks.9.prior.c1.bias
# decoder.decoder.dec_blocks.9.prior.c2.weight
# decoder.decoder.dec_blocks.9.prior.c2.bias
# decoder.decoder.dec_blocks.9.prior.c3.weight
# decoder.decoder.dec_blocks.9.prior.c3.bias
# decoder.decoder.dec_blocks.9.prior.c4.weight
# decoder.decoder.dec_blocks.9.prior.c4.bias
# decoder.decoder.dec_blocks.9.z_proj.weight
# decoder.decoder.dec_blocks.9.z_proj.bias
# decoder.decoder.dec_blocks.9.resnet.c1.weight
# decoder.decoder.dec_blocks.9.resnet.c1.bias
# decoder.decoder.dec_blocks.9.resnet.c2.weight
# decoder.decoder.dec_blocks.9.resnet.c2.bias
# decoder.decoder.dec_blocks.9.resnet.c3.weight
# decoder.decoder.dec_blocks.9.resnet.c3.bias
# decoder.decoder.dec_blocks.9.resnet.c4.weight
# decoder.decoder.dec_blocks.9.resnet.c4.bias
# decoder.decoder.dec_blocks.10.enc.c1.weight
# decoder.decoder.dec_blocks.10.enc.c1.bias
# decoder.decoder.dec_blocks.10.enc.c2.weight
# decoder.decoder.dec_blocks.10.enc.c2.bias
# decoder.decoder.dec_blocks.10.enc.c3.weight
# decoder.decoder.dec_blocks.10.enc.c3.bias
# decoder.decoder.dec_blocks.10.enc.c4.weight
# decoder.decoder.dec_blocks.10.enc.c4.bias
# decoder.decoder.dec_blocks.10.prior.c1.weight
# decoder.decoder.dec_blocks.10.prior.c1.bias
# decoder.decoder.dec_blocks.10.prior.c2.weight
# decoder.decoder.dec_blocks.10.prior.c2.bias
# decoder.decoder.dec_blocks.10.prior.c3.weight
# decoder.decoder.dec_blocks.10.prior.c3.bias
# decoder.decoder.dec_blocks.10.prior.c4.weight
# decoder.decoder.dec_blocks.10.prior.c4.bias
# decoder.decoder.dec_blocks.10.z_proj.weight
# decoder.decoder.dec_blocks.10.z_proj.bias
# decoder.decoder.dec_blocks.10.resnet.c1.weight
# decoder.decoder.dec_blocks.10.resnet.c1.bias
# decoder.decoder.dec_blocks.10.resnet.c2.weight
# decoder.decoder.dec_blocks.10.resnet.c2.bias
# decoder.decoder.dec_blocks.10.resnet.c3.weight
# decoder.decoder.dec_blocks.10.resnet.c3.bias
# decoder.decoder.dec_blocks.10.resnet.c4.weight
# decoder.decoder.dec_blocks.10.resnet.c4.bias
# decoder.decoder.dec_blocks.11.enc.c1.weight
# decoder.decoder.dec_blocks.11.enc.c1.bias
# decoder.decoder.dec_blocks.11.enc.c2.weight
# decoder.decoder.dec_blocks.11.enc.c2.bias
# decoder.decoder.dec_blocks.11.enc.c3.weight
# decoder.decoder.dec_blocks.11.enc.c3.bias
# decoder.decoder.dec_blocks.11.enc.c4.weight
# decoder.decoder.dec_blocks.11.enc.c4.bias
# decoder.decoder.dec_blocks.11.prior.c1.weight
# decoder.decoder.dec_blocks.11.prior.c1.bias
# decoder.decoder.dec_blocks.11.prior.c2.weight
# decoder.decoder.dec_blocks.11.prior.c2.bias
# decoder.decoder.dec_blocks.11.prior.c3.weight
# decoder.decoder.dec_blocks.11.prior.c3.bias
# decoder.decoder.dec_blocks.11.prior.c4.weight
# decoder.decoder.dec_blocks.11.prior.c4.bias
# decoder.decoder.dec_blocks.11.z_proj.weight
# decoder.decoder.dec_blocks.11.z_proj.bias
# decoder.decoder.dec_blocks.11.resnet.c1.weight
# decoder.decoder.dec_blocks.11.resnet.c1.bias
# decoder.decoder.dec_blocks.11.resnet.c2.weight
# decoder.decoder.dec_blocks.11.resnet.c2.bias
# decoder.decoder.dec_blocks.11.resnet.c3.weight
# decoder.decoder.dec_blocks.11.resnet.c3.bias
# decoder.decoder.dec_blocks.11.resnet.c4.weight
# decoder.decoder.dec_blocks.11.resnet.c4.bias
# decoder.decoder.dec_blocks.12.enc.c1.weight
# decoder.decoder.dec_blocks.12.enc.c1.bias
# decoder.decoder.dec_blocks.12.enc.c2.weight
# decoder.decoder.dec_blocks.12.enc.c2.bias
# decoder.decoder.dec_blocks.12.enc.c3.weight
# decoder.decoder.dec_blocks.12.enc.c3.bias
# decoder.decoder.dec_blocks.12.enc.c4.weight
# decoder.decoder.dec_blocks.12.enc.c4.bias
# decoder.decoder.dec_blocks.12.prior.c1.weight
# decoder.decoder.dec_blocks.12.prior.c1.bias
# decoder.decoder.dec_blocks.12.prior.c2.weight
# decoder.decoder.dec_blocks.12.prior.c2.bias
# decoder.decoder.dec_blocks.12.prior.c3.weight
# decoder.decoder.dec_blocks.12.prior.c3.bias
# decoder.decoder.dec_blocks.12.prior.c4.weight
# decoder.decoder.dec_blocks.12.prior.c4.bias
# decoder.decoder.dec_blocks.12.z_proj.weight
# decoder.decoder.dec_blocks.12.z_proj.bias
# decoder.decoder.dec_blocks.12.resnet.c1.weight
# decoder.decoder.dec_blocks.12.resnet.c1.bias
# decoder.decoder.dec_blocks.12.resnet.c2.weight
# decoder.decoder.dec_blocks.12.resnet.c2.bias
# decoder.decoder.dec_blocks.12.resnet.c3.weight
# decoder.decoder.dec_blocks.12.resnet.c3.bias
# decoder.decoder.dec_blocks.12.resnet.c4.weight
# decoder.decoder.dec_blocks.12.resnet.c4.bias
# decoder.decoder.dec_blocks.13.enc.c1.weight
# decoder.decoder.dec_blocks.13.enc.c1.bias
# decoder.decoder.dec_blocks.13.enc.c2.weight
# decoder.decoder.dec_blocks.13.enc.c2.bias
# decoder.decoder.dec_blocks.13.enc.c3.weight
# decoder.decoder.dec_blocks.13.enc.c3.bias
# decoder.decoder.dec_blocks.13.enc.c4.weight
# decoder.decoder.dec_blocks.13.enc.c4.bias
# decoder.decoder.dec_blocks.13.prior.c1.weight
# decoder.decoder.dec_blocks.13.prior.c1.bias
# decoder.decoder.dec_blocks.13.prior.c2.weight
# decoder.decoder.dec_blocks.13.prior.c2.bias
# decoder.decoder.dec_blocks.13.prior.c3.weight
# decoder.decoder.dec_blocks.13.prior.c3.bias
# decoder.decoder.dec_blocks.13.prior.c4.weight
# decoder.decoder.dec_blocks.13.prior.c4.bias
# decoder.decoder.dec_blocks.13.z_proj.weight
# decoder.decoder.dec_blocks.13.z_proj.bias
# decoder.decoder.dec_blocks.13.resnet.c1.weight
# decoder.decoder.dec_blocks.13.resnet.c1.bias
# decoder.decoder.dec_blocks.13.resnet.c2.weight
# decoder.decoder.dec_blocks.13.resnet.c2.bias
# decoder.decoder.dec_blocks.13.resnet.c3.weight
# decoder.decoder.dec_blocks.13.resnet.c3.bias
# decoder.decoder.dec_blocks.13.resnet.c4.weight
# decoder.decoder.dec_blocks.13.resnet.c4.bias
# decoder.decoder.dec_blocks.14.enc.c1.weight
# decoder.decoder.dec_blocks.14.enc.c1.bias
# decoder.decoder.dec_blocks.14.enc.c2.weight
# decoder.decoder.dec_blocks.14.enc.c2.bias
# decoder.decoder.dec_blocks.14.enc.c3.weight
# decoder.decoder.dec_blocks.14.enc.c3.bias
# decoder.decoder.dec_blocks.14.enc.c4.weight
# decoder.decoder.dec_blocks.14.enc.c4.bias
# decoder.decoder.dec_blocks.14.prior.c1.weight
# decoder.decoder.dec_blocks.14.prior.c1.bias
# decoder.decoder.dec_blocks.14.prior.c2.weight
# decoder.decoder.dec_blocks.14.prior.c2.bias
# decoder.decoder.dec_blocks.14.prior.c3.weight
# decoder.decoder.dec_blocks.14.prior.c3.bias
# decoder.decoder.dec_blocks.14.prior.c4.weight
# decoder.decoder.dec_blocks.14.prior.c4.bias
# decoder.decoder.dec_blocks.14.z_proj.weight
# decoder.decoder.dec_blocks.14.z_proj.bias
# decoder.decoder.dec_blocks.14.resnet.c1.weight
# decoder.decoder.dec_blocks.14.resnet.c1.bias
# decoder.decoder.dec_blocks.14.resnet.c2.weight
# decoder.decoder.dec_blocks.14.resnet.c2.bias
# decoder.decoder.dec_blocks.14.resnet.c3.weight
# decoder.decoder.dec_blocks.14.resnet.c3.bias
# decoder.decoder.dec_blocks.14.resnet.c4.weight
# decoder.decoder.dec_blocks.14.resnet.c4.bias
# decoder.decoder.dec_blocks.15.enc.c1.weight
# decoder.decoder.dec_blocks.15.enc.c1.bias
# decoder.decoder.dec_blocks.15.enc.c2.weight
# decoder.decoder.dec_blocks.15.enc.c2.bias
# decoder.decoder.dec_blocks.15.enc.c3.weight
# decoder.decoder.dec_blocks.15.enc.c3.bias
# decoder.decoder.dec_blocks.15.enc.c4.weight
# decoder.decoder.dec_blocks.15.enc.c4.bias
# decoder.decoder.dec_blocks.15.prior.c1.weight
# decoder.decoder.dec_blocks.15.prior.c1.bias
# decoder.decoder.dec_blocks.15.prior.c2.weight
# decoder.decoder.dec_blocks.15.prior.c2.bias
# decoder.decoder.dec_blocks.15.prior.c3.weight
# decoder.decoder.dec_blocks.15.prior.c3.bias
# decoder.decoder.dec_blocks.15.prior.c4.weight
# decoder.decoder.dec_blocks.15.prior.c4.bias
# decoder.decoder.dec_blocks.15.z_proj.weight
# decoder.decoder.dec_blocks.15.z_proj.bias
# decoder.decoder.dec_blocks.15.resnet.c1.weight
# decoder.decoder.dec_blocks.15.resnet.c1.bias
# decoder.decoder.dec_blocks.15.resnet.c2.weight
# decoder.decoder.dec_blocks.15.resnet.c2.bias
# decoder.decoder.dec_blocks.15.resnet.c3.weight
# decoder.decoder.dec_blocks.15.resnet.c3.bias
# decoder.decoder.dec_blocks.15.resnet.c4.weight
# decoder.decoder.dec_blocks.15.resnet.c4.bias
# decoder.decoder.dec_blocks.16.enc.c1.weight
# decoder.decoder.dec_blocks.16.enc.c1.bias
# decoder.decoder.dec_blocks.16.enc.c2.weight
# decoder.decoder.dec_blocks.16.enc.c2.bias
# decoder.decoder.dec_blocks.16.enc.c3.weight
# decoder.decoder.dec_blocks.16.enc.c3.bias
# decoder.decoder.dec_blocks.16.enc.c4.weight
# decoder.decoder.dec_blocks.16.enc.c4.bias
# decoder.decoder.dec_blocks.16.prior.c1.weight
# decoder.decoder.dec_blocks.16.prior.c1.bias
# decoder.decoder.dec_blocks.16.prior.c2.weight
# decoder.decoder.dec_blocks.16.prior.c2.bias
# decoder.decoder.dec_blocks.16.prior.c3.weight
# decoder.decoder.dec_blocks.16.prior.c3.bias
# decoder.decoder.dec_blocks.16.prior.c4.weight
# decoder.decoder.dec_blocks.16.prior.c4.bias
# decoder.decoder.dec_blocks.16.z_proj.weight
# decoder.decoder.dec_blocks.16.z_proj.bias
# decoder.decoder.dec_blocks.16.resnet.c1.weight
# decoder.decoder.dec_blocks.16.resnet.c1.bias
# decoder.decoder.dec_blocks.16.resnet.c2.weight
# decoder.decoder.dec_blocks.16.resnet.c2.bias
# decoder.decoder.dec_blocks.16.resnet.c3.weight
# decoder.decoder.dec_blocks.16.resnet.c3.bias
# decoder.decoder.dec_blocks.16.resnet.c4.weight
# decoder.decoder.dec_blocks.16.resnet.c4.bias
# decoder.decoder.dec_blocks.17.enc.c1.weight
# decoder.decoder.dec_blocks.17.enc.c1.bias
# decoder.decoder.dec_blocks.17.enc.c2.weight
# decoder.decoder.dec_blocks.17.enc.c2.bias
# decoder.decoder.dec_blocks.17.enc.c3.weight
# decoder.decoder.dec_blocks.17.enc.c3.bias
# decoder.decoder.dec_blocks.17.enc.c4.weight
# decoder.decoder.dec_blocks.17.enc.c4.bias
# decoder.decoder.dec_blocks.17.prior.c1.weight
# decoder.decoder.dec_blocks.17.prior.c1.bias
# decoder.decoder.dec_blocks.17.prior.c2.weight
# decoder.decoder.dec_blocks.17.prior.c2.bias
# decoder.decoder.dec_blocks.17.prior.c3.weight
# decoder.decoder.dec_blocks.17.prior.c3.bias
# decoder.decoder.dec_blocks.17.prior.c4.weight
# decoder.decoder.dec_blocks.17.prior.c4.bias
# decoder.decoder.dec_blocks.17.z_proj.weight
# decoder.decoder.dec_blocks.17.z_proj.bias
# decoder.decoder.dec_blocks.17.resnet.c1.weight
# decoder.decoder.dec_blocks.17.resnet.c1.bias
# decoder.decoder.dec_blocks.17.resnet.c2.weight
# decoder.decoder.dec_blocks.17.resnet.c2.bias
# decoder.decoder.dec_blocks.17.resnet.c3.weight
# decoder.decoder.dec_blocks.17.resnet.c3.bias
# decoder.decoder.dec_blocks.17.resnet.c4.weight
# decoder.decoder.dec_blocks.17.resnet.c4.bias
# decoder.decoder.dec_blocks.18.enc.c1.weight
# decoder.decoder.dec_blocks.18.enc.c1.bias
# decoder.decoder.dec_blocks.18.enc.c2.weight
# decoder.decoder.dec_blocks.18.enc.c2.bias
# decoder.decoder.dec_blocks.18.enc.c3.weight
# decoder.decoder.dec_blocks.18.enc.c3.bias
# decoder.decoder.dec_blocks.18.enc.c4.weight
# decoder.decoder.dec_blocks.18.enc.c4.bias
# decoder.decoder.dec_blocks.18.prior.c1.weight
# decoder.decoder.dec_blocks.18.prior.c1.bias
# decoder.decoder.dec_blocks.18.prior.c2.weight
# decoder.decoder.dec_blocks.18.prior.c2.bias
# decoder.decoder.dec_blocks.18.prior.c3.weight
# decoder.decoder.dec_blocks.18.prior.c3.bias
# decoder.decoder.dec_blocks.18.prior.c4.weight
# decoder.decoder.dec_blocks.18.prior.c4.bias
# decoder.decoder.dec_blocks.18.z_proj.weight
# decoder.decoder.dec_blocks.18.z_proj.bias
# decoder.decoder.dec_blocks.18.resnet.c1.weight
# decoder.decoder.dec_blocks.18.resnet.c1.bias
# decoder.decoder.dec_blocks.18.resnet.c2.weight
# decoder.decoder.dec_blocks.18.resnet.c2.bias
# decoder.decoder.dec_blocks.18.resnet.c3.weight
# decoder.decoder.dec_blocks.18.resnet.c3.bias
# decoder.decoder.dec_blocks.18.resnet.c4.weight
# decoder.decoder.dec_blocks.18.resnet.c4.bias
# decoder.decoder.dec_blocks.19.enc.c1.weight
# decoder.decoder.dec_blocks.19.enc.c1.bias
# decoder.decoder.dec_blocks.19.enc.c2.weight
# decoder.decoder.dec_blocks.19.enc.c2.bias
# decoder.decoder.dec_blocks.19.enc.c3.weight
# decoder.decoder.dec_blocks.19.enc.c3.bias
# decoder.decoder.dec_blocks.19.enc.c4.weight
# decoder.decoder.dec_blocks.19.enc.c4.bias
# decoder.decoder.dec_blocks.19.prior.c1.weight
# decoder.decoder.dec_blocks.19.prior.c1.bias
# decoder.decoder.dec_blocks.19.prior.c2.weight
# decoder.decoder.dec_blocks.19.prior.c2.bias
# decoder.decoder.dec_blocks.19.prior.c3.weight
# decoder.decoder.dec_blocks.19.prior.c3.bias
# decoder.decoder.dec_blocks.19.prior.c4.weight
# decoder.decoder.dec_blocks.19.prior.c4.bias
# decoder.decoder.dec_blocks.19.z_proj.weight
# decoder.decoder.dec_blocks.19.z_proj.bias
# decoder.decoder.dec_blocks.19.resnet.c1.weight
# decoder.decoder.dec_blocks.19.resnet.c1.bias
# decoder.decoder.dec_blocks.19.resnet.c2.weight
# decoder.decoder.dec_blocks.19.resnet.c2.bias
# decoder.decoder.dec_blocks.19.resnet.c3.weight
# decoder.decoder.dec_blocks.19.resnet.c3.bias
# decoder.decoder.dec_blocks.19.resnet.c4.weight
# decoder.decoder.dec_blocks.19.resnet.c4.bias
# decoder.decoder.dec_blocks.20.enc.c1.weight
# decoder.decoder.dec_blocks.20.enc.c1.bias
# decoder.decoder.dec_blocks.20.enc.c2.weight
# decoder.decoder.dec_blocks.20.enc.c2.bias
# decoder.decoder.dec_blocks.20.enc.c3.weight
# decoder.decoder.dec_blocks.20.enc.c3.bias
# decoder.decoder.dec_blocks.20.enc.c4.weight
# decoder.decoder.dec_blocks.20.enc.c4.bias
# decoder.decoder.dec_blocks.20.prior.c1.weight
# decoder.decoder.dec_blocks.20.prior.c1.bias
# decoder.decoder.dec_blocks.20.prior.c2.weight
# decoder.decoder.dec_blocks.20.prior.c2.bias
# decoder.decoder.dec_blocks.20.prior.c3.weight
# decoder.decoder.dec_blocks.20.prior.c3.bias
# decoder.decoder.dec_blocks.20.prior.c4.weight
# decoder.decoder.dec_blocks.20.prior.c4.bias
# decoder.decoder.dec_blocks.20.z_proj.weight
# decoder.decoder.dec_blocks.20.z_proj.bias
# decoder.decoder.dec_blocks.20.resnet.c1.weight
# decoder.decoder.dec_blocks.20.resnet.c1.bias
# decoder.decoder.dec_blocks.20.resnet.c2.weight
# decoder.decoder.dec_blocks.20.resnet.c2.bias
# decoder.decoder.dec_blocks.20.resnet.c3.weight
# decoder.decoder.dec_blocks.20.resnet.c3.bias
# decoder.decoder.dec_blocks.20.resnet.c4.weight
# decoder.decoder.dec_blocks.20.resnet.c4.bias
# decoder.decoder.dec_blocks.21.enc.c1.weight
# decoder.decoder.dec_blocks.21.enc.c1.bias
# decoder.decoder.dec_blocks.21.enc.c2.weight
# decoder.decoder.dec_blocks.21.enc.c2.bias
# decoder.decoder.dec_blocks.21.enc.c3.weight
# decoder.decoder.dec_blocks.21.enc.c3.bias
# decoder.decoder.dec_blocks.21.enc.c4.weight
# decoder.decoder.dec_blocks.21.enc.c4.bias
# decoder.decoder.dec_blocks.21.prior.c1.weight
# decoder.decoder.dec_blocks.21.prior.c1.bias
# decoder.decoder.dec_blocks.21.prior.c2.weight
# decoder.decoder.dec_blocks.21.prior.c2.bias
# decoder.decoder.dec_blocks.21.prior.c3.weight
# decoder.decoder.dec_blocks.21.prior.c3.bias
# decoder.decoder.dec_blocks.21.prior.c4.weight
# decoder.decoder.dec_blocks.21.prior.c4.bias
# decoder.decoder.dec_blocks.21.z_proj.weight
# decoder.decoder.dec_blocks.21.z_proj.bias
# decoder.decoder.dec_blocks.21.resnet.c1.weight
# decoder.decoder.dec_blocks.21.resnet.c1.bias
# decoder.decoder.dec_blocks.21.resnet.c2.weight
# decoder.decoder.dec_blocks.21.resnet.c2.bias
# decoder.decoder.dec_blocks.21.resnet.c3.weight
# decoder.decoder.dec_blocks.21.resnet.c3.bias
# decoder.decoder.dec_blocks.21.resnet.c4.weight
# decoder.decoder.dec_blocks.21.resnet.c4.bias
# decoder.decoder.dec_blocks.22.enc.c1.weight
# decoder.decoder.dec_blocks.22.enc.c1.bias
# decoder.decoder.dec_blocks.22.enc.c2.weight
# decoder.decoder.dec_blocks.22.enc.c2.bias
# decoder.decoder.dec_blocks.22.enc.c3.weight
# decoder.decoder.dec_blocks.22.enc.c3.bias
# decoder.decoder.dec_blocks.22.enc.c4.weight
# decoder.decoder.dec_blocks.22.enc.c4.bias
# decoder.decoder.dec_blocks.22.prior.c1.weight
# decoder.decoder.dec_blocks.22.prior.c1.bias
# decoder.decoder.dec_blocks.22.prior.c2.weight
# decoder.decoder.dec_blocks.22.prior.c2.bias
# decoder.decoder.dec_blocks.22.prior.c3.weight
# decoder.decoder.dec_blocks.22.prior.c3.bias
# decoder.decoder.dec_blocks.22.prior.c4.weight
# decoder.decoder.dec_blocks.22.prior.c4.bias
# decoder.decoder.dec_blocks.22.z_proj.weight
# decoder.decoder.dec_blocks.22.z_proj.bias
# decoder.decoder.dec_blocks.22.resnet.c1.weight
# decoder.decoder.dec_blocks.22.resnet.c1.bias
# decoder.decoder.dec_blocks.22.resnet.c2.weight
# decoder.decoder.dec_blocks.22.resnet.c2.bias
# decoder.decoder.dec_blocks.22.resnet.c3.weight
# decoder.decoder.dec_blocks.22.resnet.c3.bias
# decoder.decoder.dec_blocks.22.resnet.c4.weight
# decoder.decoder.dec_blocks.22.resnet.c4.bias
# decoder.decoder.dec_blocks.23.enc.c1.weight
# decoder.decoder.dec_blocks.23.enc.c1.bias
# decoder.decoder.dec_blocks.23.enc.c2.weight
# decoder.decoder.dec_blocks.23.enc.c2.bias
# decoder.decoder.dec_blocks.23.enc.c3.weight
# decoder.decoder.dec_blocks.23.enc.c3.bias
# decoder.decoder.dec_blocks.23.enc.c4.weight
# decoder.decoder.dec_blocks.23.enc.c4.bias
# decoder.decoder.dec_blocks.23.prior.c1.weight
# decoder.decoder.dec_blocks.23.prior.c1.bias
# decoder.decoder.dec_blocks.23.prior.c2.weight
# decoder.decoder.dec_blocks.23.prior.c2.bias
# decoder.decoder.dec_blocks.23.prior.c3.weight
# decoder.decoder.dec_blocks.23.prior.c3.bias
# decoder.decoder.dec_blocks.23.prior.c4.weight
# decoder.decoder.dec_blocks.23.prior.c4.bias
# decoder.decoder.dec_blocks.23.z_proj.weight
# decoder.decoder.dec_blocks.23.z_proj.bias
# decoder.decoder.dec_blocks.23.resnet.c1.weight
# decoder.decoder.dec_blocks.23.resnet.c1.bias
# decoder.decoder.dec_blocks.23.resnet.c2.weight
# decoder.decoder.dec_blocks.23.resnet.c2.bias
# decoder.decoder.dec_blocks.23.resnet.c3.weight
# decoder.decoder.dec_blocks.23.resnet.c3.bias
# decoder.decoder.dec_blocks.23.resnet.c4.weight
# decoder.decoder.dec_blocks.23.resnet.c4.bias
# decoder.decoder.dec_blocks.26.enc.c3.bias
# decoder.decoder.dec_blocks.26.enc.c4.weight
# decoder.decoder.dec_blocks.26.enc.c4.bias
# decoder.decoder.dec_blocks.26.prior.c1.weight
# decoder.decoder.dec_blocks.26.prior.c1.bias
# decoder.decoder.dec_blocks.26.prior.c2.weight
# decoder.decoder.dec_blocks.26.prior.c2.bias
# decoder.decoder.dec_blocks.26.prior.c3.weight
# decoder.decoder.dec_blocks.26.prior.c3.bias
# decoder.decoder.dec_blocks.26.prior.c4.weight
# decoder.decoder.dec_blocks.26.prior.c4.bias
# decoder.decoder.dec_blocks.26.z_proj.weight
# decoder.decoder.dec_blocks.26.z_proj.bias
# decoder.decoder.dec_blocks.26.resnet.c1.weight
# decoder.decoder.dec_blocks.26.resnet.c1.bias
# decoder.decoder.dec_blocks.26.resnet.c2.weight
# decoder.decoder.dec_blocks.26.resnet.c2.bias
# decoder.decoder.dec_blocks.26.resnet.c3.weight
# decoder.decoder.dec_blocks.26.resnet.c3.bias
# decoder.decoder.dec_blocks.26.resnet.c4.weight
# decoder.decoder.dec_blocks.26.resnet.c4.bias
# decoder.decoder.dec_blocks.27.enc.c1.weight
# decoder.decoder.dec_blocks.27.enc.c1.bias
# decoder.decoder.dec_blocks.27.enc.c2.weight
# decoder.decoder.dec_blocks.27.enc.c2.bias
# decoder.decoder.dec_blocks.27.enc.c3.weight
# decoder.decoder.dec_blocks.27.enc.c3.bias
# decoder.decoder.dec_blocks.27.enc.c4.weight
# decoder.decoder.dec_blocks.27.enc.c4.bias
# decoder.decoder.dec_blocks.27.prior.c1.weight
# decoder.decoder.dec_blocks.27.prior.c1.bias
# decoder.decoder.dec_blocks.27.prior.c2.weight
# decoder.decoder.dec_blocks.27.prior.c2.bias
# decoder.decoder.dec_blocks.27.prior.c3.weight
# decoder.decoder.dec_blocks.27.prior.c3.bias
# decoder.decoder.dec_blocks.27.prior.c4.weight
# decoder.decoder.dec_blocks.27.prior.c4.bias
# decoder.decoder.dec_blocks.27.z_proj.weight
# decoder.decoder.dec_blocks.27.z_proj.bias
# decoder.decoder.dec_blocks.27.resnet.c1.weight
# decoder.decoder.dec_blocks.27.resnet.c1.bias
# decoder.decoder.dec_blocks.27.resnet.c2.weight
# decoder.decoder.dec_blocks.27.resnet.c2.bias
# decoder.decoder.dec_blocks.27.resnet.c3.weight
# decoder.decoder.dec_blocks.27.resnet.c3.bias
# decoder.decoder.dec_blocks.27.resnet.c4.weight
# decoder.decoder.dec_blocks.27.resnet.c4.bias
# decoder.decoder.dec_blocks.28.enc.c1.weight
# decoder.decoder.dec_blocks.28.enc.c1.bias
# decoder.decoder.dec_blocks.28.enc.c2.weight
# decoder.decoder.dec_blocks.28.enc.c2.bias
# decoder.decoder.dec_blocks.28.enc.c3.weight
# decoder.decoder.dec_blocks.28.enc.c3.bias
# decoder.decoder.dec_blocks.28.enc.c4.weight
# decoder.decoder.dec_blocks.28.enc.c4.bias
# decoder.decoder.dec_blocks.28.prior.c1.weight
# decoder.decoder.dec_blocks.28.prior.c1.bias
# decoder.decoder.dec_blocks.28.prior.c2.weight
# decoder.decoder.dec_blocks.28.prior.c2.bias
# decoder.decoder.dec_blocks.28.prior.c3.weight
# decoder.decoder.dec_blocks.28.prior.c3.bias
# decoder.decoder.dec_blocks.28.prior.c4.weight
# decoder.decoder.dec_blocks.28.prior.c4.bias
# decoder.decoder.dec_blocks.28.z_proj.weight
# decoder.decoder.dec_blocks.28.z_proj.bias
# decoder.decoder.dec_blocks.28.resnet.c1.weight
# decoder.decoder.dec_blocks.28.resnet.c1.bias
# decoder.decoder.dec_blocks.28.resnet.c2.weight
# decoder.decoder.dec_blocks.28.resnet.c2.bias
# decoder.decoder.dec_blocks.28.resnet.c3.weight
# decoder.decoder.dec_blocks.28.resnet.c3.bias
# decoder.decoder.dec_blocks.28.resnet.c4.weight
# decoder.decoder.dec_blocks.28.resnet.c4.bias
# decoder.decoder.dec_blocks.29.enc.c1.weight
# decoder.decoder.dec_blocks.29.enc.c1.bias
# decoder.decoder.dec_blocks.29.enc.c2.weight
# decoder.decoder.dec_blocks.29.enc.c2.bias
# decoder.decoder.dec_blocks.29.enc.c3.weight
# decoder.decoder.dec_blocks.29.enc.c3.bias
# decoder.decoder.dec_blocks.29.enc.c4.weight
# decoder.decoder.dec_blocks.29.enc.c4.bias
# decoder.decoder.dec_blocks.29.prior.c1.weight
# decoder.decoder.dec_blocks.29.prior.c1.bias
# decoder.decoder.dec_blocks.29.prior.c2.weight
# decoder.decoder.dec_blocks.29.prior.c2.bias
# decoder.decoder.dec_blocks.29.prior.c3.weight
# decoder.decoder.dec_blocks.29.prior.c3.bias
# decoder.decoder.dec_blocks.29.prior.c4.weight
# decoder.decoder.dec_blocks.29.prior.c4.bias
# decoder.decoder.dec_blocks.29.z_proj.weight
# decoder.decoder.dec_blocks.29.z_proj.bias
# decoder.decoder.dec_blocks.29.resnet.c1.weight
# decoder.decoder.dec_blocks.29.resnet.c1.bias
# decoder.decoder.dec_blocks.29.resnet.c2.weight
# decoder.decoder.dec_blocks.29.resnet.c2.bias
# decoder.decoder.dec_blocks.29.resnet.c3.weight
# decoder.decoder.dec_blocks.29.resnet.c3.bias
# decoder.decoder.dec_blocks.29.resnet.c4.weight
# decoder.decoder.dec_blocks.29.resnet.c4.bias
# decoder.decoder.dec_blocks.30.enc.c1.weight
# decoder.decoder.dec_blocks.30.enc.c1.bias
# decoder.decoder.dec_blocks.30.enc.c2.weight
# decoder.decoder.dec_blocks.30.enc.c2.bias
# decoder.decoder.dec_blocks.30.enc.c3.weight
# decoder.decoder.dec_blocks.30.enc.c3.bias
# decoder.decoder.dec_blocks.30.enc.c4.weight
# decoder.decoder.dec_blocks.30.enc.c4.bias
# decoder.decoder.dec_blocks.30.prior.c1.weight
# decoder.decoder.dec_blocks.30.prior.c1.bias
# decoder.decoder.dec_blocks.30.prior.c2.weight
# decoder.decoder.dec_blocks.30.prior.c2.bias
# decoder.decoder.dec_blocks.30.prior.c3.weight
# decoder.decoder.dec_blocks.32.resnet.c1.weight
# decoder.decoder.dec_blocks.32.resnet.c1.bias
# decoder.decoder.dec_blocks.32.resnet.c2.weight
# decoder.decoder.dec_blocks.32.resnet.c2.bias
# decoder.decoder.dec_blocks.32.resnet.c3.weight
# decoder.decoder.dec_blocks.32.resnet.c3.bias
# decoder.decoder.dec_blocks.32.resnet.c4.weight
# decoder.decoder.dec_blocks.32.resnet.c4.bias
# decoder.decoder.dec_blocks.33.enc.c1.weight
# decoder.decoder.dec_blocks.33.enc.c1.bias
# decoder.decoder.dec_blocks.33.enc.c2.weight
# decoder.decoder.dec_blocks.33.enc.c2.bias
# decoder.decoder.dec_blocks.33.enc.c3.weight
# decoder.decoder.dec_blocks.33.enc.c3.bias
# decoder.decoder.dec_blocks.33.enc.c4.weight
# decoder.decoder.dec_blocks.33.enc.c4.bias
# decoder.decoder.dec_blocks.33.prior.c1.weight
# decoder.decoder.dec_blocks.33.prior.c1.bias
# decoder.decoder.dec_blocks.33.prior.c2.weight
# decoder.decoder.dec_blocks.33.prior.c2.bias
# decoder.decoder.dec_blocks.33.prior.c3.weight
# decoder.decoder.dec_blocks.33.prior.c3.bias
# decoder.decoder.dec_blocks.33.prior.c4.weight
# decoder.decoder.dec_blocks.33.prior.c4.bias
# decoder.decoder.dec_blocks.33.z_proj.weight
# decoder.decoder.dec_blocks.33.z_proj.bias
# decoder.decoder.dec_blocks.33.resnet.c1.weight
# decoder.decoder.dec_blocks.33.resnet.c1.bias
# decoder.decoder.dec_blocks.33.resnet.c2.weight
# decoder.decoder.dec_blocks.33.resnet.c2.bias
# decoder.decoder.dec_blocks.33.resnet.c3.weight
# decoder.decoder.dec_blocks.33.resnet.c3.bias
# decoder.decoder.dec_blocks.33.resnet.c4.weight
# decoder.decoder.dec_blocks.33.resnet.c4.bias
# decoder.decoder.dec_blocks.34.enc.c1.weight
# decoder.decoder.dec_blocks.34.enc.c1.bias
# decoder.decoder.dec_blocks.34.enc.c2.weight
# decoder.decoder.dec_blocks.34.enc.c2.bias
# decoder.decoder.dec_blocks.34.enc.c3.weight
# decoder.decoder.dec_blocks.34.enc.c3.bias
# decoder.decoder.dec_blocks.34.enc.c4.weight
# decoder.decoder.dec_blocks.34.enc.c4.bias
# decoder.decoder.dec_blocks.34.prior.c1.weight
# decoder.decoder.dec_blocks.34.prior.c1.bias
# decoder.decoder.dec_blocks.34.prior.c2.weight
# decoder.decoder.dec_blocks.34.prior.c2.bias
# decoder.decoder.dec_blocks.34.prior.c3.weight
# decoder.decoder.dec_blocks.34.prior.c3.bias
# decoder.decoder.dec_blocks.34.prior.c4.weight
# decoder.decoder.dec_blocks.34.prior.c4.bias
# decoder.decoder.dec_blocks.34.z_proj.weight
# decoder.decoder.dec_blocks.34.z_proj.bias
# decoder.decoder.dec_blocks.34.resnet.c1.weight
# decoder.decoder.dec_blocks.34.resnet.c1.bias
# decoder.decoder.dec_blocks.34.resnet.c2.weight
# decoder.decoder.dec_blocks.34.resnet.c2.bias
# decoder.decoder.dec_blocks.34.resnet.c3.weight
# decoder.decoder.dec_blocks.34.resnet.c3.bias
# decoder.decoder.dec_blocks.34.resnet.c4.weight
# decoder.decoder.dec_blocks.34.resnet.c4.bias
# decoder.decoder.dec_blocks.35.enc.c1.weight
# decoder.decoder.dec_blocks.35.enc.c1.bias
# decoder.decoder.dec_blocks.35.enc.c2.weight
# decoder.decoder.dec_blocks.35.enc.c2.bias
# decoder.decoder.dec_blocks.35.enc.c3.weight
# decoder.decoder.dec_blocks.35.enc.c3.bias
# decoder.decoder.dec_blocks.35.enc.c4.weight
# decoder.decoder.dec_blocks.35.enc.c4.bias
# decoder.decoder.dec_blocks.35.prior.c1.weight
# decoder.decoder.dec_blocks.35.prior.c1.bias
# decoder.decoder.dec_blocks.35.prior.c2.weight
# decoder.decoder.dec_blocks.35.prior.c2.bias
# decoder.decoder.dec_blocks.35.prior.c3.weight
# decoder.decoder.dec_blocks.35.prior.c3.bias
# decoder.decoder.dec_blocks.35.prior.c4.weight
# decoder.decoder.dec_blocks.35.prior.c4.bias
# decoder.decoder.dec_blocks.35.z_proj.weight
# decoder.decoder.dec_blocks.35.z_proj.bias
# decoder.decoder.dec_blocks.35.resnet.c1.weight
# decoder.decoder.dec_blocks.35.resnet.c1.bias
# decoder.decoder.dec_blocks.35.resnet.c2.weight
# decoder.decoder.dec_blocks.35.resnet.c2.bias
# decoder.decoder.dec_blocks.35.resnet.c3.weight
# decoder.decoder.dec_blocks.35.resnet.c3.bias
# decoder.decoder.dec_blocks.35.resnet.c4.weight
# decoder.decoder.dec_blocks.35.resnet.c4.bias
# decoder.decoder.dec_blocks.36.enc.c1.weight
# decoder.decoder.dec_blocks.36.enc.c1.bias
# decoder.decoder.dec_blocks.36.enc.c2.weight
# decoder.decoder.dec_blocks.36.enc.c2.bias
# decoder.decoder.dec_blocks.36.enc.c3.weight
# decoder.decoder.dec_blocks.36.enc.c3.bias
# decoder.decoder.dec_blocks.36.enc.c4.weight
# decoder.decoder.dec_blocks.36.enc.c4.bias
# decoder.decoder.dec_blocks.36.prior.c1.weight
# decoder.decoder.dec_blocks.36.prior.c1.bias
# decoder.decoder.dec_blocks.36.prior.c2.weight
# decoder.decoder.dec_blocks.36.prior.c2.bias
# decoder.decoder.dec_blocks.36.prior.c3.weight
# decoder.decoder.dec_blocks.36.prior.c3.bias
# decoder.decoder.dec_blocks.36.prior.c4.weight
# decoder.decoder.dec_blocks.36.prior.c4.bias
# decoder.decoder.dec_blocks.36.z_proj.weight
# decoder.decoder.dec_blocks.36.z_proj.bias
# decoder.decoder.dec_blocks.36.resnet.c1.weight
# decoder.decoder.dec_blocks.36.resnet.c1.bias
# decoder.decoder.dec_blocks.36.resnet.c2.weight
# decoder.decoder.dec_blocks.36.resnet.c2.bias
# decoder.decoder.dec_blocks.36.resnet.c3.weight
# decoder.decoder.dec_blocks.36.resnet.c3.bias
# decoder.decoder.dec_blocks.36.resnet.c4.weight
# decoder.decoder.dec_blocks.36.resnet.c4.bias
# decoder.decoder.dec_blocks.37.enc.c1.weight
# decoder.decoder.dec_blocks.37.enc.c1.bias
# decoder.decoder.dec_blocks.37.enc.c2.weight
# decoder.decoder.dec_blocks.37.enc.c2.bias
# decoder.decoder.dec_blocks.37.enc.c3.weight
# decoder.decoder.dec_blocks.37.enc.c3.bias
# decoder.decoder.dec_blocks.37.enc.c4.weight
# decoder.decoder.dec_blocks.37.enc.c4.bias
# decoder.decoder.dec_blocks.37.prior.c1.weight
# decoder.decoder.dec_blocks.37.prior.c1.bias
# decoder.decoder.dec_blocks.37.prior.c2.weight
# decoder.decoder.dec_blocks.37.prior.c2.bias
# decoder.decoder.dec_blocks.37.prior.c3.weight
# decoder.decoder.dec_blocks.37.prior.c3.bias
# decoder.decoder.dec_blocks.37.prior.c4.weight
# decoder.decoder.dec_blocks.37.prior.c4.bias
# decoder.decoder.dec_blocks.37.z_proj.weight
# decoder.decoder.dec_blocks.37.z_proj.bias
# decoder.decoder.dec_blocks.37.resnet.c1.weight
# decoder.decoder.dec_blocks.37.resnet.c1.bias
# decoder.decoder.dec_blocks.37.resnet.c2.weight
# decoder.decoder.dec_blocks.37.resnet.c2.bias
# decoder.decoder.dec_blocks.37.resnet.c3.weight
# decoder.decoder.dec_blocks.37.resnet.c3.bias
# decoder.decoder.dec_blocks.37.resnet.c4.weight
# decoder.decoder.dec_blocks.37.resnet.c4.bias
# decoder.decoder.dec_blocks.38.enc.c1.weight
# decoder.decoder.dec_blocks.38.enc.c1.bias
# decoder.decoder.dec_blocks.38.enc.c2.weight
# decoder.decoder.dec_blocks.38.enc.c2.bias
# decoder.decoder.dec_blocks.38.enc.c3.weight
# decoder.decoder.dec_blocks.38.enc.c3.bias
# decoder.decoder.dec_blocks.38.enc.c4.weight
# decoder.decoder.dec_blocks.38.enc.c4.bias
# decoder.decoder.dec_blocks.38.prior.c1.weight
# decoder.decoder.dec_blocks.38.prior.c1.bias
# decoder.decoder.dec_blocks.38.prior.c2.weight
# decoder.decoder.dec_blocks.38.prior.c2.bias
# decoder.decoder.dec_blocks.38.prior.c3.weight
# decoder.decoder.dec_blocks.38.prior.c3.bias
# decoder.decoder.dec_blocks.38.prior.c4.weight
# decoder.decoder.dec_blocks.38.prior.c4.bias
# decoder.decoder.dec_blocks.38.z_proj.weight
# decoder.decoder.dec_blocks.38.z_proj.bias
# decoder.decoder.dec_blocks.38.resnet.c1.weight
# decoder.decoder.dec_blocks.38.resnet.c1.bias
# decoder.decoder.dec_blocks.38.resnet.c2.weight
# decoder.decoder.dec_blocks.38.resnet.c2.bias
# decoder.decoder.dec_blocks.38.resnet.c3.weight
# decoder.decoder.dec_blocks.38.resnet.c3.bias
# decoder.decoder.dec_blocks.38.resnet.c4.weight
# decoder.decoder.dec_blocks.38.resnet.c4.bias
# decoder.decoder.dec_blocks.39.enc.c1.weight
# decoder.decoder.dec_blocks.39.enc.c1.bias
# decoder.decoder.dec_blocks.39.enc.c2.weight
# decoder.decoder.dec_blocks.39.enc.c2.bias
# decoder.decoder.dec_blocks.39.enc.c3.weight
# decoder.decoder.dec_blocks.39.enc.c3.bias
# decoder.decoder.dec_blocks.39.enc.c4.weight
# decoder.decoder.dec_blocks.39.enc.c4.bias
# decoder.decoder.dec_blocks.39.prior.c1.weight
# decoder.decoder.dec_blocks.39.prior.c1.bias
# decoder.decoder.dec_blocks.39.prior.c2.weight
# decoder.decoder.dec_blocks.39.prior.c2.bias
# decoder.decoder.dec_blocks.39.prior.c3.weight
# decoder.decoder.dec_blocks.39.prior.c3.bias
# decoder.decoder.dec_blocks.39.prior.c4.weight
# decoder.decoder.dec_blocks.39.prior.c4.bias
# decoder.decoder.dec_blocks.39.z_proj.weight
# decoder.decoder.dec_blocks.39.z_proj.bias
# decoder.decoder.dec_blocks.39.resnet.c1.weight
# decoder.decoder.dec_blocks.39.resnet.c1.bias
# decoder.decoder.dec_blocks.39.resnet.c2.weight
# decoder.decoder.dec_blocks.39.resnet.c2.bias
# decoder.decoder.dec_blocks.39.resnet.c3.weight
# decoder.decoder.dec_blocks.39.resnet.c3.bias
# decoder.decoder.dec_blocks.39.resnet.c4.weight
# decoder.decoder.dec_blocks.39.resnet.c4.bias
# decoder.decoder.dec_blocks.40.enc.c1.weight
# decoder.decoder.dec_blocks.40.enc.c1.bias
# decoder.decoder.dec_blocks.40.enc.c2.weight
# decoder.decoder.dec_blocks.40.enc.c2.bias
# decoder.decoder.dec_blocks.40.enc.c3.weight
# decoder.decoder.dec_blocks.40.enc.c3.bias
# decoder.decoder.dec_blocks.40.enc.c4.weight
# decoder.decoder.dec_blocks.40.enc.c4.bias
# decoder.decoder.dec_blocks.40.prior.c1.weight
# decoder.decoder.dec_blocks.40.prior.c1.bias
# decoder.decoder.dec_blocks.40.prior.c2.weight
# decoder.decoder.dec_blocks.40.prior.c2.bias
# decoder.decoder.dec_blocks.40.prior.c3.weight
# decoder.decoder.dec_blocks.40.prior.c3.bias
# decoder.decoder.dec_blocks.40.prior.c4.weight
# decoder.decoder.dec_blocks.40.prior.c4.bias
# decoder.decoder.dec_blocks.40.z_proj.weight
# decoder.decoder.dec_blocks.40.z_proj.bias
# decoder.decoder.dec_blocks.40.resnet.c1.weight
# decoder.decoder.dec_blocks.40.resnet.c1.bias
# decoder.decoder.dec_blocks.40.resnet.c2.weight
# decoder.decoder.dec_blocks.40.resnet.c2.bias
# decoder.decoder.dec_blocks.40.resnet.c3.weight
# decoder.decoder.dec_blocks.40.resnet.c3.bias
# decoder.decoder.dec_blocks.40.resnet.c4.weight
# decoder.decoder.dec_blocks.40.resnet.c4.bias
# decoder.decoder.dec_blocks.41.enc.c1.weight
# decoder.decoder.dec_blocks.41.enc.c1.bias
# decoder.decoder.dec_blocks.41.enc.c2.weight
# decoder.decoder.dec_blocks.41.enc.c2.bias
# decoder.decoder.dec_blocks.41.enc.c3.weight
# decoder.decoder.dec_blocks.41.enc.c3.bias
# decoder.decoder.dec_blocks.41.enc.c4.weight
# decoder.decoder.dec_blocks.41.enc.c4.bias
# decoder.decoder.dec_blocks.41.prior.c1.weight
# decoder.decoder.dec_blocks.41.prior.c1.bias
# decoder.decoder.dec_blocks.41.prior.c2.weight
# decoder.decoder.dec_blocks.41.prior.c2.bias
# decoder.decoder.dec_blocks.41.prior.c3.weight
# decoder.decoder.dec_blocks.41.prior.c3.bias
# decoder.decoder.dec_blocks.41.prior.c4.weight
# decoder.decoder.dec_blocks.41.prior.c4.bias
# decoder.decoder.dec_blocks.41.z_proj.weight
# decoder.decoder.dec_blocks.41.z_proj.bias
# decoder.decoder.dec_blocks.41.resnet.c1.weight
# decoder.decoder.dec_blocks.41.resnet.c1.bias
# decoder.decoder.dec_blocks.41.resnet.c2.weight
# decoder.decoder.dec_blocks.41.resnet.c2.bias
# decoder.decoder.dec_blocks.41.resnet.c3.weight
# decoder.decoder.dec_blocks.41.resnet.c3.bias
# decoder.decoder.dec_blocks.41.resnet.c4.weight
# decoder.decoder.dec_blocks.41.resnet.c4.bias
# decoder.decoder.dec_blocks.42.enc.c1.weight
# decoder.decoder.dec_blocks.42.enc.c1.bias
# decoder.decoder.dec_blocks.42.enc.c2.weight
# decoder.decoder.dec_blocks.42.enc.c2.bias
# decoder.decoder.dec_blocks.42.enc.c3.weight
# decoder.decoder.dec_blocks.42.enc.c3.bias
# decoder.decoder.dec_blocks.42.enc.c4.weight
# decoder.decoder.dec_blocks.42.enc.c4.bias
# decoder.decoder.dec_blocks.42.prior.c1.weight
# decoder.decoder.dec_blocks.42.prior.c1.bias
# decoder.decoder.dec_blocks.42.prior.c2.weight
# decoder.decoder.dec_blocks.42.prior.c2.bias
# decoder.decoder.dec_blocks.42.prior.c3.weight
# decoder.decoder.dec_blocks.42.prior.c3.bias
# decoder.decoder.dec_blocks.42.prior.c4.weight
# decoder.decoder.dec_blocks.42.prior.c4.bias
# decoder.decoder.dec_blocks.42.z_proj.weight
# decoder.decoder.dec_blocks.42.z_proj.bias
# decoder.decoder.dec_blocks.42.resnet.c1.weight
# decoder.decoder.dec_blocks.42.resnet.c1.bias
# decoder.decoder.dec_blocks.42.resnet.c2.weight
# decoder.decoder.dec_blocks.42.resnet.c2.bias
# decoder.decoder.dec_blocks.42.resnet.c3.weight
# decoder.decoder.dec_blocks.42.resnet.c3.bias
# decoder.decoder.dec_blocks.42.resnet.c4.weight
# decoder.decoder.dec_blocks.42.resnet.c4.bias
# decoder.decoder.bias_xs.0
# decoder.decoder.bias_xs.1
# decoder.decoder.bias_xs.2
# decoder.decoder.bias_xs.3
# decoder.decoder.bias_xs.4
# loss.out_net.out_conv.weight
# loss.out_net.out_conv.bias
# done

# %% [markdown]
# ### Dataset

# %%
from torch.utils.data import DataLoader
from data.vdvae_data import set_up_data

hp, data_train, data_valid_or_test, preprocess_fn = set_up_data(hp)
hp.image_size = 32
train_loader = DataLoader(data_train, batch_size=hp.n_batch, drop_last=True, pin_memory=True)
print(train_loader)
# Out:
# DOING TEST
# <torch.utils.data.dataloader.DataLoader object at 0x7f720f75e7e0>

# %% [markdown]
# ### Train

# %%
import time
from util.train_helpers import update_ema

def training_step(H, data_input, target, model, ema_model, optimizer):
    model.train()
    model.zero_grad()
    data = {'x': data_input,
            'x_target': target}
    stats = model.forward(data)
    stats['elbo'].backward()
    grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), H.grad_clip).item()
    distortion_nans = torch.isnan(stats['distortion']).sum()
    rate_nans = torch.isnan(stats['rate']).sum()
    stats.update(dict(rate_nans=0 if rate_nans == 0 else 1, distortion_nans=0 if distortion_nans == 0 else 1))

    skipped_updates = 1
    # only update if no rank has a nan and if the grad norm is below a specific threshold
    if stats['distortion_nans'] == 0 and stats['rate_nans'] == 0 and (H.skip_threshold == -1 or grad_norm < H.skip_threshold):
        optimizer.step()
        skipped_updates = 0
        if ema_model is not None:
            update_ema(model, ema_model, H.ema_rate)

    stats.update(skipped_updates=skipped_updates, grad_norm=grad_norm)
    return stats

def show_samples(model, N):
    model.eval()
    with torch.no_grad():
        samples = model.sample(N)
    plt.figure(figsize=[18, 4])
    for i in range(len(samples)):
        plt.subplot(1, N, i+1)
        plt.imshow(samples[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()

# %%
import matplotlib.pyplot as plt
from IPython import display
import torchvision.transforms as transforms

resize = transforms.Resize((hp.image_size, hp.image_size))

while True:
    for x in train_loader:
        x[0] = resize(x[0].permute(0, 3, 1, 2)).permute(0, 2, 3, 1)
        data_input, target = preprocess_fn(x)
        data_input = data_input.to(device)
        target = target.to(device)
        stats = training_step(hp, data_input, target, model, ema_model, optimizer)

        if step % 10 == 0:
            print(step, 'elbo', stats['elbo'].item())
            writer.add_scalar('elbo', stats['elbo'].item(), step)
            writer.add_scalar('distortion', stats['distortion'].item(), step)
            writer.add_scalar('rate', stats['rate'].item(), step)
            
        if step % 1000 == 0:
            display.clear_output()
            show_samples(model, 10)
            
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 16010 elbo 1.0792295932769775
# 16020 elbo 1.132434606552124
# 16030 elbo 1.1564445495605469
# 16040 elbo 1.169511079788208
# 16050 elbo 1.1058456897735596
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 13
#      11 data_input = data_input.to(device)
#      12 target = target.to(device)
# ---> 13 stats = training_step(hp, data_input, target, model, ema_model, optimizer)
#      15 if step % 10 == 0:
#      16     print(step, 'elbo', stats['elbo'].item())
#
# Cell In[15], line 10, in training_step(H, data_input, target, model, ema_model, optimizer)
#       7 data = {'x': data_input,
#       8         'x_target': target}
#       9 stats = model.forward(data)
# ---> 10 stats['elbo'].backward()
#      11 grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), H.grad_clip).item()
#      12 distortion_nans = torch.isnan(stats['distortion']).sum()
#
# File ~/anaconda3/envs/ste/lib/python3.12/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/anaconda3/envs/ste/lib/python3.12/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
save(save_dir, step, model, optimizer)
print('done')
# Out:
# done

# %%
import matplotlib.pyplot as plt
show_samples(model, 10)

# %%
_stats = stats['stats']
for i in range(len(_stats)):
    kl = _stats[i]['kl'][0].sum(dim=0)
    kl = kl.data.cpu().numpy()
    kl_mean = np.mean(kl)
    print(kl.shape, kl_mean)
#     plt.imshow(kl, vmin=0, vmax=1)
#     plt.colorbar()
#     plt.show()
# Out:
# (1, 1) 5.6484065
# (4, 4) 1.0471808
# (4, 4) 0.7980242
# (4, 4) 0.90898836
# (8, 8) 0.74006397
# (8, 8) 0.80547214
# (8, 8) 0.7370492
# (16, 16) 0.63494813
# (16, 16) 0.9579793
# (16, 16) 0.9361669
# (32, 32) 0.14695513
# (32, 32) 0.13710248
# (32, 32) 0.09602876
