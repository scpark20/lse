# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="3"

device = 'cuda:0'
# Out:
# Mon Jan 15 17:25:10 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   26C    P8    13W / 230W |      8MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 44%   71C    P2   201W / 230W |   5310MiB / 24564MiB |     75%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   42C    P2    85W / 230W |  17664MiB / 24564MiB |     35%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   27C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   29C    P8    16W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   28C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   28C    P8    22W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   28C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2654311      C   ...onda3/envs/ste/bin/python     5302MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   2684201      C   ...onda3/envs/ste/bin/python    17656MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

### Preprocess
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# Create data loaders
# train_loader = DataLoader(mnist_trainset, batch_size=60000, shuffle=False)
# batch = next(iter(train_loader))
# data = preprocess(batch)
# print(data.keys())

test_loader = DataLoader(mnist_testset, batch_size=10000, shuffle=False)
batch = next(iter(test_loader))
data = preprocess(batch)
print(data.keys())
# Out:
# dict_keys(['x', 't'])

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.min_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
model_list = []
for i in range(10):
    model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
    model = model.to(device)
    model.eval()
    model_list.append(model)
    
print('done')
# Out:
# done

# %% [markdown]
# ### Load

# %%
# !ls -lt /data/scpark/save/lse/train01.14-4/
# Out:
# total 8924480
# -rw-rw-r-- 1 scpark scpark  23370684  1월 15 13:01 events.out.tfevents.1705221569.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 12:19 save_230000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 11:31 save_220000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 10:43 save_210000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 09:55 save_200000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 09:07 save_190000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 08:19 save_180000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 07:31 save_170000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 06:44 save_160000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 05:56 save_150000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 05:08 save_140000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 04:18 save_130000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 03:29 save_120000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 02:40 save_110000
# -rw-rw-r-- 1 scpark scpark 379803125  1월 15 01:50 save_100000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 15 01:01 save_90000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 15 00:11 save_80000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 14 23:21 save_70000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 14 22:32 save_60000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 14 21:44 save_50000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 14 20:55 save_40000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 14 20:07 save_30000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 14 19:19 save_20000
# -rw-rw-r-- 1 scpark scpark 379800983  1월 14 18:29 save_10000
# -rw-rw-r-- 1 scpark scpark 379787295  1월 14 17:39 save_0
# -rw-rw-r-- 1 scpark scpark        40  1월 14 17:39 events.out.tfevents.1705221153.GPUSVR01
# -rw-rw-r-- 1 scpark scpark        40  1월 14 17:32 events.out.tfevents.1705220744.GPUSVR01

# %%
from tqdm import tqdm_notebook as tqdm

save_path = '/data/scpark/save/lse/train01.14-9/save_200000'

# warm start
models_state_dict = torch.load(save_path, map_location=torch.device('cpu'))['models_state_dict']
for i, model in tqdm(enumerate(model_list)):
    model.load_state_dict(models_state_dict[i], strict=True)
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# ### Reconstruction Loss

# %% [markdown]
# #### Partial

# %%
N = 10000

z_list = []
recon_loss_list = []
for model in tqdm(model_list):
    with torch.no_grad():
        zs = []
        recon_losses = []
        for i in range(0, len(data['x']), N):
            result = {'x': data['x'][i:i+N]}
            result = model(result, M=1)
            zs.append(result['z'])
            recon_losses.append(result['recon_loss'].item())
            
        z_list.append(torch.cat(zs, dim=0))
        recon_loss_list.append(np.mean(recon_losses))
        
print('Reconstruction Loss :', np.mean(recon_loss_list))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Reconstruction Loss : 0.08311194007595381

# %% [markdown]
# #### All

# %%
z_list = []
recon_loss_list = []
for model in tqdm(model_list):
    with torch.no_grad():
        data = model(data, M=1)
        z_list.append(data['z'])
        recon_loss_list.append(data['recon_loss'].item())
        
print('Reconstruction Loss :', np.mean(recon_loss_list))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Reconstruction Loss : 0.11366319209337235

# %% [markdown]
# ### Linear Classification Test

# %%
def get_linear_classification_test(z, t, n_steps=100000):
    from model.classifier.linear_classifier import Classifier
    accuracy_list = []
    classifier = Classifier(2, 10)
    classifier = classifier.to(device)
    classifier.train()
    optimizer = torch.optim.AdamW(classifier.parameters(), lr=1e-3)
    
    data = {'z': z, 't': t}
    for _ in tqdm(range(n_steps)):
        data = classifier(data)
        loss = data['cross_entropy_loss']
        loss.backward()
        optimizer.step()
        accuracy_list.append(data['accuracy'].item())
    return accuracy_list

print('done')
# Out:
# done

# %%
import matplotlib.pyplot as plt

accuracys = []
for z in z_list:
    accuracy_list = get_linear_classification_test(z, data['t'])
    accuracys.append(accuracy_list[-1])
    plt.figure(figsize=[18, 3])
    plt.plot(accuracy_list)
    plt.grid()
    plt.show()
    
print('Accuracy :', np.mean(accuracys))
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Accuracy : 0.7331699848175048

# %% [markdown]
# ### Two-Linear Classification Test

# %%
def get_two_linear_classification_test(z, t, n_steps=100000):
    from model.classifier.two_linear_classifier import Classifier
    accuracy_list = []
    classifier = Classifier(2, 512, 10)
    classifier = classifier.to(device)
    classifier.train()
    optimizer = torch.optim.AdamW(classifier.parameters(), lr=1e-3)
    
    data = {'z': z, 't': t}
    for _ in tqdm(range(n_steps)):
        data = classifier(data)
        loss = data['cross_entropy_loss']
        loss.backward()
        optimizer.step()
        accuracy_list.append(data['accuracy'].item())
    return accuracy_list

print('done')
# Out:
# done

# %%
import matplotlib.pyplot as plt

accuracys = []
for z in z_list:
    accuracy_list = get_two_linear_classification_test(z, data['t'])
    accuracys.append(accuracy_list[-1])
    plt.figure(figsize=[18, 3])
    plt.plot(accuracy_list)
    plt.grid()
    plt.show()
    
print('Accuracy :', np.mean(accuracys))
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Accuracy : 0.8743399739265442

# %% [markdown]
# ### Silhouette Score Test

# %%
from sklearn.metrics import silhouette_score

scores = []
for z in tqdm(z_list):
    _z = z.data.cpu().numpy()
    _t = data['t'].data.cpu().numpy()
    score = silhouette_score(_z, _t)
    scores.append(score)
    
print('Silhouette Score :', np.mean(scores))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Silhouette Score : 0.123127185

# %% [markdown]
# ### MMD Test

# %%
from test_util.mmd_loss import MMDLoss

mmd_losses = []
mmd = MMDLoss()
for z in tqdm(z_list):
    prior = torch.randn_like(z)
    mmd_loss = mmd(prior.to('cpu'), z.to('cpu'))
    mmd_losses.append(mmd_loss.item())
    
print('MMD Loss :', np.mean(mmd_losses))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# MMD Loss : 0.08510630130767823

# %% [markdown]
# #### deviation correction

# %%
from test_util.mmd_loss import MMDLoss

mmd_losses = []
mmd = MMDLoss()
for z in tqdm(z_list):
    std = z.std(dim=0)
    prior = torch.randn_like(z)
    mmd_loss = mmd(prior.to('cpu'), z.to('cpu'))
    mmd_losses.append(mmd_loss.item())
    
print('MMD Loss :', np.mean(mmd_losses))
# Out:
# tensor([1.2669, 1.2200], device='cuda:0')
# tensor([1.2525, 1.2719], device='cuda:0')
# tensor([1.2998, 1.3286], device='cuda:0')
# tensor([1.2943, 1.2584], device='cuda:0')
# tensor([1.2865, 1.2491], device='cuda:0')
# tensor([1.3571, 1.3033], device='cuda:0')
# tensor([1.2556, 1.3066], device='cuda:0')
# tensor([1.2898, 1.2719], device='cuda:0')
# tensor([1.3054, 1.2737], device='cuda:0')
# tensor([1.2880, 1.2599], device='cuda:0')

# %% [markdown]
# ### View Embeddings

# %%
import matplotlib.pyplot as plt

# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)


for z in z_list:
    _z = z.data.cpu().numpy()
    plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'), alpha=0.1)
    plt.grid()
    plt.colorbar()
    plt.show()
