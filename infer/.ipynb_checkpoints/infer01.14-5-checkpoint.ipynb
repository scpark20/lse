# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="2"

device = 'cuda:0'
# Out:
# Mon Jan 15 17:01:55 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   28C    P8    13W / 230W |  18440MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 44%   70C    P2   205W / 230W |   5310MiB / 24564MiB |     63%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   25C    P8    15W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   26C    P8    23W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   28C    P8    16W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   28C    P8    22W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   27C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   28C    P8    21W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2679222      C   ...onda3/envs/ste/bin/python    18432MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2654311      C   ...onda3/envs/ste/bin/python     5302MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

### Preprocess
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=60000, shuffle=False)
batch = next(iter(train_loader))
data = preprocess(batch)
print(data.keys())

# test_loader = DataLoader(mnist_testset, batch_size=10000, shuffle=False)
# batch = next(iter(test_loader))
# data = preprocess(batch)
# print(data.keys())
# Out:
# dict_keys(['x', 't'])

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.trainable_sigma_uniform_lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.init_log_sigma = -2.11
hp.h_dims = [32, 64, 128, 256, 512]

# %%
model_list = []
for i in range(10):
    model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
    model = model.to(device)
    model.eval()
    model_list.append(model)
    
print('done')
# Out:
# done

# %% [markdown]
# ### Load

# %%
# !ls -lt /data/scpark/save/lse/train01.14-5/
# Out:
# total 8552740
# -rw-rw-r-- 1 scpark scpark  22237708  1월 15 13:15 events.out.tfevents.1705222584.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 12:38 save_220000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 11:47 save_210000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 10:55 save_200000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 10:04 save_190000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 09:13 save_180000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 08:22 save_170000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 07:31 save_160000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 06:39 save_150000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 05:48 save_140000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 04:56 save_130000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 04:04 save_120000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 03:13 save_110000
# -rw-rw-r-- 1 scpark scpark 379814701  1월 15 02:21 save_100000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 15 01:30 save_90000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 15 00:38 save_80000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 14 23:47 save_70000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 14 22:55 save_60000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 14 22:05 save_50000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 14 21:15 save_40000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 14 20:26 save_30000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 14 19:36 save_20000
# -rw-rw-r-- 1 scpark scpark 379812519  1월 14 18:45 save_10000
# -rw-rw-r-- 1 scpark scpark 379799247  1월 14 17:56 save_0

# %%
from tqdm import tqdm_notebook as tqdm

save_path = '/data/scpark/save/lse/train01.14-5/save_200000'

# warm start
models_state_dict = torch.load(save_path, map_location=torch.device('cpu'))['models_state_dict']
for i, model in tqdm(enumerate(model_list)):
    model.load_state_dict(models_state_dict[i], strict=True)
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# ### Reconstruction Loss

# %%
N = 10000

z_list = []
recon_loss_list = []
for model in tqdm(model_list):
    with torch.no_grad():
        zs = []
        recon_losses = []
        for i in range(0, len(data['x']), N):
            result = {'x': data['x'][i:i+N]}
            result = model(result, M=1)
            zs.append(result['z'])
            recon_losses.append(result['recon_loss'].item())
            
        z_list.append(torch.cat(zs, dim=0))
        recon_loss_list.append(np.mean(recon_losses))
        
print('Reconstruction Loss :', np.mean(recon_loss_list))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### Linear Classification Test

# %%
def get_linear_classification_test(z, t, n_steps=100000):
    from model.classifier.linear_classifier import Classifier
    accuracy_list = []
    classifier = Classifier(2, 10)
    classifier = classifier.to(device)
    classifier.train()
    optimizer = torch.optim.AdamW(classifier.parameters(), lr=1e-3)
    
    data = {'z': z, 't': t}
    for _ in tqdm(range(n_steps)):
        data = classifier(data)
        loss = data['cross_entropy_loss']
        loss.backward()
        optimizer.step()
        accuracy_list.append(data['accuracy'].item())
    return accuracy_list

print('done')
# Out:
# done

# %%
import matplotlib.pyplot as plt

accuracys = []
for z in z_list:
    accuracy_list = get_linear_classification_test(z, data['t'])
    accuracys.append(accuracy_list[-1])
    plt.figure(figsize=[18, 3])
    plt.plot(accuracy_list)
    plt.grid()
    plt.show()
    
print('Accuracy :', np.mean(accuracys))
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Accuracy : 0.6889899790287017

# %% [markdown]
# ### Two-Linear Classification Test

# %%
def get_two_linear_classification_test(z, t, n_steps=100000):
    from model.classifier.two_linear_classifier import Classifier
    accuracy_list = []
    classifier = Classifier(2, 512, 10)
    classifier = classifier.to(device)
    classifier.train()
    optimizer = torch.optim.AdamW(classifier.parameters(), lr=1e-3)
    
    data = {'z': z, 't': t}
    for _ in tqdm(range(n_steps)):
        data = classifier(data)
        loss = data['cross_entropy_loss']
        loss.backward()
        optimizer.step()
        accuracy_list.append(data['accuracy'].item())
    return accuracy_list

print('done')
# Out:
# done

# %%
import matplotlib.pyplot as plt

accuracys = []
for z in z_list:
    accuracy_list = get_two_linear_classification_test(z, data['t'])
    accuracys.append(accuracy_list[-1])
    plt.figure(figsize=[18, 3])
    plt.plot(accuracy_list)
    plt.grid()
    plt.show()
    
print('Accuracy :', np.mean(accuracys))
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Accuracy : 0.8244299769401551

# %% [markdown]
# ### Silhouette Score Test

# %%
from sklearn.metrics import silhouette_score

scores = []
for z in tqdm(z_list):
    _z = z.data.cpu().numpy()
    _t = data['t'].data.cpu().numpy()
    score = silhouette_score(_z, _t)
    scores.append(score)
    
print('Silhouette Score :', np.mean(scores))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Silhouette Score : 0.12272217

# %% [markdown]
# ### MMD Test

# %%
from test_util.mmd_loss import MMDLoss

mmd_losses = []
mmd = MMDLoss()
for z in tqdm(z_list):
    prior = (torch.rand_like(z) * 2) - 1
    mmd_loss = mmd(prior.to('cpu'), z.to('cpu'))
    mmd_losses.append(mmd_loss.item())
    
print('MMD Loss :', np.mean(mmd_losses))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# MMD Loss : 0.0030021905899047852

# %%
mmd_losses
# Out:
# [0.003771066665649414,
#  0.002272367477416992,
#  0.0034716129302978516,
#  0.0030295848846435547,
#  0.0019023418426513672,
#  0.00341033935546875,
#  0.0025281906127929688,
#  0.004370450973510742,
#  0.0027208328247070312,
#  0.0025451183319091797]

# %% [markdown]
# ### View Embeddings

# %%
import matplotlib.pyplot as plt

# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)


for z in z_list:
    _z = z.data.cpu().numpy()
    plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'), alpha=0.1)
    plt.grid()
    plt.colorbar()
    plt.show()
