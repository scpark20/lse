# %%
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator
import numpy as np
import matplotlib.ticker as ticker

def plot_tensorboard_tag(log_dirs, tag, ylim=None, log_func=None):
    plt.figure(figsize=[18, 4])

    # Function to format the x-axis labels as 'k' (thousands)
    def format_func(value, tick_number):
        return f'{int(value/1000)}k' if value >= 1000 else int(value)

    for log_dir in log_dirs:
        # Event accumulator to load the logs
        ea = event_accumulator.EventAccumulator(log_dir,
            size_guidance={event_accumulator.SCALARS: 0})
        ea.Reload()

        if tag in ea.Tags()['scalars']:
            events = ea.Scalars(tag)
            steps = [e.step for e in events]
            values = [e.value for e in events]
            if log_func is not None:
                plt.plot(steps, log_func(values), label=log_dir.split('/')[-1], alpha=0.3)
            else:    
                plt.plot(steps, values, label=log_dir.split('/')[-1], alpha=0.3)
            
    plt.xlabel('Steps')
    plt.ylabel(tag)
    plt.title(f'TensorBoard Scalars: {tag}')
    plt.legend()

    # Set the custom formatter for the x-axis
    ax = plt.gca()
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(format_func))

    if ylim is not None:
        plt.ylim(ylim)
    plt.grid() 
    plt.show()

# %%
def get_scalars(log_dirs):

    scalars_list = {}
    for log_dir in log_dirs:
        # Event accumulator to load the logs
        ea = event_accumulator.EventAccumulator(log_dir,
            size_guidance={event_accumulator.SCALARS: 0})
        ea.Reload()

        scalars = {}
        for tag in ea.Tags()['scalars']:
            events = ea.Scalars(tag)
            steps = [e.step for e in events]
            values = [e.value for e in events]
            scalars[tag] = (steps, values)
        scalars_list[log_dir] = scalars
    return scalars_list

# %% [markdown]
# ### Baseline VQVAE

# %%
vqvae = get_scalars(['/home/save/lse/train_dalle/train01.30-2/'])
print(vqvae.keys())
# Out:
# dict_keys(['/home/save/lse/train_dalle/train01.30-2/'])

# %% [markdown]
# ### MinVAE

# %%
log_dirs = ['/home/save/lse/train_dalle/train02.01-10',
            '/home/save/lse/train_dalle/train02.01-11',
            '/home/save/lse/train_dalle/train02.01-12',
           ]

scalars = get_scalars(log_dirs)
print(scalars.keys())
# Out:
# dict_keys(['/home/save/lse/train_dalle/train02.01-10', '/home/save/lse/train_dalle/train02.01-11', '/home/save/lse/train_dalle/train02.01-12'])

# %%
values = [scalars[log_dir]['commit_loss'] for log_dir in log_dirs]

plt.figure(figsize=[18, 4])
plt.plot(vqvae['/home/save/lse/train_dalle/train01.30-2/']['commit_loss'][0],
         np.log10(vqvae['/home/save/lse/train_dalle/train01.30-2/']['commit_loss'][1]),
         label='vqvae')
for i, value in enumerate(values):
    plt.plot(value[0], np.log10(value[1]), label=log_dirs[i])
plt.grid()
plt.legend()
plt.xlim([0, 500*1000])
plt.ylim([-4.0, -1])
plt.show()

# %%
values = [scalars[log_dir]['recon_loss'] for log_dir in log_dirs]

plt.figure(figsize=[18, 4])
plt.plot(vqvae['/home/save/lse/train_dalle/train01.30-2/']['recon_loss'][0],
         np.log10(vqvae['/home/save/lse/train_dalle/train01.30-2/']['recon_loss'][1]),
         label='vqvae')
for i, value in enumerate(values):
    plt.plot(value[0], np.log10(value[1]), label=log_dirs[i])
plt.grid()
plt.legend()
plt.xlim([0, 500*1000])
plt.ylim([-3.5, -2.0])
plt.show()

# %%
values = [scalars[log_dir]['usage'] for log_dir in log_dirs]

plt.figure(figsize=[18, 4])
for i, value in enumerate(values):
    plt.plot(value[0], value[1], label=log_dirs[i])
plt.grid()
plt.legend()
plt.xlim([0, 500*1000])
plt.show()

# %%
values = [scalars[log_dir]['entropy'] for log_dir in log_dirs]

plt.figure(figsize=[18, 4])
for i, value in enumerate(values):
    plt.plot(value[0], value[1], label=log_dirs[i])
plt.grid()
plt.legend()
plt.xlim([0, 500*1000])
plt.show()
