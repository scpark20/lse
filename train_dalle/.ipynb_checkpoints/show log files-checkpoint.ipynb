# %%
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing import event_accumulator
import numpy as np
import matplotlib.ticker as ticker

def plot_tensorboard_tag(log_dirs, tag, ylim=None, log_func=None):
    plt.figure(figsize=[18, 4])

    # Function to format the x-axis labels as 'k' (thousands)
    def format_func(value, tick_number):
        return f'{int(value/1000)}k' if value >= 1000 else int(value)

    for log_dir in log_dirs:
        # Event accumulator to load the logs
        ea = event_accumulator.EventAccumulator(log_dir,
            size_guidance={event_accumulator.SCALARS: 0})
        ea.Reload()

        if tag in ea.Tags()['scalars']:
            events = ea.Scalars(tag)
            steps = [e.step for e in events]
            values = [e.value for e in events]
            if log_func is not None:
                plt.plot(steps, log_func(values), label=log_dir.split('/')[-1])
            else:    
                plt.plot(steps, values, label=log_dir.split('/')[-1])
            
    plt.xlabel('Steps')
    plt.ylabel(tag)
    plt.title(f'TensorBoard Scalars: {tag}')
    plt.legend()

    # Set the custom formatter for the x-axis
    ax = plt.gca()
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(format_func))

    if ylim is not None:
        plt.ylim(ylim)
    plt.grid() 
    plt.show()

log_dirs = ['/home/save/lse/train_dalle/train01.29-3_1e-0',
            '/home/save/lse/train_dalle/train01.29-4_1e-0',
           ]

# Plot graphs with the modified function
plot_tensorboard_tag(log_dirs, 'commit_loss', log_func=np.log10)
plot_tensorboard_tag(log_dirs, 'recon_loss', [-0.2, 0.0], log_func=np.log10)
plot_tensorboard_tag(log_dirs, 'usage')

# %%
log_dirs = ['/home/save/lse/train_dalle/train01.29-3_1e-0_celeba',
            '/home/save/lse/train_dalle/train01.29-4_1e-0_celeba',
           ]

# Plot graphs with the modified function
plot_tensorboard_tag(log_dirs, 'commit_loss', log_func=np.log10)
plot_tensorboard_tag(log_dirs, 'recon_loss', log_func=np.log10)
plot_tensorboard_tag(log_dirs, 'usage')
