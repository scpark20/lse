# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Tue Jan 23 15:10:33 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.223.02   Driver Version: 470.223.02   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100 80G...  Off  | 00000000:1B:00.0 Off |                    0 |
# | N/A   31C    P0    43W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100 80G...  Off  | 00000000:1C:00.0 Off |                    0 |
# | N/A   43C    P0    45W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100 80G...  Off  | 00000000:1D:00.0 Off |                    0 |
# | N/A   53C    P0    74W / 300W |  35963MiB / 80994MiB |     41%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100 80G...  Off  | 00000000:1E:00.0 Off |                    0 |
# | N/A   41C    P0    45W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100 80G...  Off  | 00000000:89:00.0 Off |                    0 |
# | N/A   43C    P0    44W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100 80G...  Off  | 00000000:8A:00.0 Off |                    0 |
# | N/A   53C    P0    78W / 300W |  28027MiB / 80994MiB |     62%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100 80G...  Off  | 00000000:8B:00.0 Off |                    0 |
# | N/A   42C    P0    44W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100 80G...  Off  | 00000000:8C:00.0 Off |                    0 |
# | N/A   31C    P0    41W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    1   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    2   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    2   N/A  N/A   1609499      C   ...a3/envs/scpark/bin/python    35925MiB |
# |    3   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    4   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    5   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    5   N/A  N/A   1645912      C   ...a3/envs/scpark/bin/python    27989MiB |
# |    6   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    7   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_prior_latent_quantizer_dec import Model
from model.encoder.dalle_encoder import Encoder
from model.latent.vqvae_latent import Latent
from model.decoder.dalle_decoder import Decoder
from model.no_module import NoModule

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.img_size = 64
hp.n_resblocks = 6
hp.n_latents = 256
hp.z_dim = 512

# %%
step = 0
device = 'cuda:0'

model_list = []
optimizer_list = []
for i in range(1):
    model = Model(Encoder(**hp), NoModule(**hp), Latent(**hp), NoModule(**hp), Decoder(**hp))
    model = model.to(device)
    model_list.append(model)
    
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
    optimizer_list.append(optimizer)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))

print('done')
# Out:
# encoder 18.6689453125
# encoder.encoder 18.6689453125
# prior 0.0
# latent 0.0
# latent.bottle 0.0
# quantizer 0.0
# decoder 9.954113006591797
# decoder.decoder 9.954113006591797
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train_dalle/train01.21-1/'

# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if True:
    step, model_list, optimizer_list = load_model_list(save_dir, 100000, model_list, optimizer_list)
# Out:
# total 1462980
# -rw-rw-r-- 1 scpark scpark         0  1월 23 15:10 events.out.tfevents.1705990238.GPUSVR11
# -rw-rw-r-- 1 scpark scpark        40  1월 22 12:32 events.out.tfevents.1705886957.GPUSVR11
# -rw-rw-r-- 1 scpark scpark   6079875  1월 22 12:32 events.out.tfevents.1705886963.GPUSVR11
# -rw-rw-r-- 1 scpark scpark  90710013  1월 22 12:32 save_100000
# -rw-rw-r-- 1 scpark scpark  90709569  1월 22 12:12 save_90000
# -rw-rw-r-- 1 scpark scpark  90709569  1월 22 11:51 save_80000
# -rw-rw-r-- 1 scpark scpark  90709569  1월 22 11:30 save_70000
# -rw-rw-r-- 1 scpark scpark  90709569  1월 22 11:10 save_60000
# -rw-rw-r-- 1 scpark scpark  90709569  1월 22 10:50 save_50000
# -rw-rw-r-- 1 scpark scpark  90709569  1월 22 10:29 save_40000
# -rw-rw-r-- 1 scpark scpark   4812905  1월 21 22:45 events.out.tfevents.1705838827.GPUSVR11
# -rw-rw-r-- 1 scpark scpark  90709185  1월 21 22:09 save_30000
# -rw-rw-r-- 1 scpark scpark  90709185  1월 21 21:48 save_20000
# -rw-rw-r-- 1 scpark scpark  90709185  1월 21 21:28 save_10000
# -rw-rw-r-- 1 scpark scpark  90701841  1월 21 21:07 save_0
# -rw-rw-r-- 1 scpark scpark        40  1월 21 21:06 events.out.tfevents.1705838542.GPUSVR11
# -rw-rw-r-- 1 scpark scpark     62193  1월 21 21:06 events.out.tfevents.1705838544.GPUSVR11
# -rw-rw-r-- 1 scpark scpark        40  1월 21 21:01 events.out.tfevents.1705836383.GPUSVR11
# -rw-rw-r-- 1 scpark scpark    621068  1월 21 21:01 events.out.tfevents.1705836388.GPUSVR11
# -rw-rw-r-- 1 scpark scpark   2626544  1월 21 20:26 events.out.tfevents.1705828682.GPUSVR11
# -rw-rw-r-- 1 scpark scpark   7475463  1월 21 20:26 save_26332
# -rw-rw-r-- 1 scpark scpark   7474949  1월 21 19:00 save_7159
# -rw-rw-r-- 1 scpark scpark   7474949  1월 21 18:49 save_4843
# -rw-rw-r-- 1 scpark scpark     21764  1월 21 18:17 events.out.tfevents.1705828483.GPUSVR11
# -rw-rw-r-- 1 scpark scpark        40  1월 21 18:14 events.out.tfevents.1705828393.GPUSVR11
# -rw-rw-r-- 1 scpark scpark    234914  1월 21 17:59 events.out.tfevents.1705825910.GPUSVR11
# -rw-rw-r-- 1 scpark scpark 454020225  1월 21 17:37 save_837
# -rw-rw-r-- 1 scpark scpark        40  1월 21 16:22 events.out.tfevents.1705816273.GPUSVR11
# -rw-rw-r-- 1 scpark scpark   1685350  1월 21 16:22 events.out.tfevents.1705816279.GPUSVR11
# -rw-rw-r-- 1 scpark scpark       904  1월 21 14:49 events.out.tfevents.1705816051.GPUSVR11
# -rw-rw-r-- 1 scpark scpark      1577  1월 21 14:47 events.out.tfevents.1705815693.GPUSVR11
# -rw-rw-r-- 1 scpark scpark    101433  1월 21 14:41 events.out.tfevents.1705815361.GPUSVR11
# -rw-rw-r-- 1 scpark scpark   7474885  1월 21 14:41 save_1058
# -rw-rw-r-- 1 scpark scpark     24199  1월 21 14:35 events.out.tfevents.1705815231.GPUSVR11

# %% [markdown]
# ### Dataset

# %%
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CelebA

class MyCelebA(CelebA):
    """
    A work-around to address issues with pytorch's celebA dataset class.
    
    Download and Extract
    URL : https://drive.google.com/file/d/1m8-EBPgi5MRubrm6iQjafK2QMHDBMSfJ/view?usp=sharing
    """
    
    def _check_integrity(self) -> bool:
        return True

root = '/data'
train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                       transforms.CenterCrop(148),
                                       transforms.Resize(hp.img_size),
                                       transforms.ToTensor(),])
train_dataset = MyCelebA(root, split='train', transform=train_transforms, download=False)
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
print('done')
# Out:
# done

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.permute(0, 2, 3, 1).data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(8):
        plt.subplot(1, 8, i+1)
        plt.imshow(_x[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()

# %%
def linear(start_value, end_value, current_index, start_index, end_index):
    if current_index > end_index:
        return end_value
    if current_index < start_index:
        return start_value

    grad = (end_value - start_value) / (end_index - start_index)
    y = start_value + grad * (current_index - start_index)

    return y

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        loss_dict = {}
        for model, optimizer in zip(model_list, optimizer_list):
            data = preprocess(batch)

            # Forward
            model.train()
            model.zero_grad()
            data = model(data, latent_temp=1)

            # Backward
            loss = 0
            for key in data.keys():
                if 'loss' in key:
                    loss = loss + data[key]
                    if key in loss_dict:
                        loss_dict[key].append(data[key].item())
                    else:
                        loss_dict[key] = [data[key].item()]
                    
            loss.backward()
            optimizer.step()
            
        for key in loss_dict:
            writer.add_scalar(key, np.mean(loss_dict[key]), step)
            print(key, np.mean(loss_dict[key]))
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            x = data['x']
            y = data['y']
            
            plot(x)
            plot(y)
            
            def get_entropy(zi):
                # (N, L)
                zi_onehot = F.one_hot(zi, num_classes=hp.n_latents)
                # (L)
                probs = zi_onehot.sum(dim=0) / len(zi_onehot)
                entropy = torch.sum(-probs * (torch.log(torch.clamp(probs, 1e-8)) - np.log(2)))
                return entropy

            entropy = get_entropy(data['zi']).item()
            writer.add_scalar('entropy', entropy, step)
            
        if step % 10000 == 0:
            save_model_list(save_dir, step, model_list, optimizer_list)
                
        step += 1
# Out:
# 100001
# commit_loss 0.00031688500894233584
# recon_loss 0.002742694690823555
# 100002
# commit_loss 0.00030843436252325773
# recon_loss 0.0026244099717587233
# 100003
# commit_loss 0.0003277818323113024
# recon_loss 0.0027095419354736805
# 100004
# commit_loss 0.00033051459467969835
# recon_loss 0.002850025426596403
# 100005
# commit_loss 0.00034330051857978106
# recon_loss 0.002778432797640562
# 100006
# commit_loss 0.0003578827599994838
# recon_loss 0.0028069131076335907
# 100007
# commit_loss 0.00032760080648586154
# recon_loss 0.0027243352960795164
# 100008
# commit_loss 0.00030798185616731644
# recon_loss 0.0026695295237004757
# 100009
# commit_loss 0.0003055051201954484
# recon_loss 0.0025878180749714375
# 100010
# commit_loss 0.00034425410558469594
# recon_loss 0.0025537435431033373
# 100011
# commit_loss 0.00030925360624678433
# recon_loss 0.002551507903262973
# 100012
# commit_loss 0.00032167028984986246
# recon_loss 0.0025774138048291206
# 100013
# commit_loss 0.00032275859848596156
# recon_loss 0.0025701799895614386
# 100014
# commit_loss 0.0002842485555447638
# recon_loss 0.002391023561358452
# 100015
# commit_loss 0.0003053451073355973
# recon_loss 0.0027167133521288633
# 100016
# commit_loss 0.0003051739477086812
# recon_loss 0.0026235084515064955
# 100017
# commit_loss 0.0003364778822287917
# recon_loss 0.002869567833840847
# 100018
# commit_loss 0.00032764155184850097
# recon_loss 0.0026737842708826065
# 100019
# commit_loss 0.0003121651243418455
# recon_loss 0.00266949157230556
# 100020
# commit_loss 0.0003338402893859893
# recon_loss 0.0028193050529807806
# 100021
# commit_loss 0.0003010231885127723
# recon_loss 0.002499355934560299
# 100022
# commit_loss 0.00030946783954277635
# recon_loss 0.002567443996667862
# 100023
# commit_loss 0.0003227314737159759
# recon_loss 0.002616895828396082
# 100024
# commit_loss 0.0003131404228042811
# recon_loss 0.0027963235042989254
# 100025
# commit_loss 0.00029492093017324805
# recon_loss 0.0024951035156846046
# 100026
# commit_loss 0.00030177130247466266
# recon_loss 0.0026124026626348495
# 100027
# commit_loss 0.0003515888820402324
# recon_loss 0.0029156263917684555
# 100028
# commit_loss 0.0003310214669909328
# recon_loss 0.002724479651078582
# 100029
# commit_loss 0.0002918973914347589
# recon_loss 0.002578543499112129
# 100030
# commit_loss 0.00032535544596612453
# recon_loss 0.0028779292479157448
# 100031
# commit_loss 0.00033175470889545977
# recon_loss 0.002806561766192317
# 100032
# commit_loss 0.00034715759102255106
# recon_loss 0.0026944417040795088
# 100033
# commit_loss 0.0003211174625903368
# recon_loss 0.0027133426629006863
# 100034
# commit_loss 0.00031076022423803806
# recon_loss 0.0026454245671629906
# 100035
# commit_loss 0.00033009983599185944
# recon_loss 0.002739823190495372
# 100036
# commit_loss 0.00032790633849799633
# recon_loss 0.002932553179562092
# 100037
# commit_loss 0.00034352936199866235
# recon_loss 0.0029090018942952156
# 100038
# commit_loss 0.0003246295091230422
# recon_loss 0.0028075731825083494
# 100039
# commit_loss 0.0003050902741961181
# recon_loss 0.0026668100617825985
# 100040
# commit_loss 0.0003048606449738145
# recon_loss 0.002622735220938921
# 100041
# commit_loss 0.00027904598391614854
# recon_loss 0.002537735737860203
# 100042
# commit_loss 0.0003080015303567052
# recon_loss 0.0027813760098069906
# 100043
# commit_loss 0.00033496838295832276
# recon_loss 0.00287048052996397
# 100044
# commit_loss 0.0003163135552313179
# recon_loss 0.00268470193259418
# 100045
# commit_loss 0.0003101829788647592
# recon_loss 0.0026655877009034157
# 100046
# commit_loss 0.00032504985574632883
# recon_loss 0.0027674399316310883
# 100047
# commit_loss 0.0003172323922626674
# recon_loss 0.0027183829806745052
# 100048
# commit_loss 0.0003625695826485753
# recon_loss 0.002834303304553032
# 100049
# commit_loss 0.00032623004517517984
# recon_loss 0.0025994256138801575
# 100050
# commit_loss 0.00032426975667476654
# recon_loss 0.00284562143497169
# 100051
# commit_loss 0.0003213851014152169
# recon_loss 0.002779900562018156
# 100052
# commit_loss 0.00033070065546780825
# recon_loss 0.0027755312621593475
# 100053
# commit_loss 0.0003573549911379814
# recon_loss 0.0028166677802801132
# 100054
# commit_loss 0.00032689416548237205
# recon_loss 0.0029394845478236675
# 100055
# commit_loss 0.000328368681948632
# recon_loss 0.0027281527873128653
# 100056
# commit_loss 0.0002986083272844553
# recon_loss 0.0025068921968340874

# %%
save_model_list(save_dir, step, model_list, optimizer_list)
print('done')
