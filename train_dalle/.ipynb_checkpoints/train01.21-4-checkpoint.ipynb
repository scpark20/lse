# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="4"
# Out:
# Sun Jan 21 21:12:58 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.223.02   Driver Version: 470.223.02   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100 80G...  Off  | 00000000:1B:00.0 Off |                    0 |
# | N/A   30C    P0    42W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100 80G...  Off  | 00000000:1C:00.0 Off |                    0 |
# | N/A   62C    P0   288W / 300W |   7333MiB / 80994MiB |     77%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100 80G...  Off  | 00000000:1D:00.0 Off |                    0 |
# | N/A   65C    P0   315W / 300W |   8829MiB / 80994MiB |     99%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100 80G...  Off  | 00000000:1E:00.0 Off |                    0 |
# | N/A   66C    P0   256W / 300W |   8705MiB / 80994MiB |     99%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100 80G...  Off  | 00000000:89:00.0 Off |                    0 |
# | N/A   44C    P0    65W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100 80G...  Off  | 00000000:8A:00.0 Off |                    0 |
# | N/A   66C    P0   311W / 300W |   8765MiB / 80994MiB |    100%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100 80G...  Off  | 00000000:8B:00.0 Off |                    0 |
# | N/A   38C    P0    46W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100 80G...  Off  | 00000000:8C:00.0 Off |                    0 |
# | N/A   30C    P0    49W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    1   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    1   N/A  N/A   1366109      C   ...a3/envs/scpark/bin/python     7295MiB |
# |    2   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    2   N/A  N/A   1365986      C   ...a3/envs/scpark/bin/python     8791MiB |
# |    3   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    3   N/A  N/A   1367081      C   ...a3/envs/scpark/bin/python     8667MiB |
# |    4   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    5   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    5   N/A  N/A   1366484      C   ...a3/envs/scpark/bin/python     8727MiB |
# |    6   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    7   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_prior_latent_quantizer_dec import Model
from model.encoder.dalle_encoder import Encoder
from model.latent.divided_binary_vqvae_latent import Latent
from model.decoder.dalle_decoder import Decoder
from model.no_module import NoModule

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.img_size = 64
hp.n_resblocks = 6
hp.n_latents = 8
hp.z_dim = 512
hp.latent_linear = 1
print(hp.z_dim)
# Out:
# 512

# %%
step = 0
device = 'cuda:0'

model_list = []
optimizer_list = []
for i in range(1):
    model = Model(Encoder(**hp), NoModule(**hp), Latent(**hp), NoModule(**hp), Decoder(**hp))
    model = model.to(device)
    model_list.append(model)
    
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
    optimizer_list.append(optimizer)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))

print('done')
# Out:
# encoder 18.6689453125
# encoder.encoder 18.6689453125
# prior 0.0
# latent 0.0
# latent.bottles 0.0
# quantizer 0.0
# decoder 9.954113006591797
# decoder.decoder 9.954113006591797
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train_dalle/train01.21-4/'

# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, model_list, optimizer_list = load_model_list(save_dir, 12131, model_list, optimizer_list)
# Out:
# total 129404
# -rw-rw-r-- 1 scpark scpark        40  1월 21 21:12 events.out.tfevents.1705839129.GPUSVR11
# -rw-rw-r-- 1 scpark scpark        40  1월 21 21:11 events.out.tfevents.1705839089.GPUSVR11
# -rw-rw-r-- 1 scpark scpark        40  1월 21 21:11 events.out.tfevents.1705839012.GPUSVR11
# -rw-rw-r-- 1 scpark scpark        40  1월 21 21:10 events.out.tfevents.1705838880.GPUSVR11
# -rw-rw-r-- 1 scpark scpark        40  1월 21 21:07 events.out.tfevents.1705838773.GPUSVR11
# -rw-rw-r-- 1 scpark scpark     13089  1월 21 21:06 events.out.tfevents.1705838681.GPUSVR11
# -rw-rw-r-- 1 scpark scpark 115432783  1월 21 21:04 save_0
# -rw-rw-r-- 1 scpark scpark    207834  1월 21 21:01 events.out.tfevents.1705837834.GPUSVR11
# -rw-rw-r-- 1 scpark scpark   1200749  1월 21 20:50 events.out.tfevents.1705834176.GPUSVR11
# -rw-rw-r-- 1 scpark scpark        40  1월 21 20:50 events.out.tfevents.1705837819.GPUSVR11
# -rw-rw-r-- 1 scpark scpark   7805983  1월 21 20:50 save_12131
# -rw-rw-r-- 1 scpark scpark   7805983  1월 21 20:39 save_10000

# %% [markdown]
# ### Dataset

# %%
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CelebA

class MyCelebA(CelebA):
    """
    A work-around to address issues with pytorch's celebA dataset class.
    
    Download and Extract
    URL : https://drive.google.com/file/d/1m8-EBPgi5MRubrm6iQjafK2QMHDBMSfJ/view?usp=sharing
    """
    
    def _check_integrity(self) -> bool:
        return True

root = '/data'
train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                       transforms.CenterCrop(148),
                                       transforms.Resize(hp.img_size),
                                       transforms.ToTensor(),])
train_dataset = MyCelebA(root, split='train', transform=train_transforms, download=False)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
print('done')
# Out:
# done

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.permute(0, 2, 3, 1).data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(8):
        plt.subplot(1, 8, i+1)
        plt.imshow(_x[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()

# %%
def linear(start_value, end_value, current_index, start_index, end_index):
    if current_index > end_index:
        return end_value
    if current_index < start_index:
        return start_value

    grad = (end_value - start_value) / (end_index - start_index)
    y = start_value + grad * (current_index - start_index)

    return y

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        loss_dict = {}
        for model, optimizer in zip(model_list, optimizer_list):
            data = preprocess(batch)

            # Forward
            model.train()
            model.zero_grad()
            data = model(data, latent_temp=1)

            # Backward
            loss = 0
            for key in data.keys():
                if 'loss' in key:
                    loss = loss + data[key]
                    if key in loss_dict:
                        loss_dict[key].append(data[key].item())
                    else:
                        loss_dict[key] = [data[key].item()]
                    
            loss.backward()
            optimizer.step()
            
        for key in loss_dict:
            writer.add_scalar(key, np.mean(loss_dict[key]), step)
            print(key, np.mean(loss_dict[key]))
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            x = data['x']
            y = data['y']
            
            plot(x)
            plot(y)
            
            def get_entropy(zi):
                # (N, L)
                zi_onehot = F.one_hot(zi, num_classes=2 ** hp.n_latents)
                # (L)
                probs = zi_onehot.sum(dim=0) / len(zi_onehot)
                entropy = torch.sum(-probs * (torch.log(torch.clamp(probs, 1e-8)) - np.log(2)))
                return entropy

            entropy = get_entropy(data['zi']).item()
            writer.add_scalar('entropy', entropy, step)

            
        if step % 10000 == 0:
            save_model_list(save_dir, step, model_list, optimizer_list)
                
        step += 1
# Out:
# 1
# commit_loss 0.19065041840076447
# recon_loss 0.08189748227596283
# 2
# commit_loss 0.1701321303844452
# recon_loss 0.07939305901527405
# 3
# commit_loss 0.16165050864219666
# recon_loss 0.07702190428972244
# 4
# commit_loss 0.14554232358932495
# recon_loss 0.07756403833627701
# 5
# commit_loss 0.1369839906692505
# recon_loss 0.07481899857521057
# 6
# commit_loss 0.13501523435115814
# recon_loss 0.07195253670215607
# 7
# commit_loss 0.1206241026520729
# recon_loss 0.07045859098434448
# 8
# commit_loss 0.12901821732521057
# recon_loss 0.0742587000131607
# 9
# commit_loss 0.12027450650930405
# recon_loss 0.06959923356771469
# 10
# commit_loss 0.11315802484750748
# recon_loss 0.07097126543521881
# 11
# commit_loss 0.11645826697349548
# recon_loss 0.0751505047082901
# 12
# commit_loss 0.1103629618883133
# recon_loss 0.07349272072315216
# 13
# commit_loss 0.1086134985089302
# recon_loss 0.07281005382537842
# 14
# commit_loss 0.11137522011995316
# recon_loss 0.07494186609983444
# 15
# commit_loss 0.10301504284143448
# recon_loss 0.0684485137462616
# 16
# commit_loss 0.10294818878173828
# recon_loss 0.07189548015594482
# 17
# commit_loss 0.10345876961946487
# recon_loss 0.07483439892530441
# 18
# commit_loss 0.10082845389842987
# recon_loss 0.07075223326683044
# 19
# commit_loss 0.09722909331321716
# recon_loss 0.06944851577281952
# 20
# commit_loss 0.09474392235279083
# recon_loss 0.06645849347114563

# %%
save_model_list(save_dir, step, model_list, optimizer_list)
print('done')

# %%
data.keys()
