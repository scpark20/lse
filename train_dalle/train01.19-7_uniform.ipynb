# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# Wed Jan 24 11:25:55 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.223.02   Driver Version: 470.223.02   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100 80G...  Off  | 00000000:1B:00.0 Off |                    0 |
# | N/A   35C    P0    44W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100 80G...  Off  | 00000000:1C:00.0 Off |                    0 |
# | N/A   66C    P0   297W / 300W |  24081MiB / 80994MiB |    100%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100 80G...  Off  | 00000000:1D:00.0 Off |                    0 |
# | N/A   45C    P0    47W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100 80G...  Off  | 00000000:1E:00.0 Off |                    0 |
# | N/A   28C    P0    41W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100 80G...  Off  | 00000000:89:00.0 Off |                    0 |
# | N/A   40C    P0    43W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100 80G...  Off  | 00000000:8A:00.0 Off |                    0 |
# | N/A   43C    P0    43W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100 80G...  Off  | 00000000:8B:00.0 Off |                    0 |
# | N/A   43C    P0    44W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100 80G...  Off  | 00000000:8C:00.0 Off |                    0 |
# | N/A   44C    P0    45W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    1   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    1   N/A  N/A   1738762      C   ...a3/envs/scpark/bin/python    24043MiB |
# |    2   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    3   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    4   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    5   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    6   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    7   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_prior_latent_quantizer_dec import Model
from model.encoder.net_64_encoder import Encoder
from model.prior.dalle_rand_prior import Prior
from model.latent.dalle_lse_latent import Latent
from model.quantizer.dalle_nearest_quantizer import Quantizer
from model.decoder.net_64_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.img_size = 64
hp.n_resblocks = 6
hp.z_dim = 64
hp.n_prior_embeddings = 512
hp.init_log_sigma = 0
hp.const_sigma = True
hp.quantize = False
hp.prior_mu = 0.9999

# %%
step = 0
device = 'cuda:0'

model_list = []
optimizer_list = []
for i in range(1):
    model = Model(Encoder(**hp), Prior(**hp), Latent(**hp), Quantizer(**hp), Decoder(**hp))
    model = model.to(device)
    model_list.append(model)
    
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
    optimizer_list.append(optimizer)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))

print('done')
# Out:
# encoder 1.2191162109375
# encoder.encoder 1.2191162109375
# prior 0.126953125
# latent 3.814697265625e-06
# quantizer 0.0
# decoder 1.0611686706542969
# decoder.decoder 1.0611686706542969
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train_dalle/train01.19-7_uniform/'

# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if True:
    step, model_list, optimizer_list = load_model_list(save_dir, 440475, model_list, optimizer_list)
# Out:
# total 408620
# -rw-rw-r-- 1 scpark scpark        0  1월 24 11:25 events.out.tfevents.1706063159.GPUSVR11
# -rw-rw-r-- 1 scpark scpark       40  1월 24 11:24 events.out.tfevents.1706063054.GPUSVR11
# -rw-rw-r-- 1 scpark scpark 65581273  1월 24 11:24 events.out.tfevents.1705935502.GPUSVR11
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 11:24 save_440475
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 11:21 save_440000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 10:32 save_430000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 09:43 save_420000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 08:55 save_410000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 08:07 save_400000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 07:19 save_390000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 06:30 save_380000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 05:42 save_370000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 04:54 save_360000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 04:06 save_350000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 03:17 save_340000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 02:29 save_330000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 01:41 save_320000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 00:53 save_310000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 24 00:05 save_300000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 23:16 save_290000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 22:28 save_280000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 21:40 save_270000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 20:52 save_260000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 20:05 save_250000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 19:17 save_240000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 18:30 save_230000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 17:42 save_220000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 16:54 save_210000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 16:07 save_200000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 15:19 save_190000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 14:32 save_180000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 13:46 save_170000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 12:59 save_160000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 12:13 save_150000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 11:26 save_140000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 10:39 save_130000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 09:52 save_120000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 09:03 save_110000
# -rw-rw-r-- 1 scpark scpark  7478283  1월 23 08:14 save_100000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 07:25 save_90000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 06:36 save_80000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 05:46 save_70000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 04:57 save_60000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 04:08 save_50000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 03:19 save_40000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 02:30 save_30000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 01:40 save_20000
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 01:27 save_18159
# -rw-rw-r-- 1 scpark scpark  7477768  1월 23 00:47 save_10000
# -rw-rw-r-- 1 scpark scpark  7470716  1월 22 23:58 save_0
# -rw-rw-r-- 1 scpark scpark  1310146  1월 22 02:58 events.out.tfevents.1705859007.GPUSVR11

# %% [markdown]
# ### Dataset

# %%
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CelebA

class MyCelebA(CelebA):
    """
    A work-around to address issues with pytorch's celebA dataset class.
    
    Download and Extract
    URL : https://drive.google.com/file/d/1m8-EBPgi5MRubrm6iQjafK2QMHDBMSfJ/view?usp=sharing
    """
    
    def _check_integrity(self) -> bool:
        return True

root = '/data'
train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                       transforms.CenterCrop(148),
                                       transforms.Resize(hp.img_size),
                                       transforms.ToTensor(),])
train_dataset = MyCelebA(root, split='train', transform=train_transforms, download=False)
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
print('done')
# Out:
# done

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.permute(0, 2, 3, 1).data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(8):
        plt.subplot(1, 8, i+1)
        plt.imshow(_x[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()

# %%
def linear(start_value, end_value, current_index, start_index, end_index):
    if current_index > end_index:
        return end_value
    if current_index < start_index:
        return start_value

    grad = (end_value - start_value) / (end_index - start_index)
    y = start_value + grad * (current_index - start_index)

    return y

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        loss_dict = {}
        for model, optimizer in zip(model_list, optimizer_list):
            data = preprocess(batch)

            # Forward
            model.train()
            model.zero_grad()
            data = model(data, latent_temp=1)

            # Backward
            loss = 0
            for key in data.keys():
                if 'lse_loss' in key:
                    loss = loss + data[key]
                    if key in loss_dict:
                        loss_dict[key].append(data[key].item())
                    else:
                        loss_dict[key] = [data[key].item()]
                elif 'commit_loss' in key:
                    loss = loss + data[key] * 0
                    if key in loss_dict:
                        loss_dict[key].append(data[key].item())
                    else:
                        loss_dict[key] = [data[key].item()]        
                elif 'loss' in key:
                    loss = loss + data[key]
                    if key in loss_dict:
                        loss_dict[key].append(data[key].item())
                    else:
                        loss_dict[key] = [data[key].item()]
                    
            loss.backward()
            optimizer.step()
            
        for key in loss_dict:
            writer.add_scalar(key, np.mean(loss_dict[key]), step)
            print(key, np.mean(loss_dict[key]))
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            x = data['x']
            y = data['y']
            
            plot(x)
            plot(y)
                        
            grad = torch.softmax(data['matrix'], dim=0)
            grad = grad.data.cpu().numpy()

            import matplotlib.pyplot as plt

            for i in np.random.randint(0, grad.shape[1], size=[10]):
                plt.figure(figsize=[18, 1])
                plt.plot(grad[:, i])
                plt.grid()
                plt.show()
            
            from sklearn.decomposition import PCA
            pca = PCA(n_components=2)
            e = model.prior.prior.data.cpu().numpy()
            pca.fit(e)
            e_pca = pca.transform(e)
            z_pca = pca.transform(data['z'].permute(0, 2, 3, 1).reshape(-1, hp.z_dim).data.cpu().numpy())
            plt.figure(figsize=[10, 10])
            plt.scatter(e_pca[:, 0], e_pca[:, 1], marker='x', alpha=1.0, color='black')
            plt.scatter(z_pca[:, 0], z_pca[:, 1], marker='o', alpha=0.01, color='blue')
            plt.grid()
            plt.show() 
            
        if step % 10000 == 0:
            save_model_list(save_dir, step, model_list, optimizer_list)
                
        step += 1
# Out:
# 440475
# lse_loss -21.739513397216797
# commit_loss 0.00022956044995225966
# recon_loss 0.0009437100379727781
# 440476
# lse_loss -21.73986053466797
# commit_loss 0.00020679854787886143
# recon_loss 0.0009966011857613921
# 440477
# lse_loss -21.739459991455078
# commit_loss 0.00025089725386351347
# recon_loss 0.0009222132503055036
# 440478
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 39
#      36                 loss_dict[key] = [data[key].item()]
#      38     loss.backward()
# ---> 39     optimizer.step()
#      41 for key in loss_dict:
#      42     writer.add_scalar(key, np.mean(loss_dict[key]), step)
#
# File ~/anaconda3/envs/scpark/lib/python3.9/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~/anaconda3/envs/scpark/lib/python3.9/site-packages/torch/optim/optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File ~/anaconda3/envs/scpark/lib/python3.9/site-packages/torch/optim/adamw.py:171, in AdamW.step(self, closure)
#     158     beta1, beta2 = group["betas"]
#     160     self._init_group(
#     161         group,
#     162         params_with_grad,
#    (...)
#     168         state_steps,
#     169     )
# --> 171     adamw(
#     172         params_with_grad,
#     173         grads,
#     174         exp_avgs,
#     175         exp_avg_sqs,
#     176         max_exp_avg_sqs,
#     177         state_steps,
#     178         amsgrad=amsgrad,
#     179         beta1=beta1,
#     180         beta2=beta2,
#     181         lr=group["lr"],
#     182         weight_decay=group["weight_decay"],
#     183         eps=group["eps"],
#     184         maximize=group["maximize"],
#     185         foreach=group["foreach"],
#     186         capturable=group["capturable"],
#     187         differentiable=group["differentiable"],
#     188         fused=group["fused"],
#     189         grad_scale=getattr(self, "grad_scale", None),
#     190         found_inf=getattr(self, "found_inf", None),
#     191     )
#     193 return loss
#
# File ~/anaconda3/envs/scpark/lib/python3.9/site-packages/torch/optim/adamw.py:321, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     318 else:
#     319     func = _single_tensor_adamw
# --> 321 func(
#     322     params,
#     323     grads,
#     324     exp_avgs,
#     325     exp_avg_sqs,
#     326     max_exp_avg_sqs,
#     327     state_steps,
#     328     amsgrad=amsgrad,
#     329     beta1=beta1,
#     330     beta2=beta2,
#     331     lr=lr,
#     332     weight_decay=weight_decay,
#     333     eps=eps,
#     334     maximize=maximize,
#     335     capturable=capturable,
#     336     differentiable=differentiable,
#     337     grad_scale=grad_scale,
#     338     found_inf=found_inf,
#     339 )
#
# File ~/anaconda3/envs/scpark/lib/python3.9/site-packages/torch/optim/adamw.py:493, in _multi_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     490 device_params = [torch.view_as_real(x) if torch.is_complex(x) else x for x in device_params]
#     492 # update steps
# --> 493 torch._foreach_add_(device_state_steps, 1)
#     495 # Perform stepweight decay
#     496 torch._foreach_mul_(device_params, 1 - lr * weight_decay)
#
# KeyboardInterrupt:

# %%
save_model_list(save_dir, step, model_list, optimizer_list)
print('done')

# %%
import matplotlib.pyplot as plt
display.clear_output()

x = data['x']
y = data['y']

plot(x)
plot(y)

grad = torch.softmax(data['matrix'], dim=0)
grad = grad.data.cpu().numpy()

import matplotlib.pyplot as plt

for i in np.random.randint(0, grad.shape[1], size=[10]):
    plt.figure(figsize=[18, 1])
    plt.plot(grad[:, i])
    plt.grid()
    plt.show()

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
e = model.prior.prior.data.cpu().numpy()
pca.fit(e)
e_pca = pca.transform(e)
z_pca = pca.transform(data['z'].permute(0, 2, 3, 1).reshape(-1, hp.z_dim).data.cpu().numpy())
plt.figure(figsize=[10, 10])
plt.scatter(e_pca[:, 0], e_pca[:, 1], marker='x', alpha=1.0, color='black')
plt.scatter(z_pca[:, 0], z_pca[:, 1], marker='o', alpha=0.01, color='blue')
plt.grid()
plt.show()

# %%
from tqdm import tqdm

belongs = []
for i, batch in tqdm(enumerate(train_loader)):
    data = preprocess(batch)

    # Forward
    model.eval()
    data = model(data, latent_temp=1)
    belongs.append(data['belong'])

    if i > 100:
        break
# Out:
# 101it [00:24,  4.13it/s]

# %%
#belongs = torch.stack(belongs, dim=0)
print(belongs.shape)
# Out:
# torch.Size([102, 65536, 512])

# %%
(belongs.sum(dim=[0, 1]) > 0).sum()
# Out:
# tensor(110, device='cuda:0')
