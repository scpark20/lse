# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Thu Jan 25 01:48:50 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.223.02   Driver Version: 470.223.02   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100 80G...  Off  | 00000000:1B:00.0 Off |                    0 |
# | N/A   33C    P0    50W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100 80G...  Off  | 00000000:1C:00.0 Off |                    0 |
# | N/A   66C    P0   344W / 300W |  24081MiB / 80994MiB |     81%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100 80G...  Off  | 00000000:1D:00.0 Off |                    0 |
# | N/A   50C    P0    75W / 300W |  10347MiB / 80994MiB |     22%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100 80G...  Off  | 00000000:1E:00.0 Off |                    0 |
# | N/A   38C    P0    71W / 300W |  10347MiB / 80994MiB |     22%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100 80G...  Off  | 00000000:89:00.0 Off |                    0 |
# | N/A   41C    P0    49W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100 80G...  Off  | 00000000:8A:00.0 Off |                    0 |
# | N/A   32C    P0    43W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100 80G...  Off  | 00000000:8B:00.0 Off |                    0 |
# | N/A   42C    P0    44W / 300W |     35MiB / 80994MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100 80G...  Off  | 00000000:8C:00.0 Off |                    0 |
# | N/A   50C    P0   221W / 300W |   8299MiB / 80994MiB |     22%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    1   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    1   N/A  N/A   1738762      C   ...a3/envs/scpark/bin/python    24043MiB |
# |    2   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    2   N/A  N/A   1996033      C   ...a3/envs/scpark/bin/python    10309MiB |
# |    3   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    3   N/A  N/A   2027363      C   ...a3/envs/scpark/bin/python    10309MiB |
# |    4   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    5   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    6   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    7   N/A  N/A      2426      G   /usr/lib/xorg/Xorg                 35MiB |
# |    7   N/A  N/A   1986311      C   ...a3/envs/scpark/bin/python     8261MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_prior_latent_quantizer_dec import Model
from model.encoder.dalle_encoder import Encoder
from model.latent.vqvae_latent import Latent
from model.decoder.dalle_decoder import Decoder
from model.no_module import NoModule

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.img_size = 64
hp.n_resblocks = 6
hp.n_latents = 256
hp.z_dim = 512

# %%
step = 0
device = 'cuda:0'

model_list = []
optimizer_list = []
for i in range(1):
    model = Model(Encoder(**hp), NoModule(**hp), Latent(**hp), NoModule(**hp), Decoder(**hp))
    model = model.to(device)
    model_list.append(model)
    
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)
    optimizer_list.append(optimizer)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))

print('done')
# Out:
# encoder 18.6689453125
# encoder.encoder 18.6689453125
# prior 0.0
# latent 0.0
# latent.bottle 0.0
# quantizer 0.0
# decoder 9.954113006591797
# decoder.decoder 9.954113006591797
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train_dalle/train01.21-1_lr1e-3/'

# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, model_list, optimizer_list = load_model_list(save_dir, 100000, model_list, optimizer_list)
# Out:
# total 0

# %% [markdown]
# ### Dataset

# %%
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import CelebA

class MyCelebA(CelebA):
    """
    A work-around to address issues with pytorch's celebA dataset class.
    
    Download and Extract
    URL : https://drive.google.com/file/d/1m8-EBPgi5MRubrm6iQjafK2QMHDBMSfJ/view?usp=sharing
    """
    
    def _check_integrity(self) -> bool:
        return True

root = '/data'
train_transforms = transforms.Compose([transforms.RandomHorizontalFlip(),
                                       transforms.CenterCrop(148),
                                       transforms.Resize(hp.img_size),
                                       transforms.ToTensor(),])
train_dataset = MyCelebA(root, split='train', transform=train_transforms, download=False)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
print('done')
# Out:
# done

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.permute(0, 2, 3, 1).data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(8):
        plt.subplot(1, 8, i+1)
        plt.imshow(_x[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()

# %%
def linear(start_value, end_value, current_index, start_index, end_index):
    if current_index > end_index:
        return end_value
    if current_index < start_index:
        return start_value

    grad = (end_value - start_value) / (end_index - start_index)
    y = start_value + grad * (current_index - start_index)

    return y

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        loss_dict = {}
        for model, optimizer in zip(model_list, optimizer_list):
            data = preprocess(batch)

            # Forward
            model.train()
            model.zero_grad()
            data = model(data, latent_temp=1)

            # Backward
            loss = 0
            for key in data.keys():
                if 'loss' in key:
                    loss = loss + data[key]
                    if key in loss_dict:
                        loss_dict[key].append(data[key].item())
                    else:
                        loss_dict[key] = [data[key].item()]
                    
            loss.backward()
            optimizer.step()
            
        for key in loss_dict:
            writer.add_scalar(key, np.mean(loss_dict[key]), step)
            print(key, np.mean(loss_dict[key]))
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            x = data['x']
            y = data['y']
            
            plot(x)
            plot(y)
            
            def get_entropy(zi):
                # (N, L)
                zi_onehot = F.one_hot(zi, num_classes=hp.n_latents)
                # (L)
                probs = zi_onehot.sum(dim=0) / len(zi_onehot)
                entropy = torch.sum(-probs * (torch.log(torch.clamp(probs, 1e-8)) - np.log(2)))
                return entropy

            entropy = get_entropy(data['zi']).item()
            writer.add_scalar('entropy', entropy, step)
            
        if step % 10000 == 0:
            save_model_list(save_dir, step, model_list, optimizer_list)
                
        step += 1
# Out:
# 1
# commit_loss 0.048873238265514374
# recon_loss 0.09293242543935776
# 2
# commit_loss 0.01510566659271717
# recon_loss 0.0802702009677887
# 3
# commit_loss 0.01394714880734682
# recon_loss 0.07243600487709045
# 4
# commit_loss 0.010296037420630455
# recon_loss 0.06638951599597931
# 5
# commit_loss 0.009929505176842213
# recon_loss 0.05595868080854416
# 6
# commit_loss 0.010464143007993698
# recon_loss 0.04979943856596947
# 7
# commit_loss 0.008607827126979828
# recon_loss 0.04052778333425522
# 8
# commit_loss 0.009599657729268074
# recon_loss 0.05001972243189812
# 9
# commit_loss 0.007201403379440308
# recon_loss 0.04059648513793945
# 10
# commit_loss 0.007371224462985992
# recon_loss 0.048305392265319824
# 11
# commit_loss 0.006285439245402813
# recon_loss 0.03717225044965744
# 12
# commit_loss 0.006321975030004978
# recon_loss 0.04090309888124466
# 13
# commit_loss 0.006520275957882404
# recon_loss 0.04116179421544075
# 14
# commit_loss 0.006341304164379835
# recon_loss 0.02949470840394497
# 15
# commit_loss 0.005475799553096294
# recon_loss 0.030989229679107666
# 16
# commit_loss 0.005691200029104948
# recon_loss 0.04532438516616821
# 17
# commit_loss 0.005002837162464857
# recon_loss 0.031069323420524597
# 18
# commit_loss 0.005829537287354469
# recon_loss 0.024182777851819992
# 19
# commit_loss 0.00566929392516613
# recon_loss 0.031715333461761475
# 20
# commit_loss 0.005973971448838711
# recon_loss 0.03049567900598049
# 21
# commit_loss 0.00531804608181119
# recon_loss 0.021609388291835785
# 22
# commit_loss 0.005551568232476711
# recon_loss 0.024801377207040787
# 23
# commit_loss 0.005344031378626823
# recon_loss 0.029414042830467224
# 24
# commit_loss 0.004765667021274567
# recon_loss 0.02140536904335022
# 25
# commit_loss 0.004659057594835758
# recon_loss 0.022192751988768578
# 26
# commit_loss 0.004107074346393347
# recon_loss 0.023059245198965073
# 27
# commit_loss 0.004471158608794212
# recon_loss 0.021453408524394035
# 28
# commit_loss 0.0040443819016218185
# recon_loss 0.020966632291674614
# 29
# commit_loss 0.004964823834598064
# recon_loss 0.01705041527748108
# 30
# commit_loss 0.003847918240353465
# recon_loss 0.01638898067176342
# 31
# commit_loss 0.0042712390422821045
# recon_loss 0.01957673579454422
# 32
# commit_loss 0.003600166644901037
# recon_loss 0.016647949814796448
# 33
# commit_loss 0.0035823225043714046
# recon_loss 0.0165381021797657
# 34
# commit_loss 0.003753512864932418
# recon_loss 0.017159968614578247
# 35
# commit_loss 0.0035740199964493513
# recon_loss 0.018821626901626587
# 36
# commit_loss 0.0028517083264887333
# recon_loss 0.01610622927546501
# 37
# commit_loss 0.0031576312612742186
# recon_loss 0.01754818856716156
# 38
# commit_loss 0.0029985811561346054
# recon_loss 0.016530239954590797
# 39
# commit_loss 0.0029136096127331257
# recon_loss 0.015841247513890266
# 40
# commit_loss 0.002723769983276725
# recon_loss 0.014185241423547268
# 41
# commit_loss 0.0029233270324766636
# recon_loss 0.014221797697246075
# 42
# commit_loss 0.0028611603192985058
# recon_loss 0.01376374065876007
# 43
# commit_loss 0.0027023665606975555
# recon_loss 0.014240359887480736
# 44
# commit_loss 0.0027450560592114925
# recon_loss 0.013147538527846336
# 45
# commit_loss 0.0032026092521846294
# recon_loss 0.014719732105731964
# 46
# commit_loss 0.00265599531121552
# recon_loss 0.012815548107028008
# 47
# commit_loss 0.0023526009172201157
# recon_loss 0.011481620371341705
# 48
# commit_loss 0.002293915953487158
# recon_loss 0.011357398703694344
# 49
# commit_loss 0.0023678913712501526
# recon_loss 0.012228216044604778
# 50
# commit_loss 0.0026592309586703777
# recon_loss 0.01268239226192236
# 51
# commit_loss 0.0025945210363715887
# recon_loss 0.01215001754462719
# 52
# commit_loss 0.0022250358015298843
# recon_loss 0.01103672944009304
# 53
# commit_loss 0.002175536472350359
# recon_loss 0.010778333060443401
# 54
# commit_loss 0.0022014807909727097
# recon_loss 0.01123204454779625
# 55
# commit_loss 0.0022666295990347862
# recon_loss 0.011068260297179222
# 56
# commit_loss 0.0021950716618448496
# recon_loss 0.010523490607738495
# 57
# commit_loss 0.0020342771895229816
# recon_loss 0.009674369357526302
# 58
# commit_loss 0.002212809631600976
# recon_loss 0.010211028158664703
# 59
# commit_loss 0.0023112096823751926
# recon_loss 0.01074129343032837
# 60
# commit_loss 0.002456868998706341
# recon_loss 0.01123616099357605
# 61
# commit_loss 0.0020617139525711536
# recon_loss 0.0100218141451478
# 62
# commit_loss 0.0020685424096882343
# recon_loss 0.010103046894073486
# 63
# commit_loss 0.0022346782498061657
# recon_loss 0.010521076619625092
# 64
# commit_loss 0.0024032099172472954
# recon_loss 0.011001559905707836
# 65
# commit_loss 0.002139850053936243
# recon_loss 0.009803487919270992
# 66
# commit_loss 0.001977144042029977
# recon_loss 0.0101162139326334

# %%
save_model_list(save_dir, step, model_list, optimizer_list)
print('done')
