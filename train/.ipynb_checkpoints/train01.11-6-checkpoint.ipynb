# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="6"
# Out:
# Sat Jan 13 21:39:37 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   27C    P8    14W / 230W |  17558MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   30C    P8    14W / 230W |    402MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   37C    P2    95W / 230W |   4166MiB / 24564MiB |     29%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   34C    P2    92W / 230W |   4166MiB / 24564MiB |     29%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   35C    P2    96W / 230W |   4166MiB / 24564MiB |     29%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   33C    P2    92W / 230W |   4166MiB / 24564MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   28C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   27C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2106188      C   ...onda3/envs/ste/bin/python    17550MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2307797      C   ...onda3/envs/ste/bin/python      394MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   2322792      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   2322811      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2322890      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   2323029      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.uniform_lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.004646301269531
# encoder.convs 5.989013671875
# encoder.linear 0.01563262939453125
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.11-6/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 573716
# -rw-rw-r-- 1 scpark scpark 11571388  1월 12 21:20 events.out.tfevents.1705056411.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37979957  1월 12 21:13 save_110000
# -rw-rw-r-- 1 scpark scpark 37979957  1월 12 21:05 save_100000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 20:57 save_90000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 20:50 save_80000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 20:42 save_70000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 20:34 save_60000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 20:26 save_50000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 20:18 save_40000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 20:10 save_30000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 20:02 save_20000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 19:54 save_10000
# -rw-rw-r-- 1 scpark scpark 37973949  1월 12 19:46 save_0
# -rw-rw-r-- 1 scpark scpark  4936886  1월 12 19:46 events.out.tfevents.1705053989.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 13619882  1월 12 19:06 events.out.tfevents.1705046990.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37979957  1월 12 18:58 save_130000
# -rw-rw-r-- 1 scpark scpark 37979957  1월 12 18:50 save_120000
# -rw-rw-r-- 1 scpark scpark  2866146  1월 12 17:09 events.out.tfevents.1705045550.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   938564  1월 12 16:45 events.out.tfevents.1705045068.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   526724  1월 12 16:37 events.out.tfevents.1705044796.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  9704488  1월 12 16:33 events.out.tfevents.1705039950.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1694066  1월 12 15:12 events.out.tfevents.1705039073.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1538852  1월 12 14:57 events.out.tfevents.1705038291.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  2065388  1월 12 00:52 events.out.tfevents.1704987264.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   765092  1월 12 00:09 events.out.tfevents.1704985403.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   661988  1월 12 00:03 events.out.tfevents.1704985057.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   352388  1월 11 23:57 events.out.tfevents.1704984873.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   379556  1월 11 23:54 events.out.tfevents.1704984673.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1108004  1월 11 22:02 events.out.tfevents.1704977562.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   910724  1월 11 21:52 events.out.tfevents.1704977066.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  2024816  1월 11 21:44 events.out.tfevents.1704976027.GPUSVR01

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=1000, sigma=0.149)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000, sigma=1e-1)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'), alpha=0.2)
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 39001
# lse_loss -1.3579087257385254
# recon_loss 0.129189595580101
# 39002
# lse_loss -1.3530417680740356
# recon_loss 0.12307935208082199
# 39003
# lse_loss -1.3777679204940796
# recon_loss 0.1232726201415062
# 39004
# lse_loss -1.3577022552490234
# recon_loss 0.13893383741378784
# 39005
# lse_loss -1.3704452514648438
# recon_loss 0.12230110168457031
# 39006
# lse_loss -1.3709676265716553
# recon_loss 0.12838473916053772
# 39007
# lse_loss -1.368342638015747
# recon_loss 0.1259317249059677
# 39008
# lse_loss -1.3551536798477173
# recon_loss 0.12393142282962799
# 39009
# lse_loss -1.3812124729156494
# recon_loss 0.12120717763900757
# 39010
# lse_loss -1.3309162855148315
# recon_loss 0.12732252478599548
# 39011
# lse_loss -1.3490204811096191
# recon_loss 0.13932403922080994
# 39012
# lse_loss -1.3524093627929688
# recon_loss 0.11856275051832199
# 39013
# lse_loss -1.3273708820343018
# recon_loss 0.13249924778938293
# 39014
# lse_loss -1.3411448001861572
# recon_loss 0.10908740758895874
# 39015
# lse_loss -1.36701500415802
# recon_loss 0.11706864088773727
# 39016
# lse_loss -1.3723649978637695
# recon_loss 0.12969575822353363
# 39017
# lse_loss -1.3793460130691528
# recon_loss 0.12349039316177368
# 39018
# lse_loss -1.3624162673950195
# recon_loss 0.11480092257261276
# 39019
# lse_loss -1.3326609134674072
# recon_loss 0.12524458765983582
# 39020
# lse_loss -1.3807148933410645
# recon_loss 0.11859437823295593
# 39021
# lse_loss -1.340501308441162
# recon_loss 0.12076766788959503
# 39022
# lse_loss -1.3511426448822021
# recon_loss 0.11643128097057343
# 39023
# lse_loss -1.3706098794937134
# recon_loss 0.11837470531463623
# 39024
# lse_loss -1.374948501586914
# recon_loss 0.12261426448822021
# 39025
# lse_loss -1.3514846563339233
# recon_loss 0.13053080439567566
# 39026
# lse_loss -1.3889131546020508
# recon_loss 0.11122491210699081
# 39027
# lse_loss -1.3386462926864624
# recon_loss 0.13290363550186157
# 39028
# lse_loss -1.3479766845703125
# recon_loss 0.13367393612861633
# 39029
# lse_loss -1.389338493347168
# recon_loss 0.1283079981803894
# 39030
# lse_loss -1.3257246017456055
# recon_loss 0.12436378002166748

# %%
import matplotlib.pyplot as plt
display.clear_output()

batch = next(iter(test_loader))
data = preprocess(batch)

model.eval()
with torch.no_grad():
    data = model(data, M=1000, sigma=1e-1)

plot(data['x'])
plot(data['y'])

with torch.no_grad():
    z = torch.randn(10, hp.z_dim).to(device)
    y = model.sample(z)
    plot(y)

import matplotlib.pyplot as plt
_z = data['z'].data.cpu().numpy()
plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'), alpha=0.2)
plt.grid()
plt.colorbar()
plt.show()
