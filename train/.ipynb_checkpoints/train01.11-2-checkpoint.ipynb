# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# Fri Jan 12 00:02:45 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   24C    P8    14W / 230W |      8MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   25C    P8    14W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   57C    P2   126W / 230W |   4186MiB / 24564MiB |     24%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   57C    P2   182W / 230W |   8362MiB / 24564MiB |     53%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 33%   62C    P2   200W / 230W |   8362MiB / 24564MiB |     51%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   58C    P2   170W / 230W |   8086MiB / 24564MiB |     49%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   24C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   24C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   1941038      C   ...onda3/envs/ste/bin/python     4178MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   1941110      C   ...onda3/envs/ste/bin/python     4178MiB |
# |    3   N/A  N/A   1942496      C   ...onda3/envs/ste/bin/python     4176MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   1941133      C   ...onda3/envs/ste/bin/python     4178MiB |
# |    4   N/A  N/A   1942305      C   ...onda3/envs/ste/bin/python     4176MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   1941283      C   ...onda3/envs/ste/bin/python     3902MiB |
# |    5   N/A  N/A   1942411      C   ...onda3/envs/ste/bin/python     4176MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.004646301269531
# encoder.convs 5.989013671875
# encoder.linear 0.01563262939453125
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.11-2/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 344572
# -rw-rw-r-- 1 scpark scpark   907076  1월 12 00:02 events.out.tfevents.1704984907.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37973949  1월 11 23:55 save_0
# -rw-rw-r-- 1 scpark scpark   357284  1월 11 23:55 events.out.tfevents.1704984718.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1077860  1월 11 22:02 events.out.tfevents.1704977575.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37979741  1월 11 22:01 save_10000
# -rw-rw-r-- 1 scpark scpark   906116  1월 11 21:52 events.out.tfevents.1704977086.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  5431982  1월 11 21:44 events.out.tfevents.1704974487.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 66192541  1월 11 21:39 save_50000
# -rw-rw-r-- 1 scpark scpark 66192541  1월 11 21:31 save_40000
# -rw-rw-r-- 1 scpark scpark 66192541  1월 11 21:24 save_30000
# -rw-rw-r-- 1 scpark scpark 66192541  1월 11 21:16 save_20000
# -rw-rw-r-- 1 scpark scpark   463076  1월 11 21:01 events.out.tfevents.1704974252.GPUSVR01
# -rw-rw-r-- 1 scpark scpark       40  1월 11 20:57 events.out.tfevents.1704974218.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1005860  1월 11 20:56 events.out.tfevents.1704973737.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1886146  1월 11 20:48 events.out.tfevents.1704972838.GPUSVR01
# -rw-rw-r-- 1 scpark scpark     7995  1월 11 20:33 events.out.tfevents.1704972821.GPUSVR01
# -rw-rw-r-- 1 scpark scpark    14895  1월 11 20:33 events.out.tfevents.1704972732.GPUSVR01
# -rw-rw-r-- 1 scpark scpark       86  1월 11 20:32 events.out.tfevents.1704972689.GPUSVR01
# -rw-rw-r-- 1 scpark scpark       86  1월 11 20:31 events.out.tfevents.1704972630.GPUSVR01
# -rw-rw-r-- 1 scpark scpark       40  1월 11 20:30 events.out.tfevents.1704972584.GPUSVR01

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=10000, sigma=1e-1)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000, sigma=1e-1)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 11001
# lse_loss 27857.666015625
# recon_loss 0.2076500654220581
# 11002
# lse_loss 27704.248046875
# recon_loss 0.19352445006370544
# 11003
# lse_loss 32873.65625
# recon_loss 0.20348577201366425
# 11004
# lse_loss 29550.021484375
# recon_loss 0.19286638498306274
# 11005
# lse_loss 29852.1015625
# recon_loss 0.19435398280620575
# 11006
# lse_loss 28781.439453125
# recon_loss 0.19395755231380463
# 11007
# lse_loss 26955.669921875
# recon_loss 0.2076665163040161
# KeyboardInterrupt
