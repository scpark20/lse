# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="5"
# Out:
# Fri Jan 12 17:08:11 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   24C    P8    14W / 230W |      8MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   40C    P2    90W / 230W |   4168MiB / 24564MiB |     26%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 34%   61C    P2   198W / 230W |  12208MiB / 24564MiB |     73%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 34%   60C    P2   179W / 230W |  12484MiB / 24564MiB |     74%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 32%   57C    P2   119W / 230W |   4506MiB / 24564MiB |     29%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   57C    P2   136W / 230W |   4168MiB / 24564MiB |     23%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   41C    P2    96W / 230W |   4168MiB / 24564MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   41C    P2    96W / 230W |   4168MiB / 24564MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2084161      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   2082643      C   ...onda3/envs/ste/bin/python     3882MiB |
# |    2   N/A  N/A   2083533      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    2   N/A  N/A   2088138      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   2083613      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    3   N/A  N/A   2084020      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    3   N/A  N/A   2088160      C   ...onda3/envs/ste/bin/python     4156MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2083749      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    4   N/A  N/A   2088232      C   ...onda3/envs/ste/bin/python      338MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   2083832      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A   2083911      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A   2083988      C   ...onda3/envs/ste/bin/python     4160MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_vae_encoder import Encoder
from model.latent_layer.sampling_uniform_lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.0202789306640625
# encoder.convs 5.989013671875
# encoder.linear 0.0312652587890625
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.12-5/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 38144
# -rw-rw-r-- 1 scpark scpark   488132  1월 12 17:08 events.out.tfevents.1705046628.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 38024305  1월 12 17:03 save_0
# -rw-rw-r-- 1 scpark scpark   434468  1월 12 17:03 events.out.tfevents.1705046390.GPUSVR01
# -rw-rw-r-- 1 scpark scpark    98468  1월 12 16:59 events.out.tfevents.1705046317.GPUSVR01

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=1000, sigma=8e-2)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000, sigma=1e-2)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z_mean'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 7001
# lse_loss 599021.75
# recon_loss 0.18811027705669403
# 7002
# lse_loss 606696.0625
# recon_loss 0.18685907125473022
# 7003
# lse_loss 551841.8125
# recon_loss 0.1973428726196289
# 7004
# lse_loss 575270.5
# recon_loss 0.19676820933818817
# 7005
# lse_loss 524762.3125
# recon_loss 0.19139674305915833
# 7006
# lse_loss 621020.875
# recon_loss 0.20260873436927795
# 7007
# lse_loss 658862.875
# recon_loss 0.19354967772960663
# 7008
# lse_loss 576188.0625
# recon_loss 0.19067303836345673
# 7009
# lse_loss 639653.75
# recon_loss 0.19472765922546387
# 7010
# lse_loss 577144.9375
# recon_loss 0.19733265042304993
# 7011
# lse_loss 533575.3125
# recon_loss 0.19752070307731628
# 7012
# lse_loss 637520.625
# recon_loss 0.20397399365901947
# 7013
# lse_loss 554648.875
# recon_loss 0.1952664852142334
# 7014
# lse_loss 575535.75
# recon_loss 0.18899337947368622
# 7015
# lse_loss 672576.1875
# recon_loss 0.19114618003368378
# 7016
# lse_loss 528472.0625
# recon_loss 0.1901257485151291
# 7017
# lse_loss 549889.3125
# recon_loss 0.1873132437467575
# 7018
# lse_loss 642055.25
# recon_loss 0.19130699336528778
# 7019
# lse_loss 539174.0625
# recon_loss 0.19676688313484192
# 7020
# lse_loss 515875.28125
# recon_loss 0.19942903518676758
# 7021
# lse_loss 622359.1875
# recon_loss 0.19082006812095642
# 7022
# lse_loss 584667.5
# recon_loss 0.18019376695156097
# 7023
# lse_loss 611235.125
# recon_loss 0.17838320136070251
# 7024
# lse_loss 608073.25
# recon_loss 0.18879550695419312
# 7025
# lse_loss 595762.1875
# recon_loss 0.18597190082073212
# 7026
# lse_loss 556177.8125
# recon_loss 0.18993864953517914
# 7027
# lse_loss 544127.9375
# recon_loss 0.18900156021118164
# 7028
# lse_loss 552819.8125
# recon_loss 0.193747878074646
# 7029
# lse_loss 543232.6875
# recon_loss 0.18065695464611053
# 7030
# lse_loss 580504.875
# recon_loss 0.18310940265655518
# 7031
# lse_loss 544568.625
# recon_loss 0.1872536838054657
# 7032
# lse_loss 636092.125
# recon_loss 0.18367469310760498
# 7033
# lse_loss 625369.875
# recon_loss 0.18685667216777802
# 7034
# lse_loss 798428.5
# recon_loss 0.17965446412563324
# 7035
# lse_loss 515447.96875
# recon_loss 0.1973947286605835
# 7036
# lse_loss 553407.125
# recon_loss 0.18209296464920044
# 7037
# lse_loss 566506.25
# recon_loss 0.18076691031455994
# 7038
# lse_loss 673219.125
# recon_loss 0.18915800750255585
# 7039
# lse_loss 607730.9375
# recon_loss 0.19341561198234558
# 7040
# lse_loss 603869.6875
# recon_loss 0.19074778258800507
# 7041
# lse_loss 524739.1875
# recon_loss 0.19404953718185425
# 7042
# lse_loss 506401.3125
# recon_loss 0.20165680348873138
# 7043
# lse_loss 545188.4375
# recon_loss 0.18291595578193665
# 7044
# lse_loss 533120.25
# recon_loss 0.18082743883132935
# 7045
# lse_loss 558708.25
# recon_loss 0.18626950681209564
# 7046
# lse_loss 546071.1875
# recon_loss 0.18450510501861572
# 7047
# lse_loss 536845.3125
# recon_loss 0.182411789894104
# 7048
# lse_loss 557333.6875
# recon_loss 0.19553685188293457
# 7049
# lse_loss 559935.25
# recon_loss 0.18383201956748962
# 7050
# lse_loss 529127.0625
# recon_loss 0.17939281463623047
# 7051
# lse_loss 567443.875
# recon_loss 0.18281611800193787
# 7052
# lse_loss 560125.3125
# recon_loss 0.18991629779338837
# 7053
# lse_loss 580772.875
# recon_loss 0.1905519813299179
# 7054
# lse_loss 526291.75
# recon_loss 0.19364695250988007
# 7055
# lse_loss 567843.75
# recon_loss 0.1824307143688202
# 7056
# lse_loss 521213.0
# recon_loss 0.19897684454917908
# 7057
# lse_loss 505826.5625
# recon_loss 0.18675456941127777
# 7058
# lse_loss 526631.625
# recon_loss 0.18529336154460907
# 7059
# lse_loss 524021.84375
# recon_loss 0.1915222406387329
# 7060
# lse_loss 569169.5625
# recon_loss 0.19358688592910767
# 7061
# lse_loss 590011.1875
# recon_loss 0.19914530217647552
# 7062
# lse_loss 556417.1875
# recon_loss 0.18769919872283936
# 7063
# lse_loss 497271.625
# recon_loss 0.18301042914390564
# 7064
# lse_loss 548405.375
# recon_loss 0.19985489547252655
# 7065
# lse_loss 533838.125
# recon_loss 0.19428303837776184
# 7066
# lse_loss 565164.1875
# recon_loss 0.18771599233150482
# 7067
# lse_loss 565255.8125
# recon_loss 0.18879616260528564
# 7068
# lse_loss 588737.1875
# recon_loss 0.1847042441368103
# 7069
# lse_loss 586528.0
# recon_loss 0.17536596953868866
# 7070
# lse_loss 535173.125
# recon_loss 0.19429753720760345
# 7071
# lse_loss 521520.71875
# recon_loss 0.18517380952835083
# 7072
# lse_loss 585316.125
# recon_loss 0.19346725940704346
# 7073
# lse_loss 533517.0625
# recon_loss 0.18380701541900635
# 7074
# lse_loss 593394.6875
# recon_loss 0.19277247786521912
# 7075
# lse_loss 482441.6875
# recon_loss 0.18939194083213806
# 7076
# lse_loss 534671.8125
# recon_loss 0.20633506774902344
# 7077
# lse_loss 582416.875
# recon_loss 0.1844385266304016
# 7078
# lse_loss 548665.25
# recon_loss 0.1962006390094757
# 7079
# lse_loss 553101.9375
# recon_loss 0.18717670440673828
# 7080
# lse_loss 559511.0
# recon_loss 0.18213579058647156
# 7081
# lse_loss 596495.375
# recon_loss 0.19297334551811218
# 7082
# lse_loss 471698.0
# recon_loss 0.18553271889686584
# 7083
# lse_loss 527381.3125
# recon_loss 0.1952599287033081
# 7084
# lse_loss 607138.75
# recon_loss 0.19439774751663208
# 7085
# lse_loss 661286.9375
# recon_loss 0.184430330991745
# 7086
# lse_loss 526397.9375
# recon_loss 0.1962464451789856
# 7087
# lse_loss 612115.75
# recon_loss 0.18972763419151306
# 7088
# lse_loss 556037.4375
# recon_loss 0.19116590917110443
# 7089
# lse_loss 492095.0
# recon_loss 0.19110804796218872
# 7090
# lse_loss 573453.75
# recon_loss 0.18376338481903076
# 7091
# lse_loss 506575.96875
# recon_loss 0.18469667434692383
# 7092
# lse_loss 573955.6875
# recon_loss 0.19618692994117737
# 7093
# lse_loss 604407.875
# recon_loss 0.18360142409801483
# 7094
# lse_loss 481592.125
# recon_loss 0.19700837135314941
# 7095
# lse_loss 485256.46875
# recon_loss 0.2025066614151001
# 7096
# lse_loss 483686.5
# recon_loss 0.19498561322689056
# 7097
# lse_loss 548673.125
# recon_loss 0.18998095393180847
# 7098
# lse_loss 536924.5
# recon_loss 0.19649574160575867
# 7099
# lse_loss 597247.25
# recon_loss 0.18871299922466278
# 7100
# lse_loss 512450.0625
# recon_loss 0.19865211844444275
# 7101
# lse_loss 582756.5
# recon_loss 0.1996304988861084
