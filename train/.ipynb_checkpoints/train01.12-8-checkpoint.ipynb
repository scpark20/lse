# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Fri Jan 12 17:15:24 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   23C    P8    14W / 230W |      8MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   40C    P2    88W / 230W |   4168MiB / 24564MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 33%   62C    P2   197W / 230W |  12210MiB / 24564MiB |     79%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 33%   63C    P2   212W / 230W |  12488MiB / 24564MiB |     78%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 32%   60C    P2   185W / 230W |   8328MiB / 24564MiB |     46%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   58C    P2   176W / 230W |   8328MiB / 24564MiB |     51%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   50C    P2   170W / 230W |   8326MiB / 24564MiB |     50%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   46C    P2   169W / 230W |   8326MiB / 24564MiB |     50%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2089195      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   2082643      C   ...onda3/envs/ste/bin/python     3882MiB |
# |    2   N/A  N/A   2088594      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    2   N/A  N/A   2089910      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   2088668      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    3   N/A  N/A   2089123      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    3   N/A  N/A   2089996      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2088774      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    4   N/A  N/A   2090085      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   2088860      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    5   N/A  N/A   2090169      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A   2088936      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    6   N/A  N/A   2090274      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A   2089024      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    7   N/A  N/A   2090288      C   ...onda3/envs/ste/bin/python     4158MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_vae_encoder import Encoder
from model.latent_layer.sampling_uniform_lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.0202789306640625
# encoder.convs 5.989013671875
# encoder.linear 0.0312652587890625
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.12-8/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 0

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=1000, sigma=4e-1)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000, sigma=1e-2)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z_mean'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 1001
# lse_loss -3.201831102371216
# recon_loss 0.20606404542922974
# 1002
# lse_loss -3.1849074363708496
# recon_loss 0.2154475897550583
# 1003
# lse_loss -3.2296667098999023
# recon_loss 0.20828817784786224
# 1004
# lse_loss -3.2084271907806396
# recon_loss 0.20423874258995056
# 1005
# lse_loss -3.231370687484741
# recon_loss 0.2061437964439392
# 1006
# lse_loss -3.226346254348755
# recon_loss 0.20734421908855438
# 1007
# lse_loss -3.213402509689331
# recon_loss 0.2125130593776703
# 1008
# lse_loss -3.195652961730957
# recon_loss 0.20722532272338867
# 1009
# lse_loss -3.203248977661133
# recon_loss 0.21674597263336182
# 1010
# lse_loss -3.233945369720459
# recon_loss 0.2081317901611328
# 1011
# lse_loss -3.2008848190307617
# recon_loss 0.21003639698028564
# 1012
# lse_loss -3.2197835445404053
# recon_loss 0.21161869168281555
# 1013
# lse_loss -3.21685791015625
# recon_loss 0.21158024668693542
# 1014
# lse_loss -3.2219533920288086
# recon_loss 0.21217063069343567
# 1015
# lse_loss -3.2088727951049805
# recon_loss 0.20607084035873413
# 1016
# lse_loss -3.218871831893921
# recon_loss 0.20132288336753845
# 1017
# lse_loss -3.2096216678619385
# recon_loss 0.20961472392082214
# 1018
# lse_loss -3.2070963382720947
# recon_loss 0.21373412013053894
# 1019
# lse_loss -3.212496042251587
# recon_loss 0.2069900929927826
# 1020
# lse_loss -3.2240729331970215
# recon_loss 0.20958110690116882
# 1021
# lse_loss -3.2045485973358154
# recon_loss 0.20605222880840302
# 1022
# lse_loss -3.202843427658081
# recon_loss 0.20191721618175507
# 1023
# lse_loss -3.214674234390259
# recon_loss 0.21557196974754333
# 1024
# lse_loss -3.2163689136505127
# recon_loss 0.20573851466178894
# 1025
# lse_loss -3.204267740249634
# recon_loss 0.20399752259254456
# 1026
# lse_loss -3.200104236602783
# recon_loss 0.21050797402858734
# 1027
# lse_loss -3.2307636737823486
# recon_loss 0.2156994640827179
# 1028
# lse_loss -3.209066152572632
# recon_loss 0.20790252089500427
# 1029
# lse_loss -3.2195169925689697
# recon_loss 0.20503559708595276
# 1030
# lse_loss -3.2227540016174316
# recon_loss 0.22277355194091797
# 1031
# lse_loss -3.2177653312683105
# recon_loss 0.22261345386505127
# 1032
# lse_loss -3.2227864265441895
# recon_loss 0.211492657661438
# 1033
# lse_loss -3.2178196907043457
# recon_loss 0.21743278205394745
# 1034
# lse_loss -3.212463617324829
# recon_loss 0.20443609356880188
# 1035
# lse_loss -3.2221407890319824
# recon_loss 0.21872559189796448
# 1036
# lse_loss -3.242011070251465
# recon_loss 0.20126812160015106
# 1037
# lse_loss -3.214639186859131
# recon_loss 0.22278384864330292
# 1038
# lse_loss -3.2224113941192627
# recon_loss 0.20816169679164886
# 1039
# lse_loss -3.225069522857666
# recon_loss 0.2099483460187912
# 1040
# lse_loss -3.1940929889678955
# recon_loss 0.20176467299461365
# 1041
# lse_loss -3.2119925022125244
# recon_loss 0.20091870427131653
# 1042
# lse_loss -3.206348180770874
# recon_loss 0.21415027976036072
# 1043
# lse_loss -3.209995746612549
# recon_loss 0.19868230819702148
# 1044
# lse_loss -3.2273192405700684
# recon_loss 0.213578462600708
# 1045
# lse_loss -3.197983980178833
# recon_loss 0.19794997572898865
# 1046
# lse_loss -3.189260959625244
# recon_loss 0.20851826667785645
# 1047
# lse_loss -3.213214635848999
# recon_loss 0.21386167407035828
# 1048
# lse_loss -3.2090396881103516
# recon_loss 0.21337687969207764
# 1049
# lse_loss -3.225628614425659
# recon_loss 0.2125210165977478
# 1050
# lse_loss -3.209717273712158
# recon_loss 0.2179764211177826
# 1051
# lse_loss -3.1868577003479004
# recon_loss 0.21408748626708984
# 1052
# lse_loss -3.1916403770446777
# recon_loss 0.21947801113128662
# 1053
# lse_loss -3.224698305130005
# recon_loss 0.20129720866680145
# 1054
# lse_loss -3.22115421295166
# recon_loss 0.20573315024375916
# 1055
# lse_loss -3.180152416229248
# recon_loss 0.2161211222410202
# 1056
# lse_loss -3.1778478622436523
# recon_loss 0.19435441493988037
# 1057
# lse_loss -3.211665391921997
# recon_loss 0.21129529178142548
# 1058
# lse_loss -3.200371742248535
# recon_loss 0.20366212725639343
# 1059
# lse_loss -3.213702440261841
# recon_loss 0.22463077306747437
# 1060
# lse_loss -3.236269474029541
# recon_loss 0.20870935916900635
# 1061
# lse_loss -3.209287643432617
# recon_loss 0.20319914817810059
# 1062
# lse_loss -3.204258441925049
# recon_loss 0.20085260272026062
# 1063
# lse_loss -3.21669602394104
# recon_loss 0.20571915805339813
# 1064
# lse_loss -3.2078115940093994
# recon_loss 0.20955972373485565
# 1065
# lse_loss -3.2232956886291504
# recon_loss 0.21005980670452118
# 1066
# lse_loss -3.2029714584350586
# recon_loss 0.21603843569755554
# 1067
# lse_loss -3.2102553844451904
# recon_loss 0.20692037045955658
# 1068
# lse_loss -3.231285810470581
# recon_loss 0.20863273739814758
# 1069
# lse_loss -3.2135207653045654
# recon_loss 0.22116468846797943
# 1070
# lse_loss -3.2025647163391113
# recon_loss 0.20476490259170532
# 1071
# lse_loss -3.2203521728515625
# recon_loss 0.20717990398406982
# 1072
# lse_loss -3.2172627449035645
# recon_loss 0.21051126718521118
# 1073
# lse_loss -3.2125847339630127
# recon_loss 0.21026813983917236
