# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Sat Jan 13 22:22:19 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   25C    P8    14W / 230W |  17558MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 35%   61C    P2   137W / 230W |   4562MiB / 24564MiB |     28%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   58C    P2   157W / 230W |   8288MiB / 24564MiB |     44%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 32%   61C    P2   169W / 230W |   8328MiB / 24564MiB |     24%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   49C    P2   106W / 230W |   4168MiB / 24564MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   47C    P2    96W / 230W |   4168MiB / 24564MiB |     28%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   47C    P2   100W / 230W |   4168MiB / 24564MiB |     28%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   46C    P2   100W / 230W |   4168MiB / 24564MiB |     30%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2106188      C   ...onda3/envs/ste/bin/python    17550MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2307797      C   ...onda3/envs/ste/bin/python      394MiB |
# |    1   N/A  N/A   2323390      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   2322792      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    2   N/A  N/A   2328571      C   ...onda3/envs/ste/bin/python     4120MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   2322811      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    3   N/A  N/A   2323288      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2322890      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   2323029      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A   2323126      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A   2323205      C   ...onda3/envs/ste/bin/python     4160MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.trainable_sigma_uniform_lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.004646301269531
# encoder.convs 5.989013671875
# encoder.linear 0.01563262939453125
# latent_layer 3.814697265625e-06
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.11-11/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 0

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=1000)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            print(torch.exp(model.latent_layer.log_sigma))
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# tensor([0.5776], device='cuda:0', grad_fn=<ExpBackward0>)
# 45001
# lse_loss -1.129845142364502
# recon_loss 0.2300969362258911
# 45002
# lse_loss -1.0606226921081543
# recon_loss 0.2229137420654297
# 45003
# lse_loss -1.078160285949707
# recon_loss 0.22928838431835175
# 45004
# lse_loss -1.1093382835388184
# recon_loss 0.22358880937099457
# 45005
# lse_loss -1.0967249870300293
# recon_loss 0.22306641936302185
# 45006
# lse_loss -1.1129918098449707
# recon_loss 0.23232541978359222
# 45007
# lse_loss -1.0638279914855957
# recon_loss 0.22671270370483398
# 45008
# lse_loss -1.089932918548584
# recon_loss 0.22454965114593506
# 45009
# lse_loss -1.1071290969848633
# recon_loss 0.22378015518188477
# 45010
# lse_loss -1.1176238059997559
# recon_loss 0.21488520503044128
# 45011
# lse_loss -1.126558780670166
# recon_loss 0.22494816780090332
# 45012
# lse_loss -1.083383560180664
# recon_loss 0.22330014407634735
# 45013
# lse_loss -1.0882163047790527
# recon_loss 0.22145280241966248
# 45014
# lse_loss -1.1100831031799316
# recon_loss 0.21775683760643005
# 45015
# lse_loss -1.1050095558166504
# recon_loss 0.2247256636619568
# 45016
# lse_loss -1.1077752113342285
# recon_loss 0.23245057463645935
# 45017
# lse_loss -1.0729193687438965
# recon_loss 0.23482683300971985
# 45018
# lse_loss -1.065962314605713
# recon_loss 0.23334667086601257
# 45019
# lse_loss -1.1284260749816895
# recon_loss 0.2388477325439453
# 45020
# lse_loss -1.0880398750305176
# recon_loss 0.22941277921199799
# 45021
# lse_loss -1.1275124549865723
# recon_loss 0.24008993804454803
# 45022
# lse_loss -1.1030464172363281
# recon_loss 0.22307947278022766
# 45023
# lse_loss -1.0779294967651367
# recon_loss 0.22290587425231934
# 45024
# lse_loss -1.073044776916504
# recon_loss 0.2186252474784851
# 45025
# lse_loss -1.0758109092712402
# recon_loss 0.22992965579032898
# 45026
# lse_loss -1.1201248168945312
# recon_loss 0.23223452270030975
# 45027
# lse_loss -1.0694127082824707
# recon_loss 0.2136097550392151
# 45028
# lse_loss -1.133601188659668
# recon_loss 0.23396454751491547
# 45029
# lse_loss -1.10121488571167
# recon_loss 0.23002204298973083
# 45030
# lse_loss -1.1289916038513184
# recon_loss 0.22286616265773773
# 45031
# lse_loss -1.060926914215088
# recon_loss 0.22968542575836182
# 45032
# lse_loss -1.1223187446594238
# recon_loss 0.22138743102550507
# 45033
# lse_loss -1.0902514457702637
# recon_loss 0.22006216645240784
# 45034
# lse_loss -1.0741877555847168
# recon_loss 0.21839569509029388
# 45035
# lse_loss -1.0861353874206543
# recon_loss 0.22391027212142944
# 45036
# lse_loss -1.074021816253662
# recon_loss 0.22547277808189392
# 45037
# lse_loss -1.1036267280578613
# recon_loss 0.22200749814510345
# 45038
# lse_loss -1.116386890411377
# recon_loss 0.22160503268241882
# 45039
# lse_loss -1.1127352714538574
# recon_loss 0.22645044326782227
# 45040
# lse_loss -1.0734047889709473
# recon_loss 0.2249693125486374
# 45041
# lse_loss -1.1100497245788574
# recon_loss 0.2114572525024414
# 45042
# lse_loss -1.0884647369384766
# recon_loss 0.22290568053722382
# 45043
# lse_loss -1.0952949523925781
# recon_loss 0.22100961208343506
# 45044
# lse_loss -1.1369500160217285
# recon_loss 0.22438785433769226
# 45045
# lse_loss -1.1111502647399902
# recon_loss 0.22683534026145935
# 45046
# lse_loss -1.0839753150939941
# recon_loss 0.22745826840400696
# 45047
# lse_loss -1.0861563682556152
# recon_loss 0.21985119581222534
# 45048
# lse_loss -1.1166620254516602
# recon_loss 0.22158432006835938
# 45049
# lse_loss -1.10750150680542
# recon_loss 0.22078609466552734
# 45050
# lse_loss -1.1193828582763672
# recon_loss 0.22561213374137878
# 45051
# lse_loss -1.0915379524230957
# recon_loss 0.2331952154636383
# 45052
# lse_loss -1.0583481788635254
# recon_loss 0.21588441729545593
# 45053
# lse_loss -1.123763084411621
# recon_loss 0.2293645739555359
# 45054
# lse_loss -1.076554775238037
# recon_loss 0.2240675389766693
# 45055
# lse_loss -1.102278709411621
# recon_loss 0.22959992289543152
# 45056
# lse_loss -1.108187198638916
# recon_loss 0.21738439798355103
# 45057
# lse_loss -1.1081314086914062
# recon_loss 0.21871855854988098
# 45058
# lse_loss -1.0881619453430176
# recon_loss 0.2205123007297516
# 45059
# lse_loss -1.119255542755127
# recon_loss 0.22442112863063812
# 45060
# lse_loss -1.097548007965088
# recon_loss 0.22716598212718964
# 45061
# lse_loss -1.097813606262207
# recon_loss 0.22409550845623016
# 45062
# lse_loss -1.1386313438415527
# recon_loss 0.21239256858825684
# 45063
# lse_loss -1.1515002250671387
# recon_loss 0.20870232582092285
# 45064
# lse_loss -1.1045489311218262
# recon_loss 0.23718968033790588
# 45065
# lse_loss -1.098433017730713
# recon_loss 0.2249324917793274
# 45066
# lse_loss -1.1206598281860352
# recon_loss 0.22285443544387817
# 45067
# lse_loss -1.085035800933838
# recon_loss 0.2330562323331833
# 45068
# lse_loss -1.0836215019226074
# recon_loss 0.2268642634153366
# 45069
# lse_loss -1.0971837043762207
# recon_loss 0.21742594242095947
# 45070
# lse_loss -1.0511107444763184
# recon_loss 0.22055059671401978
# 45071
# lse_loss -1.096203327178955
# recon_loss 0.23034493625164032
# 45072
# lse_loss -1.0936522483825684
# recon_loss 0.2299058437347412
# 45073
# lse_loss -1.080960750579834
# recon_loss 0.22459694743156433
# 45074
# lse_loss -1.0482430458068848
# recon_loss 0.2266254723072052
# 45075
# lse_loss -1.110208511352539
# recon_loss 0.2254844605922699
# 45076
# lse_loss -1.1151890754699707
# recon_loss 0.23221787810325623
# 45077
# lse_loss -1.1370816230773926
# recon_loss 0.23088324069976807
# 45078
# lse_loss -1.1278395652770996
# recon_loss 0.24005281925201416
# 45079
# lse_loss -1.1151123046875
# recon_loss 0.2204817533493042
# 45080
# lse_loss -1.0970540046691895
# recon_loss 0.2213488519191742
# 45081
# lse_loss -1.1150202751159668
# recon_loss 0.22969159483909607
# 45082
# lse_loss -1.127978801727295
# recon_loss 0.23443910479545593
# 45083
# lse_loss -1.0928006172180176
# recon_loss 0.22696387767791748
# 45084
# lse_loss -1.108558177947998
# recon_loss 0.22907200455665588
# 45085
# lse_loss -1.1172380447387695
# recon_loss 0.2334299385547638
# 45086
# lse_loss -1.0752787590026855
# recon_loss 0.22498898208141327
# 45087
# lse_loss -1.1080355644226074
# recon_loss 0.2206449955701828
# 45088
# lse_loss -1.1134228706359863
# recon_loss 0.22468814253807068
# 45089
# lse_loss -1.1178336143493652
# recon_loss 0.22947023808956146
# 45090
# lse_loss -1.1447491645812988
# recon_loss 0.23353008925914764
# 45091
# lse_loss -1.0994820594787598
# recon_loss 0.22777120769023895
# 45092
# lse_loss -1.1205778121948242
# recon_loss 0.22906622290611267
# 45093
# lse_loss -1.1396431922912598
# recon_loss 0.22634916007518768
# 45094
# lse_loss -1.110231876373291
# recon_loss 0.22963643074035645
# 45095
# lse_loss -1.1165413856506348
# recon_loss 0.22223496437072754
# 45096
# lse_loss -1.0821833610534668
# recon_loss 0.2290726602077484
# 45097
# lse_loss -1.0969538688659668
# recon_loss 0.23260335624217987
# 45098
# lse_loss -1.13358736038208
# recon_loss 0.21258345246315002
# 45099
# lse_loss -1.118701457977295
# recon_loss 0.2359752357006073
# 45100
# lse_loss -1.1187396049499512
# recon_loss 0.22538673877716064
# 45101
# lse_loss -1.1045212745666504
# recon_loss 0.23193025588989258
# 45102
# lse_loss -1.0986695289611816
# recon_loss 0.2144700288772583
# 45103
# lse_loss -1.0948429107666016
# recon_loss 0.22105193138122559
# 45104
# lse_loss -1.0984182357788086
# recon_loss 0.22133223712444305
# 45105
# lse_loss -1.1116867065429688
# recon_loss 0.23605462908744812
# 45106
# lse_loss -1.0515055656433105
# recon_loss 0.21770739555358887
# 45107
# lse_loss -1.086108684539795
# recon_loss 0.22297130525112152
# 45108
# lse_loss -1.1224913597106934
# recon_loss 0.22419559955596924
# 45109
# lse_loss -1.132127285003662
# recon_loss 0.22589044272899628
# 45110
# lse_loss -1.0826826095581055
# recon_loss 0.21131615340709686
# 45111
# lse_loss -1.1149682998657227
# recon_loss 0.21394526958465576
# 45112
# lse_loss -1.0967860221862793
# recon_loss 0.2301054447889328
# 45113
# lse_loss -1.087651252746582
# recon_loss 0.21927496790885925
# 45114
# lse_loss -1.1189846992492676
# recon_loss 0.23562221229076385
# 45115
# lse_loss -1.1059880256652832
# recon_loss 0.22832803428173065
# 45116
# lse_loss -1.0742230415344238
# recon_loss 0.2283981293439865
# 45117
# lse_loss -1.0788946151733398
# recon_loss 0.22235849499702454
# 45118
# lse_loss -1.087501049041748
# recon_loss 0.2222941368818283
# 45119
# lse_loss -1.0926299095153809
# recon_loss 0.23225077986717224
# 45120
# lse_loss -1.0998010635375977
# recon_loss 0.23636946082115173
# 45121
# lse_loss -1.1078839302062988
# recon_loss 0.2281164824962616
# 45122
# lse_loss -1.0660052299499512
# recon_loss 0.23586545884609222
# 45123
# lse_loss -1.0875358581542969
# recon_loss 0.22574391961097717
# 45124
# lse_loss -1.093841552734375
# recon_loss 0.21435603499412537
# 45125
# lse_loss -1.1065340042114258
# recon_loss 0.22048673033714294
# 45126
# lse_loss -1.1015324592590332
# recon_loss 0.22781407833099365
# 45127
# lse_loss -1.0907998085021973
# recon_loss 0.23354634642601013
# 45128
# lse_loss -1.0763092041015625
# recon_loss 0.21840082108974457
# 45129
# lse_loss -1.056891918182373
# recon_loss 0.22704975306987762
# 45130
# lse_loss -1.1163663864135742
# recon_loss 0.22737497091293335
# 45131
# lse_loss -1.0795931816101074
# recon_loss 0.22374120354652405
# 45132
# lse_loss -1.1104774475097656
# recon_loss 0.22674739360809326
# 45133
# lse_loss -1.0831856727600098
# recon_loss 0.21648097038269043
# 45134
# lse_loss -1.1025338172912598
# recon_loss 0.22851967811584473
# 45135
# lse_loss -1.0975642204284668
# recon_loss 0.21930132806301117
# 45136
# lse_loss -1.1177630424499512
# recon_loss 0.2215745896100998
# 45137
# lse_loss -1.0675230026245117
# recon_loss 0.21799173951148987
# 45138
# lse_loss -1.0863189697265625
# recon_loss 0.2299620360136032
# 45139
# lse_loss -1.0733437538146973
# recon_loss 0.2246875762939453
# 45140
# lse_loss -1.11869478225708
# recon_loss 0.21667258441448212
# 45141
# lse_loss -1.0932021141052246
# recon_loss 0.23274213075637817
# 45142
# lse_loss -1.0574584007263184
# recon_loss 0.22435300052165985
# 45143
# lse_loss -1.0700082778930664
# recon_loss 0.2267220914363861
# 45144
# lse_loss -1.1319880485534668
# recon_loss 0.22583967447280884
# 45145
# lse_loss -1.0678553581237793
# recon_loss 0.23440638184547424
# 45146
# lse_loss -1.09279203414917
# recon_loss 0.2216210961341858
# 45147
# lse_loss -1.1089634895324707
# recon_loss 0.2342240810394287
# 45148
# lse_loss -1.0852370262145996
# recon_loss 0.23136691749095917
# 45149
# lse_loss -1.0922980308532715
# recon_loss 0.23265746235847473
# 45150
# lse_loss -1.0965666770935059
# recon_loss 0.22862476110458374
# 45151
# lse_loss -1.1056103706359863
# recon_loss 0.23314139246940613
# 45152
# lse_loss -1.0903515815734863
# recon_loss 0.22638623416423798
# 45153
# lse_loss -1.092393398284912
# recon_loss 0.22265999019145966
# 45154
# lse_loss -1.065469741821289
# recon_loss 0.23469583690166473
# 45155
# lse_loss -1.1262211799621582
# recon_loss 0.23697242140769958
# 45156
# lse_loss -1.1276640892028809
# recon_loss 0.2251366376876831
# 45157
# lse_loss -1.1039156913757324
# recon_loss 0.23511812090873718
# 45158
# lse_loss -1.0860695838928223
# recon_loss 0.2254808396100998
# 45159
# lse_loss -1.082420825958252
# recon_loss 0.22139959037303925
# 45160
# lse_loss -1.0935120582580566
# recon_loss 0.22769847512245178
# 45161
# lse_loss -1.0490336418151855
# recon_loss 0.23315861821174622
# 45162
# lse_loss -1.1274266242980957
# recon_loss 0.22072026133537292
# 45163
# lse_loss -1.1180777549743652
# recon_loss 0.23186174035072327
# 45164
# lse_loss -1.0558018684387207
# recon_loss 0.23047083616256714
# 45165
# lse_loss -1.1001033782958984
# recon_loss 0.2248269021511078
# 45166
# lse_loss -1.1075177192687988
# recon_loss 0.23235516250133514
# 45167
# lse_loss -1.0960712432861328
# recon_loss 0.22924207150936127
# 45168
# lse_loss -1.081881046295166
# recon_loss 0.22878611087799072
# 45169
# lse_loss -1.1061010360717773
# recon_loss 0.21827685832977295
# 45170
# lse_loss -1.111894130706787
# recon_loss 0.22769276797771454
# 45171
# lse_loss -1.119983196258545
# recon_loss 0.24468104541301727
# 45172
# lse_loss -1.1132588386535645
# recon_loss 0.23012316226959229
# 45173
# lse_loss -1.11226224899292
# recon_loss 0.23554283380508423
# 45174
# lse_loss -1.0830130577087402
# recon_loss 0.21970133483409882
# 45175
# lse_loss -1.1374773979187012
# recon_loss 0.21538162231445312
# 45176
# lse_loss -1.0926356315612793
# recon_loss 0.23008763790130615
# 45177
# lse_loss -1.0553946495056152
# recon_loss 0.23206540942192078
# 45178
# lse_loss -1.0737910270690918
# recon_loss 0.21908625960350037
# 45179
# lse_loss -1.0840668678283691
# recon_loss 0.21853052079677582
# 45180
# lse_loss -1.1207756996154785
# recon_loss 0.2291853427886963
# 45181
# lse_loss -1.0971097946166992
# recon_loss 0.2200649231672287
# 45182
# lse_loss -1.1007733345031738
# recon_loss 0.23171338438987732
# 45183
# lse_loss -1.0973429679870605
# recon_loss 0.21864959597587585
# 45184
# lse_loss -1.0953011512756348
# recon_loss 0.2304190844297409
# 45185
# lse_loss -1.072455883026123
# recon_loss 0.2201569378376007
# 45186
# lse_loss -1.0779156684875488
# recon_loss 0.2323298454284668
# 45187
# lse_loss -1.1369705200195312
# recon_loss 0.23535582423210144
# 45188
# lse_loss -1.107522964477539
# recon_loss 0.228350430727005
# 45189
# lse_loss -1.0569186210632324
# recon_loss 0.2161216139793396
# 45190
# lse_loss -1.0707173347473145
# recon_loss 0.2208099067211151
# 45191
# lse_loss -1.0955348014831543
# recon_loss 0.23045293986797333
# 45192
# lse_loss -1.1187825202941895
# recon_loss 0.22323283553123474
# 45193
# lse_loss -1.1129794120788574
# recon_loss 0.22160260379314423
# 45194
# lse_loss -1.0720582008361816
# recon_loss 0.22794219851493835
# 45195
# lse_loss -1.1079888343811035
# recon_loss 0.22971616685390472
# 45196
# lse_loss -1.0705924034118652
# recon_loss 0.22790364921092987
# 45197
# lse_loss -1.0966105461120605
# recon_loss 0.22573606669902802
# 45198
# lse_loss -1.0831947326660156
# recon_loss 0.22629740834236145
# 45199
# lse_loss -1.095231533050537
# recon_loss 0.23425692319869995
# 45200
# lse_loss -1.1071767807006836
# recon_loss 0.21707110106945038
# 45201
# lse_loss -1.1060566902160645
# recon_loss 0.21833693981170654
# 45202
# lse_loss -1.095811367034912
# recon_loss 0.22277429699897766
# 45203
# lse_loss -1.082108974456787
# recon_loss 0.22605374455451965
# 45204
# lse_loss -1.0935101509094238
# recon_loss 0.22228559851646423
# 45205
# lse_loss -1.1331825256347656
# recon_loss 0.22822773456573486
# 45206
# lse_loss -1.083925724029541
# recon_loss 0.21942715346813202
# 45207
# lse_loss -1.076948642730713
# recon_loss 0.2247685194015503
# 45208
# lse_loss -1.081204891204834
# recon_loss 0.21847085654735565
# 45209
# lse_loss -1.0988497734069824
# recon_loss 0.21487239003181458
# 45210
# lse_loss -1.1145086288452148
# recon_loss 0.2251931130886078
# 45211
# lse_loss -1.1053681373596191
# recon_loss 0.21936963498592377
# 45212
# lse_loss -1.086784839630127
# recon_loss 0.23309552669525146
# 45213
# lse_loss -1.1117701530456543
# recon_loss 0.22789782285690308
# 45214
# lse_loss -1.0721831321716309
# recon_loss 0.22779762744903564
# 45215
# lse_loss -1.0930819511413574
# recon_loss 0.22830495238304138
# 45216
# lse_loss -1.1260652542114258
# recon_loss 0.2259232997894287
# 45217
# lse_loss -1.076113224029541
# recon_loss 0.23612694442272186
# 45218
# lse_loss -1.1074566841125488
# recon_loss 0.2252989262342453
# 45219
# lse_loss -1.08943510055542
# recon_loss 0.2237240970134735
# 45220
# lse_loss -1.0901727676391602
# recon_loss 0.22918646037578583
# 45221
# lse_loss -1.1055340766906738
# recon_loss 0.2118094563484192
# 45222
# lse_loss -1.111304759979248
# recon_loss 0.23217537999153137
# 45223
# lse_loss -1.1120152473449707
# recon_loss 0.21874544024467468
# 45224
# lse_loss -1.1224160194396973
# recon_loss 0.22653350234031677
# 45225
# lse_loss -1.0432543754577637
# recon_loss 0.22006705403327942
# 45226
# lse_loss -1.1025300025939941
# recon_loss 0.22397755086421967
# 45227
# lse_loss -1.0872511863708496
# recon_loss 0.22882048785686493
# 45228
# lse_loss -1.1078014373779297
# recon_loss 0.22046774625778198
# 45229
# lse_loss -1.1437664031982422
# recon_loss 0.2167859524488449
# 45230
# lse_loss -1.1312675476074219
# recon_loss 0.23082290589809418
# 45231
# lse_loss -1.072099208831787
# recon_loss 0.22166836261749268
# 45232
# lse_loss -1.108612060546875
# recon_loss 0.22352628409862518
# 45233
# lse_loss -1.113539218902588
# recon_loss 0.20956063270568848
# 45234
# lse_loss -1.089672565460205
# recon_loss 0.22828230261802673
# 45235
# lse_loss -1.1118569374084473
# recon_loss 0.23386161029338837
# 45236
# lse_loss -1.0541949272155762
# recon_loss 0.23084025084972382
# 45237
# lse_loss -1.0877537727355957
# recon_loss 0.22557179629802704
# 45238
# lse_loss -1.0985894203186035
# recon_loss 0.2200303077697754
# 45239
# lse_loss -1.1008214950561523
# recon_loss 0.2310221642255783
# 45240
# lse_loss -1.1123342514038086
# recon_loss 0.2271958291530609
# 45241
# lse_loss -1.1257643699645996
# recon_loss 0.2243158519268036
# 45242
# lse_loss -1.0596442222595215
# recon_loss 0.2268361896276474
# 45243
# lse_loss -1.1195425987243652
# recon_loss 0.22242212295532227
# 45244
# lse_loss -1.1128296852111816
# recon_loss 0.22625307738780975
# 45245
# lse_loss -1.1142725944519043
# recon_loss 0.223334401845932
# 45246
# lse_loss -1.1022944450378418
# recon_loss 0.22007879614830017
# 45247
# lse_loss -1.1144194602966309
# recon_loss 0.22892722487449646
# 45248
# lse_loss -1.0978093147277832
# recon_loss 0.23178350925445557
# 45249
# lse_loss -1.106306552886963
# recon_loss 0.23142926394939423
# 45250
# lse_loss -1.0528779029846191
# recon_loss 0.22668525576591492
# 45251
# lse_loss -1.0711698532104492
# recon_loss 0.23020750284194946
# 45252
# lse_loss -1.1100859642028809
# recon_loss 0.22067996859550476
# 45253
# lse_loss -1.0871691703796387
# recon_loss 0.21877531707286835
# 45254
# lse_loss -1.0801901817321777
# recon_loss 0.23810970783233643
# 45255
# lse_loss -1.1064105033874512
# recon_loss 0.23261301219463348
# 45256
# lse_loss -1.0718717575073242
# recon_loss 0.2281353920698166
# 45257
# lse_loss -1.109205722808838
# recon_loss 0.2232339233160019
# 45258
# lse_loss -1.099189281463623
# recon_loss 0.22322556376457214
# 45259
# lse_loss -1.0778160095214844
# recon_loss 0.22520384192466736
# 45260
# lse_loss -1.11314058303833
# recon_loss 0.22819223999977112
# 45261
# lse_loss -1.069321632385254
# recon_loss 0.23540668189525604
# 45262
# lse_loss -1.0948090553283691
# recon_loss 0.22170042991638184
# 45263
# lse_loss -1.1155405044555664
# recon_loss 0.2164439857006073
# 45264
# lse_loss -1.10365629196167
# recon_loss 0.21876373887062073
# 45265
# lse_loss -1.0947184562683105
# recon_loss 0.22805409133434296
# 45266
# lse_loss -1.1132616996765137
# recon_loss 0.23117677867412567
# 45267
# lse_loss -1.1015429496765137
# recon_loss 0.2189604938030243
# 45268
# lse_loss -1.07474946975708
# recon_loss 0.2297363132238388
# 45269
# lse_loss -1.0889015197753906
# recon_loss 0.22332096099853516
# 45270
# lse_loss -1.0695090293884277
# recon_loss 0.2302326261997223
# 45271
# lse_loss -1.0754399299621582
# recon_loss 0.23178863525390625
# 45272
# lse_loss -1.0758910179138184
# recon_loss 0.222931370139122
# 45273
# lse_loss -1.056793212890625
# recon_loss 0.2299930900335312
# 45274
# lse_loss -1.1025543212890625
# recon_loss 0.22981064021587372
# 45275
# lse_loss -1.099611759185791
# recon_loss 0.2224893569946289
# 45276
# lse_loss -1.0780205726623535
# recon_loss 0.21773700416088104
# 45277
# lse_loss -1.1128287315368652
# recon_loss 0.2328532636165619
# 45278
# lse_loss -1.095228672027588
# recon_loss 0.2172352522611618
# 45279
# lse_loss -1.1092863082885742
# recon_loss 0.21660035848617554
# 45280
# lse_loss -1.0884194374084473
# recon_loss 0.23017118871212006
# 45281
# lse_loss -1.0894579887390137
# recon_loss 0.23106110095977783
# 45282
# lse_loss -1.0701727867126465
# recon_loss 0.2201881855726242
# 45283
# lse_loss -1.11116361618042
# recon_loss 0.2282654345035553
# 45284
# lse_loss -1.1170897483825684
# recon_loss 0.23075346648693085
# 45285
# lse_loss -1.1061630249023438
# recon_loss 0.23360268771648407
# 45286
# lse_loss -1.0898680686950684
# recon_loss 0.2234289050102234
# 45287
# lse_loss -1.0977368354797363
# recon_loss 0.23373787105083466
# 45288
# lse_loss -1.080848217010498
# recon_loss 0.2306041568517685
# 45289
# lse_loss -1.11329984664917
# recon_loss 0.22630397975444794
# 45290
# lse_loss -1.1336750984191895
# recon_loss 0.22264014184474945
# 45291
# lse_loss -1.1063714027404785
# recon_loss 0.22295960783958435
# 45292
# lse_loss -1.1012763977050781
# recon_loss 0.23693536221981049
# 45293
# lse_loss -1.0767273902893066
# recon_loss 0.22731882333755493
# 45294
# lse_loss -1.1365952491760254
# recon_loss 0.22266851365566254
# 45295
# lse_loss -1.0958166122436523
# recon_loss 0.21714448928833008
# 45296
# lse_loss -1.0692830085754395
# recon_loss 0.22598551213741302
# 45297
# lse_loss -1.1047663688659668
# recon_loss 0.2339632511138916
# 45298
# lse_loss -1.0812911987304688
# recon_loss 0.23369166254997253
# 45299
# lse_loss -1.1137032508850098
# recon_loss 0.22588741779327393
# 45300
# lse_loss -1.1113429069519043
# recon_loss 0.22790074348449707
# 45301
# lse_loss -1.139244556427002
# recon_loss 0.22894665598869324
# 45302
# lse_loss -1.103518009185791
# recon_loss 0.22539304196834564
# 45303
# lse_loss -1.1005263328552246
# recon_loss 0.22075824439525604
# 45304
# lse_loss -1.1102957725524902
# recon_loss 0.2343083620071411
# 45305
# lse_loss -1.0982236862182617
# recon_loss 0.2280004471540451
# 45306
# lse_loss -1.1156821250915527
# recon_loss 0.22795438766479492
# 45307
# lse_loss -1.1071162223815918
# recon_loss 0.23409347236156464
# 45308
# lse_loss -1.08884859085083
# recon_loss 0.2229400873184204
# 45309
# lse_loss -1.1096529960632324
# recon_loss 0.23606924712657928
# 45310
# lse_loss -1.0979070663452148
# recon_loss 0.2180110067129135
# 45311
# lse_loss -1.1075339317321777
# recon_loss 0.2229587435722351
# 45312
# lse_loss -1.1291966438293457
# recon_loss 0.2419469803571701
# 45313
# lse_loss -1.0874834060668945
# recon_loss 0.23202693462371826
# 45314
# lse_loss -1.0789895057678223
# recon_loss 0.22693952918052673
# 45315
# lse_loss -1.1320490837097168
# recon_loss 0.21966955065727234
# 45316
# lse_loss -1.0950350761413574
# recon_loss 0.22655436396598816
# 45317
# lse_loss -1.1136794090270996
# recon_loss 0.22616919875144958
# 45318
# lse_loss -1.1202607154846191
# recon_loss 0.21573257446289062
# 45319
# lse_loss -1.1006531715393066
# recon_loss 0.21619808673858643
# 45320
# lse_loss -1.1250505447387695
# recon_loss 0.22124502062797546
# 45321
# lse_loss -1.10609769821167
# recon_loss 0.23089514672756195
# 45322
# lse_loss -1.0877623558044434
# recon_loss 0.23061645030975342
# 45323
# lse_loss -1.1111531257629395
# recon_loss 0.2171197384595871
# 45324
# lse_loss -1.1214261054992676
# recon_loss 0.22180837392807007
# 45325
# lse_loss -1.1138081550598145
# recon_loss 0.22798892855644226
# 45326
# lse_loss -1.0862774848937988
# recon_loss 0.21854929625988007
# 45327
# lse_loss -1.0945358276367188
# recon_loss 0.2188795506954193
# 45328
# lse_loss -1.0668225288391113
# recon_loss 0.23326349258422852
# 45329
# lse_loss -1.0973281860351562
# recon_loss 0.2221444547176361
# 45330
# lse_loss -1.0619111061096191
# recon_loss 0.2363642305135727
# 45331
# lse_loss -1.0761289596557617
# recon_loss 0.2305486500263214
# 45332
# lse_loss -1.0811371803283691
# recon_loss 0.22678379714488983
# 45333
# lse_loss -1.0937600135803223
# recon_loss 0.23229369521141052
# 45334
# lse_loss -1.1271510124206543
# recon_loss 0.22189006209373474
# 45335
# lse_loss -1.1157288551330566
# recon_loss 0.2228127419948578
# 45336
# lse_loss -1.1162934303283691
# recon_loss 0.23196133971214294
# 45337
# lse_loss -1.1069278717041016
# recon_loss 0.2255489081144333
# 45338
# lse_loss -1.1293740272521973
# recon_loss 0.2305542677640915
# 45339
# lse_loss -1.078535556793213
# recon_loss 0.23233437538146973
# 45340
# lse_loss -1.0965332984924316
# recon_loss 0.2248288094997406
# 45341
# lse_loss -1.0916171073913574
# recon_loss 0.22077739238739014
# 45342
# lse_loss -1.066159725189209
# recon_loss 0.22444014251232147
# 45343
# lse_loss -1.1052308082580566
# recon_loss 0.22315339744091034
# 45344
# lse_loss -1.1089444160461426
# recon_loss 0.23273715376853943
# 45345
# lse_loss -1.0997867584228516
# recon_loss 0.23257140815258026
# 45346
# lse_loss -1.074174404144287
# recon_loss 0.22844097018241882
# 45347
# lse_loss -1.0685992240905762
# recon_loss 0.2259577214717865
# 45348
# lse_loss -1.0937581062316895
# recon_loss 0.21384339034557343
# 45349
# lse_loss -1.128124713897705
# recon_loss 0.2220383584499359
# 45350
# lse_loss -1.1141095161437988
# recon_loss 0.218553364276886
# 45351
# lse_loss -1.0804877281188965
# recon_loss 0.21803180873394012
# 45352
# lse_loss -1.113945484161377
# recon_loss 0.23339921236038208
# 45353
# lse_loss -1.0924158096313477
# recon_loss 0.2221711128950119
# 45354
# lse_loss -1.0931992530822754
# recon_loss 0.2257203310728073
# 45355
# lse_loss -1.10624361038208
# recon_loss 0.23407599329948425
# 45356
# lse_loss -1.0759782791137695
# recon_loss 0.22811250388622284
# 45357
# lse_loss -1.0975728034973145
# recon_loss 0.22904488444328308
# 45358
# lse_loss -1.0894427299499512
# recon_loss 0.2270822525024414
# 45359
# lse_loss -1.0799789428710938
# recon_loss 0.22585737705230713
# 45360
# lse_loss -1.1096339225769043
# recon_loss 0.22071227431297302
# 45361
# lse_loss -1.0751309394836426
# recon_loss 0.22256845235824585
# 45362
# lse_loss -1.0523881912231445
# recon_loss 0.21746937930583954
# 45363
# lse_loss -1.0810704231262207
# recon_loss 0.2261141538619995
# 45364
# lse_loss -1.1002135276794434
# recon_loss 0.2172437161207199
# 45365
# lse_loss -1.0845494270324707
# recon_loss 0.22321045398712158
# 45366
# lse_loss -1.124804973602295
# recon_loss 0.23431101441383362
# 45367
# lse_loss -1.0709280967712402
# recon_loss 0.22304320335388184
# 45368
# lse_loss -1.1287627220153809
# recon_loss 0.22244343161582947
# 45369
# lse_loss -1.075502872467041
# recon_loss 0.22570829093456268
# 45370
# lse_loss -1.1165027618408203
# recon_loss 0.22359365224838257
# 45371
# lse_loss -1.122551441192627
# recon_loss 0.22290965914726257
# 45372
# lse_loss -1.1189398765563965
# recon_loss 0.22755932807922363
# 45373
# lse_loss -1.0850238800048828
# recon_loss 0.21527521312236786
# 45374
# lse_loss -1.119518756866455
# recon_loss 0.22897738218307495
# 45375
# lse_loss -1.0930685997009277
# recon_loss 0.23368820548057556
# 45376
# lse_loss -1.1335678100585938
# recon_loss 0.22444884479045868
# 45377
# lse_loss -1.101426601409912
# recon_loss 0.23533916473388672
# 45378
# lse_loss -1.1165432929992676
# recon_loss 0.22802814841270447
# 45379
# lse_loss -1.0909934043884277
# recon_loss 0.21616604924201965
# 45380
# lse_loss -1.090837001800537
# recon_loss 0.22096745669841766
# 45381
# lse_loss -1.0832295417785645
# recon_loss 0.2308584749698639
# 45382
# lse_loss -1.091163158416748
# recon_loss 0.22785037755966187
# 45383
# lse_loss -1.0813212394714355
# recon_loss 0.2258875072002411
# 45384
# lse_loss -1.0860114097595215
# recon_loss 0.22316937148571014
# 45385
# lse_loss -1.084815502166748
# recon_loss 0.23123562335968018
# 45386
# lse_loss -1.0927414894104004
# recon_loss 0.22784416377544403
# 45387
# lse_loss -1.1198277473449707
# recon_loss 0.21909897029399872
# 45388
# lse_loss -1.1012239456176758
# recon_loss 0.22076134383678436
# 45389
# lse_loss -1.0840539932250977
# recon_loss 0.21970853209495544
# 45390
# lse_loss -1.0912261009216309
# recon_loss 0.22372660040855408
# 45391
# lse_loss -1.0826468467712402
# recon_loss 0.22585198283195496
# 45392
# lse_loss -1.1088147163391113
# recon_loss 0.23747488856315613
# 45393
# lse_loss -1.1029667854309082
# recon_loss 0.22452035546302795
# 45394
# lse_loss -1.1047883033752441
# recon_loss 0.22513192892074585
# 45395
# lse_loss -1.1111350059509277
# recon_loss 0.2182009071111679
# 45396
# lse_loss -1.1407160758972168
# recon_loss 0.22724401950836182
# 45397
# lse_loss -1.0762486457824707
# recon_loss 0.21986453235149384
# 45398
# lse_loss -1.107530117034912
# recon_loss 0.23368196189403534
# 45399
# lse_loss -1.0663409233093262
# recon_loss 0.2281298041343689
# 45400
# lse_loss -1.0996155738830566
# recon_loss 0.23031362891197205
# 45401
# lse_loss -1.0905251502990723
# recon_loss 0.2263478934764862
# 45402
# lse_loss -1.0948023796081543
# recon_loss 0.2334134578704834
# 45403
# lse_loss -1.0976991653442383
# recon_loss 0.2201547473669052
# 45404
# lse_loss -1.1049089431762695
# recon_loss 0.21608516573905945
# 45405
# lse_loss -1.1383094787597656
# recon_loss 0.23313790559768677
# 45406
# lse_loss -1.091820240020752
# recon_loss 0.22776424884796143
# 45407
# lse_loss -1.0836424827575684
# recon_loss 0.22890055179595947
# 45408
# lse_loss -1.07853364944458
# recon_loss 0.22790956497192383
# 45409
# lse_loss -1.0480661392211914
# recon_loss 0.2233276069164276
# 45410
# lse_loss -1.057260513305664
# recon_loss 0.23127886652946472
# 45411
# lse_loss -1.1045336723327637
# recon_loss 0.22597424685955048
# 45412
# lse_loss -1.121354103088379
# recon_loss 0.22312462329864502
# 45413
# lse_loss -1.0955348014831543
# recon_loss 0.22819459438323975
# 45414
# lse_loss -1.1006064414978027
# recon_loss 0.22247295081615448
# 45415
# lse_loss -1.0918402671813965
# recon_loss 0.21708576381206512
# 45416
# lse_loss -1.121593952178955
# recon_loss 0.22683106362819672
# 45417
# lse_loss -1.0804123878479004
# recon_loss 0.21814727783203125
# 45418
# lse_loss -1.1029267311096191
# recon_loss 0.21285653114318848
# 45419
# lse_loss -1.0743374824523926
# recon_loss 0.21815840899944305
# 45420
# lse_loss -1.0744233131408691
# recon_loss 0.2236885130405426
# 45421
# lse_loss -1.1228327751159668
# recon_loss 0.225617915391922
# 45422
# lse_loss -1.117539882659912
# recon_loss 0.22159120440483093
# 45423
# lse_loss -1.0957894325256348
# recon_loss 0.22774332761764526
# 45424
# lse_loss -1.0860538482666016
# recon_loss 0.2166913002729416
# 45425
# lse_loss -1.0969805717468262
# recon_loss 0.2236570566892624
# 45426
# lse_loss -1.0913500785827637
# recon_loss 0.2217886745929718
# 45427
# lse_loss -1.0746636390686035
# recon_loss 0.22339171171188354
# 45428
# lse_loss -1.0898828506469727
# recon_loss 0.22972851991653442
# 45429
# lse_loss -1.0576653480529785
# recon_loss 0.22245264053344727
# 45430
# lse_loss -1.0803561210632324
# recon_loss 0.2295047640800476
# 45431
# lse_loss -1.1515936851501465
# recon_loss 0.2281380146741867
# 45432
# lse_loss -1.075636386871338
# recon_loss 0.2295786589384079
# 45433
# lse_loss -1.0877208709716797
# recon_loss 0.22255611419677734
# 45434
# lse_loss -1.1131129264831543
# recon_loss 0.2314971685409546
# 45435
# lse_loss -1.067335605621338
# recon_loss 0.22243838012218475
# 45436
# lse_loss -1.099534511566162
# recon_loss 0.22432607412338257
# 45437
# lse_loss -1.1188530921936035
# recon_loss 0.21208512783050537
# 45438
# lse_loss -1.1216611862182617
# recon_loss 0.22847533226013184
# 45439
# lse_loss -1.0791068077087402
# recon_loss 0.2258613109588623
# 45440
# lse_loss -1.0998258590698242
# recon_loss 0.22365602850914001
# 45441
# lse_loss -1.1276793479919434
# recon_loss 0.2293834388256073
# 45442
# lse_loss -1.0973854064941406
# recon_loss 0.22206339240074158
# 45443
# lse_loss -1.1105971336364746
# recon_loss 0.22085779905319214
# 45444
# lse_loss -1.1174349784851074
# recon_loss 0.22720381617546082
# 45445
# lse_loss -1.0986318588256836
# recon_loss 0.22081032395362854
# 45446
# lse_loss -1.1284761428833008
# recon_loss 0.23712913691997528
# 45447
# lse_loss -1.0818419456481934
# recon_loss 0.2412886619567871
# 45448
# lse_loss -1.1157994270324707
# recon_loss 0.21936802566051483
# 45449
# lse_loss -1.1136813163757324
# recon_loss 0.22366544604301453
# 45450
# lse_loss -1.0686564445495605
# recon_loss 0.22387370467185974
# 45451
# lse_loss -1.100797176361084
# recon_loss 0.22880661487579346
# 45452
# lse_loss -1.0910563468933105
# recon_loss 0.21722137928009033
# 45453
# lse_loss -1.081042766571045
# recon_loss 0.2290717363357544
# 45454
# lse_loss -1.0685644149780273
# recon_loss 0.2314417064189911
# 45455
# lse_loss -1.1402173042297363
# recon_loss 0.22272616624832153
# 45456
# lse_loss -1.122018814086914
# recon_loss 0.22003790736198425
# 45457
# lse_loss -1.1254496574401855
# recon_loss 0.2257288098335266
# 45458
# lse_loss -1.1004815101623535
# recon_loss 0.2233271449804306
# 45459
# lse_loss -1.1187238693237305
# recon_loss 0.22145430743694305
# 45460
# lse_loss -1.100142002105713
# recon_loss 0.24566642940044403
# 45461
# lse_loss -1.0904297828674316
# recon_loss 0.22230803966522217
# 45462
# lse_loss -1.0677056312561035
# recon_loss 0.23181197047233582
# 45463
# lse_loss -1.1074252128601074
# recon_loss 0.22981268167495728
# 45464
# lse_loss -1.0706286430358887
# recon_loss 0.219496488571167
# 45465
# lse_loss -1.0886149406433105
# recon_loss 0.22169828414916992
# 45466
# lse_loss -1.0756659507751465
# recon_loss 0.23251324892044067
# 45467
# lse_loss -1.0961356163024902
# recon_loss 0.22322553396224976
# 45468
# lse_loss -1.1137375831604004
# recon_loss 0.233679860830307
# 45469
# lse_loss -1.107123851776123
# recon_loss 0.22318658232688904
# 45470
# lse_loss -1.0954298973083496
# recon_loss 0.23227155208587646
# 45471
# lse_loss -1.1410980224609375
# recon_loss 0.2323785275220871
# 45472
# lse_loss -1.10740327835083
# recon_loss 0.22745755314826965
# 45473
# lse_loss -1.0863947868347168
# recon_loss 0.2272195816040039
# 45474
# lse_loss -1.0640263557434082
# recon_loss 0.2287418693304062
# 45475
# lse_loss -1.0694189071655273
# recon_loss 0.23013314604759216
# 45476
# lse_loss -1.1194300651550293
# recon_loss 0.23069611191749573
# 45477
# lse_loss -1.1281647682189941
# recon_loss 0.22279267013072968
# 45478
# lse_loss -1.0687084197998047
# recon_loss 0.23188185691833496
# 45479
# lse_loss -1.062863826751709
# recon_loss 0.22058090567588806
# 45480
# lse_loss -1.0804429054260254
# recon_loss 0.22208593785762787
# 45481
# lse_loss -1.1352787017822266
# recon_loss 0.22291851043701172
# 45482
# lse_loss -1.10333251953125
# recon_loss 0.23309241235256195
# 45483
# lse_loss -1.0986580848693848
# recon_loss 0.23591820895671844
# 45484
# lse_loss -1.1141743659973145
# recon_loss 0.225600004196167
# 45485
# lse_loss -1.1173901557922363
# recon_loss 0.23327946662902832
# 45486
# lse_loss -1.0858817100524902
# recon_loss 0.2209729254245758
# 45487
# lse_loss -1.127023696899414
# recon_loss 0.2135058343410492
# 45488
# lse_loss -1.106184482574463
# recon_loss 0.2219017744064331
# 45489
# lse_loss -1.0601296424865723
# recon_loss 0.2260253131389618
# 45490
# lse_loss -1.0643877983093262
# recon_loss 0.21620437502861023
# 45491
# lse_loss -1.1198005676269531
# recon_loss 0.22237345576286316
# 45492
# lse_loss -1.071706771850586
# recon_loss 0.21334683895111084
# 45493
# lse_loss -1.1053004264831543
# recon_loss 0.21509766578674316
# 45494
# lse_loss -1.1146149635314941
# recon_loss 0.2321699559688568
# 45495
# lse_loss -1.115236759185791
# recon_loss 0.22258377075195312
# 45496
# lse_loss -1.0691289901733398
# recon_loss 0.22591641545295715
# 45497
# lse_loss -1.0575556755065918
# recon_loss 0.2303539216518402
# 45498
# lse_loss -1.0631098747253418
# recon_loss 0.22509615123271942
# 45499
# lse_loss -1.07059907913208
# recon_loss 0.2309490442276001
# 45500
# lse_loss -1.107435703277588
# recon_loss 0.23066799342632294
# 45501
# lse_loss -1.13316011428833
# recon_loss 0.21923840045928955
# 45502
# lse_loss -1.084609031677246
# recon_loss 0.2258075326681137
# 45503
# lse_loss -1.1382765769958496
# recon_loss 0.2311892956495285
# 45504
# lse_loss -1.0868911743164062
# recon_loss 0.21843984723091125
# 45505
# lse_loss -1.0906329154968262
# recon_loss 0.2414165735244751
# 45506
# lse_loss -1.0691733360290527
# recon_loss 0.2248273342847824
# 45507
# lse_loss -1.0897583961486816
# recon_loss 0.21856187283992767
# 45508
# lse_loss -1.1416492462158203
# recon_loss 0.222468763589859
# 45509
# lse_loss -1.0832533836364746
# recon_loss 0.22837528586387634
# 45510
# lse_loss -1.0871052742004395
# recon_loss 0.22123436629772186
# 45511
# lse_loss -1.0981225967407227
# recon_loss 0.23321306705474854
# 45512
# lse_loss -1.0764126777648926
# recon_loss 0.21677999198436737
# 45513
# lse_loss -1.0840983390808105
# recon_loss 0.2209765613079071
# 45514
# lse_loss -1.0924463272094727
# recon_loss 0.24126867949962616
# 45515
# lse_loss -1.1167659759521484
# recon_loss 0.23201489448547363
# 45516
# lse_loss -1.11732816696167
# recon_loss 0.21543404459953308
# 45517
# lse_loss -1.0871987342834473
# recon_loss 0.23932473361492157
# 45518
# lse_loss -1.108471393585205
# recon_loss 0.23212771117687225
# 45519
# lse_loss -1.1329727172851562
# recon_loss 0.24120478332042694
# 45520
# lse_loss -1.0992488861083984
# recon_loss 0.22274643182754517
# 45521
# lse_loss -1.070645809173584
# recon_loss 0.21698734164237976
# 45522
# lse_loss -1.0973501205444336
# recon_loss 0.22362320125102997
# 45523
# lse_loss -1.117994785308838
# recon_loss 0.22055959701538086
# 45524
# lse_loss -1.121614933013916
# recon_loss 0.21946975588798523
# 45525
# lse_loss -1.1287360191345215
# recon_loss 0.23143504559993744
# 45526
# lse_loss -1.083747386932373
# recon_loss 0.22873035073280334
# 45527
# lse_loss -1.0961637496948242
# recon_loss 0.22106409072875977
# 45528
# lse_loss -1.083183765411377
# recon_loss 0.23117578029632568
# 45529
# lse_loss -1.1043896675109863
# recon_loss 0.2261980175971985
# 45530
# lse_loss -1.076676368713379
# recon_loss 0.24149176478385925
# 45531
# lse_loss -1.085700511932373
# recon_loss 0.2266962230205536
# 45532
# lse_loss -1.0844402313232422
# recon_loss 0.2293517291545868
# 45533
# lse_loss -1.0854744911193848
# recon_loss 0.2354440540075302
# 45534
# lse_loss -1.1424064636230469
# recon_loss 0.22282473742961884
# 45535
# lse_loss -1.1106185913085938
# recon_loss 0.22415170073509216
# 45536
# lse_loss -1.0754499435424805
# recon_loss 0.23428921401500702
# 45537
# lse_loss -1.1328110694885254
# recon_loss 0.2161853313446045
# 45538
# lse_loss -1.1069445610046387
# recon_loss 0.22409510612487793
# 45539
# lse_loss -1.0807600021362305
# recon_loss 0.2312096357345581
# 45540
# lse_loss -1.0822653770446777
# recon_loss 0.21846269071102142
# 45541
# lse_loss -1.0650033950805664
# recon_loss 0.2246606945991516
# 45542
# lse_loss -1.052649974822998
# recon_loss 0.2250383347272873
# 45543
# lse_loss -1.0924134254455566
# recon_loss 0.23061880469322205
# 45544
# lse_loss -1.0888471603393555
# recon_loss 0.22638782858848572
# 45545
# lse_loss -1.0709571838378906
# recon_loss 0.23038709163665771
# 45546
# lse_loss -1.1010165214538574
# recon_loss 0.23048368096351624
# 45547
# lse_loss -1.0770049095153809
# recon_loss 0.2298123687505722
# 45548
# lse_loss -1.1119842529296875
# recon_loss 0.2289486527442932
# 45549
# lse_loss -1.125256061553955
# recon_loss 0.2185237854719162
# 45550
# lse_loss -1.0638947486877441
# recon_loss 0.2241259217262268
# 45551
# lse_loss -1.0857439041137695
# recon_loss 0.21705222129821777
# 45552
# lse_loss -1.1048283576965332
# recon_loss 0.22227983176708221
# 45553
# lse_loss -1.138261318206787
# recon_loss 0.23912066221237183
# 45554
# lse_loss -1.096412181854248
# recon_loss 0.2248852699995041
# 45555
# lse_loss -1.1117100715637207
# recon_loss 0.22842662036418915
# 45556
# lse_loss -1.1124796867370605
# recon_loss 0.21962468326091766
# 45557
# lse_loss -1.0700392723083496
# recon_loss 0.2198908030986786
# 45558
# lse_loss -1.0793547630310059
# recon_loss 0.232949897646904
# 45559
# lse_loss -1.1208887100219727
# recon_loss 0.23607277870178223
# 45560
# lse_loss -1.131716251373291
# recon_loss 0.23475204408168793
# 45561
# lse_loss -1.1017098426818848
# recon_loss 0.2376234233379364
# 45562
# lse_loss -1.0958151817321777
# recon_loss 0.2323502004146576
# 45563
# lse_loss -1.0947051048278809
# recon_loss 0.22017256915569305
# 45564
# lse_loss -1.0807890892028809
# recon_loss 0.22686326503753662
# 45565
# lse_loss -1.0993289947509766
# recon_loss 0.22560253739356995
# 45566
# lse_loss -1.1291661262512207
# recon_loss 0.22259747982025146
# 45567
# lse_loss -1.0706572532653809
# recon_loss 0.22287188470363617
# 45568
# lse_loss -1.1129059791564941
# recon_loss 0.2234630584716797
# 45569
# lse_loss -1.11088228225708
# recon_loss 0.2107260674238205
# 45570
# lse_loss -1.1270689964294434
# recon_loss 0.22847795486450195
# 45571
# lse_loss -1.0782504081726074
# recon_loss 0.22912684082984924
# 45572
# lse_loss -1.1021957397460938
# recon_loss 0.23635336756706238
# 45573
# lse_loss -1.0864696502685547
# recon_loss 0.21924898028373718
# 45574
# lse_loss -1.0928568840026855
# recon_loss 0.22761587798595428
# 45575
# lse_loss -1.0905766487121582
# recon_loss 0.2248966544866562
# 45576
# lse_loss -1.1052203178405762
# recon_loss 0.21796584129333496
# 45577
# lse_loss -1.1058392524719238
# recon_loss 0.21404099464416504
# 45578
# lse_loss -1.0809283256530762
# recon_loss 0.23412130773067474
# 45579
# lse_loss -1.1148648262023926
# recon_loss 0.21450619399547577
# 45580
# lse_loss -1.1065497398376465
# recon_loss 0.23113200068473816
# 45581
# lse_loss -1.0923151969909668
# recon_loss 0.2361699342727661
# 45582
# lse_loss -1.083676815032959
# recon_loss 0.24247901141643524
# 45583
# lse_loss -1.1112866401672363
# recon_loss 0.23264311254024506
# 45584
# lse_loss -1.0893540382385254
# recon_loss 0.23123010993003845
# 45585
# lse_loss -1.0858120918273926
# recon_loss 0.22630682587623596
# 45586
# lse_loss -1.0953302383422852
# recon_loss 0.2227504551410675
# 45587
# lse_loss -1.1112656593322754
# recon_loss 0.23008523881435394
# 45588
# lse_loss -1.1111831665039062
# recon_loss 0.21328537166118622
# 45589
# lse_loss -1.1077837944030762
# recon_loss 0.21918174624443054
# 45590
# lse_loss -1.0985198020935059
# recon_loss 0.2258376181125641
# 45591
# lse_loss -1.1092982292175293
# recon_loss 0.22096507251262665
# 45592
# lse_loss -1.1361784934997559
# recon_loss 0.23193779587745667
# 45593
# lse_loss -1.1176600456237793
# recon_loss 0.22863726317882538
# 45594
# lse_loss -1.0803742408752441
# recon_loss 0.22496682405471802
# 45595
# lse_loss -1.0952062606811523
# recon_loss 0.21854257583618164
# 45596
# lse_loss -1.1251072883605957
# recon_loss 0.22815561294555664
# 45597
# lse_loss -1.087489128112793
# recon_loss 0.23218731582164764
# 45598
# lse_loss -1.1039977073669434
# recon_loss 0.2358599156141281
# 45599
# lse_loss -1.111661434173584
# recon_loss 0.22949104011058807
# 45600
# lse_loss -1.093778133392334
# recon_loss 0.22130262851715088
# 45601
# lse_loss -1.0683226585388184
# recon_loss 0.22766396403312683
# 45602
# lse_loss -1.0987820625305176
# recon_loss 0.2240367829799652
# 45603
# lse_loss -1.1189613342285156
# recon_loss 0.22299328446388245
# 45604
# lse_loss -1.1430935859680176
# recon_loss 0.22525493800640106
# 45605
# lse_loss -1.091346263885498
# recon_loss 0.22280031442642212
# 45606
# lse_loss -1.0617613792419434
# recon_loss 0.2289755791425705
# 45607
# lse_loss -1.0909743309020996
# recon_loss 0.21455582976341248
# 45608
# lse_loss -1.0777406692504883
# recon_loss 0.2347184419631958
# 45609
# lse_loss -1.0842185020446777
# recon_loss 0.22802302241325378
# 45610
# lse_loss -1.1216702461242676
# recon_loss 0.22418934106826782
# 45611
# lse_loss -1.1072964668273926
# recon_loss 0.21758298575878143
# 45612
# lse_loss -1.1002917289733887
# recon_loss 0.23101672530174255
# 45613
# lse_loss -1.1147446632385254
# recon_loss 0.2282119244337082
# 45614
# lse_loss -1.1181883811950684
# recon_loss 0.22658061981201172
# 45615
# lse_loss -1.1398820877075195
# recon_loss 0.21840128302574158
# 45616
# lse_loss -1.10919189453125
# recon_loss 0.221809983253479
# 45617
# lse_loss -1.1174392700195312
# recon_loss 0.21961453557014465
# 45618
# lse_loss -1.1184906959533691
# recon_loss 0.2223983258008957
# 45619
# lse_loss -1.0839953422546387
# recon_loss 0.21910959482192993
# 45620
# lse_loss -1.094316005706787
# recon_loss 0.22367793321609497
# 45621
# lse_loss -1.0818142890930176
# recon_loss 0.2292184829711914
# 45622
# lse_loss -1.05958890914917
# recon_loss 0.22992011904716492
# 45623
# lse_loss -1.0943551063537598
# recon_loss 0.22548559308052063
# 45624
# lse_loss -1.0887503623962402
# recon_loss 0.23850882053375244
# 45625
# lse_loss -1.0700531005859375
# recon_loss 0.219374880194664
# 45626
# lse_loss -1.1043972969055176
# recon_loss 0.21675562858581543
# 45627
# lse_loss -1.1058201789855957
# recon_loss 0.22465316951274872
# 45628
# lse_loss -1.0669121742248535
# recon_loss 0.23231439292430878
# 45629
# lse_loss -1.0910687446594238
# recon_loss 0.228928804397583
# 45630
# lse_loss -1.1036009788513184
# recon_loss 0.21946990489959717
# 45631
# lse_loss -1.0777478218078613
# recon_loss 0.22983703017234802
# 45632
# lse_loss -1.1218295097351074
# recon_loss 0.2162875235080719
# 45633
# lse_loss -1.1349492073059082
# recon_loss 0.22561560571193695
# 45634
# lse_loss -1.1107983589172363
# recon_loss 0.2265702486038208
# 45635
# lse_loss -1.0536532402038574
# recon_loss 0.2235402762889862
# 45636
# lse_loss -1.1262593269348145
# recon_loss 0.22244775295257568
# 45637
# lse_loss -1.1136765480041504
# recon_loss 0.22977304458618164
# 45638
# lse_loss -1.1237478256225586
# recon_loss 0.23016691207885742
# 45639
# lse_loss -1.0646791458129883
# recon_loss 0.21626584231853485
# 45640
# lse_loss -1.1374435424804688
# recon_loss 0.2211885154247284
# 45641
# lse_loss -1.1307063102722168
# recon_loss 0.22663891315460205
# 45642
# lse_loss -1.1142282485961914
# recon_loss 0.2217981070280075
# 45643
# lse_loss -1.0688772201538086
# recon_loss 0.2181781828403473
# 45644
# lse_loss -1.0906867980957031
# recon_loss 0.2378486841917038
# 45645
# lse_loss -1.0919251441955566
# recon_loss 0.22593018412590027
# 45646
# lse_loss -1.1165590286254883
# recon_loss 0.23233097791671753
# 45647
# lse_loss -1.0947222709655762
# recon_loss 0.23545005917549133
# 45648
# lse_loss -1.1355013847351074
# recon_loss 0.2259969413280487
# 45649
# lse_loss -1.1064801216125488
# recon_loss 0.22135183215141296
# 45650
# lse_loss -1.1398425102233887
# recon_loss 0.22250422835350037
# 45651
# lse_loss -1.1050057411193848
# recon_loss 0.2228468656539917
# 45652
# lse_loss -1.0972938537597656
# recon_loss 0.20873384177684784
# 45653
# lse_loss -1.1161551475524902
# recon_loss 0.20793557167053223
# 45654
# lse_loss -1.107698917388916
# recon_loss 0.22207951545715332
# 45655
# lse_loss -1.0875391960144043
# recon_loss 0.22734153270721436
# 45656
# lse_loss -1.112626552581787
# recon_loss 0.21841523051261902
# 45657
# lse_loss -1.101572036743164
# recon_loss 0.2220720648765564
# 45658
# lse_loss -1.0711312294006348
# recon_loss 0.2235957384109497
# 45659
# lse_loss -1.065627098083496
# recon_loss 0.21846869587898254
# 45660
# lse_loss -1.1043815612792969
# recon_loss 0.2404058277606964
# 45661
# lse_loss -1.0815391540527344
# recon_loss 0.22702191770076752
# 45662
# lse_loss -1.08671236038208
# recon_loss 0.21826714277267456
# 45663
# lse_loss -1.0718989372253418
# recon_loss 0.22849898040294647
# 45664
# lse_loss -1.1001534461975098
# recon_loss 0.22175318002700806
# 45665
# lse_loss -1.1025338172912598
# recon_loss 0.23061273992061615
# 45666
# lse_loss -1.0712347030639648
# recon_loss 0.22401079535484314
# 45667
# lse_loss -1.0795197486877441
# recon_loss 0.21762210130691528
# 45668
# lse_loss -1.0761585235595703
# recon_loss 0.2278747856616974
# 45669
# lse_loss -1.0840201377868652
# recon_loss 0.22794055938720703
# 45670
# lse_loss -1.0707287788391113
# recon_loss 0.22384047508239746
# 45671
# lse_loss -1.0994529724121094
# recon_loss 0.2363702952861786
# 45672
# lse_loss -1.1204113960266113
# recon_loss 0.21125367283821106
# 45673
# lse_loss -1.1275887489318848
# recon_loss 0.21379774808883667
# 45674
# lse_loss -1.1160783767700195
# recon_loss 0.21625922620296478
# 45675
# lse_loss -1.0756721496582031
# recon_loss 0.22253945469856262
# 45676
# lse_loss -1.1016144752502441
# recon_loss 0.21425127983093262
# 45677
# lse_loss -1.1138253211975098
# recon_loss 0.23073220252990723
# 45678
# lse_loss -1.1131377220153809
# recon_loss 0.22120164334774017
# 45679
# lse_loss -1.109921932220459
# recon_loss 0.2298632562160492
# 45680
# lse_loss -1.10966157913208
# recon_loss 0.22904756665229797
# 45681
# lse_loss -1.0926671028137207
# recon_loss 0.23345284163951874
# 45682
# lse_loss -1.099088191986084
# recon_loss 0.22922229766845703
# 45683
# lse_loss -1.0570626258850098
# recon_loss 0.22277438640594482
# 45684
# lse_loss -1.0679006576538086
# recon_loss 0.2303849458694458
# 45685
# lse_loss -1.0796961784362793
# recon_loss 0.22486290335655212
# 45686
# lse_loss -1.0914196968078613
# recon_loss 0.23490910232067108
# 45687
# lse_loss -1.0935406684875488
# recon_loss 0.21750685572624207
# 45688
# lse_loss -1.0999517440795898
# recon_loss 0.22765901684761047
# 45689
# lse_loss -1.124910831451416
# recon_loss 0.2326110601425171
# 45690
# lse_loss -1.1018481254577637
# recon_loss 0.22558145225048065
# 45691
# lse_loss -1.08195161819458
# recon_loss 0.2292405217885971
# 45692
# lse_loss -1.0554027557373047
# recon_loss 0.23499295115470886
# 45693
# lse_loss -1.0970368385314941
# recon_loss 0.2340366095304489
# 45694
# lse_loss -1.1164345741271973
# recon_loss 0.22207480669021606
# 45695
# lse_loss -1.101822853088379
# recon_loss 0.221735879778862
# 45696
# lse_loss -1.0885796546936035
# recon_loss 0.2219131886959076
# 45697
# lse_loss -1.1153473854064941
# recon_loss 0.22416767477989197
# 45698
# lse_loss -1.070167064666748
# recon_loss 0.2283267229795456
# 45699
# lse_loss -1.1360034942626953
# recon_loss 0.23635271191596985
# 45700
# lse_loss -1.1291184425354004
# recon_loss 0.24413785338401794
# 45701
# lse_loss -1.0786070823669434
# recon_loss 0.22962307929992676
# 45702
# lse_loss -1.0710711479187012
# recon_loss 0.22743277251720428
# 45703
# lse_loss -1.119278907775879
# recon_loss 0.23139795660972595
# 45704
# lse_loss -1.111717700958252
# recon_loss 0.2169315069913864
# 45705
# lse_loss -1.111158847808838
# recon_loss 0.22470933198928833
# 45706
# lse_loss -1.092071533203125
# recon_loss 0.2278331220149994
# 45707
# lse_loss -1.1409945487976074
# recon_loss 0.23389148712158203
# 45708
# lse_loss -1.1009035110473633
# recon_loss 0.2274588644504547
# 45709
# lse_loss -1.108607292175293
# recon_loss 0.2285485714673996
# 45710
# lse_loss -1.1034483909606934
# recon_loss 0.22728216648101807
# 45711
# lse_loss -1.1096515655517578
# recon_loss 0.22239002585411072
# 45712
# lse_loss -1.052968978881836
# recon_loss 0.219722718000412
# 45713
# lse_loss -1.1024518013000488
# recon_loss 0.21432620286941528
# 45714
# lse_loss -1.1086440086364746
# recon_loss 0.2229999154806137
# 45715
# lse_loss -1.0927348136901855
# recon_loss 0.2383534163236618
# 45716
# lse_loss -1.0776557922363281
# recon_loss 0.22535984218120575
# 45717
# lse_loss -1.0944180488586426
# recon_loss 0.23021404445171356
# 45718
# lse_loss -1.0820565223693848
# recon_loss 0.22757574915885925
# 45719
# lse_loss -1.1704506874084473
# recon_loss 0.2310190200805664
# 45720
# lse_loss -1.0779142379760742
# recon_loss 0.2281005084514618
# 45721
# lse_loss -1.1033401489257812
# recon_loss 0.22893349826335907
# 45722
# lse_loss -1.110053539276123
# recon_loss 0.23034128546714783
# 45723
# lse_loss -1.0769615173339844
# recon_loss 0.22740042209625244
# 45724
# lse_loss -1.1127562522888184
# recon_loss 0.2221686840057373
# 45725
# lse_loss -1.0878996849060059
# recon_loss 0.2278478592634201
# 45726
# lse_loss -1.0700368881225586
# recon_loss 0.21378539502620697
# 45727
# lse_loss -1.0968947410583496
# recon_loss 0.2205485999584198
# 45728
# lse_loss -1.1117281913757324
# recon_loss 0.22458496689796448
# 45729
# lse_loss -1.1165261268615723
# recon_loss 0.22486117482185364
# 45730
# lse_loss -1.1009831428527832
# recon_loss 0.22180089354515076
# 45731
# lse_loss -1.106400966644287
# recon_loss 0.20693093538284302
# 45732
# lse_loss -1.1348133087158203
# recon_loss 0.2229660451412201
# 45733
# lse_loss -1.099381923675537
# recon_loss 0.22496715188026428
# 45734
# lse_loss -1.0921072959899902
# recon_loss 0.23396365344524384
# 45735
# lse_loss -1.09495210647583
# recon_loss 0.22501182556152344
# 45736
# lse_loss -1.0937705039978027
# recon_loss 0.2385627031326294
# 45737
# lse_loss -1.0889554023742676
# recon_loss 0.2193165123462677
# 45738
# lse_loss -1.1371254920959473
# recon_loss 0.2282862365245819
# 45739
# lse_loss -1.1089043617248535
# recon_loss 0.21824876964092255
# 45740
# lse_loss -1.0837244987487793
# recon_loss 0.2376398891210556
# 45741
# lse_loss -1.0571494102478027
# recon_loss 0.23009797930717468
# 45742
# lse_loss -1.1155333518981934
# recon_loss 0.21113333106040955
# 45743
# lse_loss -1.1207661628723145
# recon_loss 0.22648382186889648
# 45744
# lse_loss -1.0935420989990234
# recon_loss 0.22232560813426971
# 45745
# lse_loss -1.0925517082214355
# recon_loss 0.22576531767845154
# 45746
# lse_loss -1.1151127815246582
# recon_loss 0.2325725257396698
# 45747
# lse_loss -1.0892348289489746
# recon_loss 0.21967798471450806
# 45748
# lse_loss -1.0752243995666504
# recon_loss 0.23723316192626953
# 45749
# lse_loss -1.1083769798278809
# recon_loss 0.23376981914043427
# 45750
# lse_loss -1.0907254219055176
# recon_loss 0.22501258552074432
# 45751
# lse_loss -1.1163520812988281
# recon_loss 0.22732612490653992
# 45752
# lse_loss -1.1232409477233887
# recon_loss 0.22635678946971893
# 45753
# lse_loss -1.1324567794799805
# recon_loss 0.2268335074186325
# 45754
# lse_loss -1.0868725776672363
# recon_loss 0.22993378341197968
# 45755
# lse_loss -1.0958313941955566
# recon_loss 0.23165082931518555
# 45756
# lse_loss -1.07828950881958
# recon_loss 0.22090694308280945
# 45757
# lse_loss -1.1258459091186523
# recon_loss 0.22734378278255463
# 45758
# lse_loss -1.0643854141235352
# recon_loss 0.22251757979393005
# 45759
# lse_loss -1.1514906883239746
# recon_loss 0.21748477220535278
# 45760
# lse_loss -1.1063132286071777
# recon_loss 0.21984848380088806
# 45761
# lse_loss -1.0670161247253418
# recon_loss 0.22725149989128113
# 45762
# lse_loss -1.1275811195373535
# recon_loss 0.23506121337413788
# 45763
# lse_loss -1.1223578453063965
# recon_loss 0.2131841480731964
# 45764
# lse_loss -1.07476806640625
# recon_loss 0.21870015561580658
# 45765
# lse_loss -1.1098132133483887
# recon_loss 0.22303438186645508
# 45766
# lse_loss -1.0884804725646973
# recon_loss 0.2199144810438156
# 45767
# lse_loss -1.0852694511413574
# recon_loss 0.2226170003414154
# 45768
# lse_loss -1.1032557487487793
# recon_loss 0.22701512277126312
# 45769
# lse_loss -1.0926356315612793
# recon_loss 0.22550633549690247
# 45770
# lse_loss -1.063321590423584
# recon_loss 0.22668325901031494
# 45771
# lse_loss -1.1355719566345215
# recon_loss 0.22428962588310242
# 45772
# lse_loss -1.0883393287658691
# recon_loss 0.23150920867919922
# 45773
# lse_loss -1.1273212432861328
# recon_loss 0.22262588143348694
# 45774
# lse_loss -1.093818187713623
# recon_loss 0.21951976418495178
# 45775
# lse_loss -1.0955204963684082
# recon_loss 0.2310703694820404
# 45776
# lse_loss -1.0660462379455566
# recon_loss 0.2255011796951294
# 45777
# lse_loss -1.0921177864074707
# recon_loss 0.22137826681137085
# 45778
# lse_loss -1.1220393180847168
# recon_loss 0.2196047306060791
# 45779
# lse_loss -1.1070632934570312
# recon_loss 0.22137954831123352
# 45780
# lse_loss -1.0730857849121094
# recon_loss 0.23257307708263397
# 45781
# lse_loss -1.0630254745483398
# recon_loss 0.23741769790649414
# 45782
# lse_loss -1.1082038879394531
# recon_loss 0.22393527626991272
# 45783
# lse_loss -1.1114201545715332
# recon_loss 0.23010222613811493
# 45784
# lse_loss -1.1086134910583496
# recon_loss 0.22718846797943115
# 45785
# lse_loss -1.0924897193908691
# recon_loss 0.23925253748893738
# 45786
# lse_loss -1.0930962562561035
# recon_loss 0.2253360003232956
# 45787
# lse_loss -1.0718669891357422
# recon_loss 0.22956112027168274
# 45788
# lse_loss -1.0741081237792969
# recon_loss 0.22431252896785736
# 45789
# lse_loss -1.1016812324523926
# recon_loss 0.2297239601612091
# 45790
# lse_loss -1.0854887962341309
# recon_loss 0.22355620563030243
# 45791
# lse_loss -1.0876927375793457
# recon_loss 0.22710347175598145
# 45792
# lse_loss -1.0810604095458984
# recon_loss 0.21182022988796234
# 45793
# lse_loss -1.0828423500061035
# recon_loss 0.22971385717391968
# 45794
# lse_loss -1.0959210395812988
# recon_loss 0.2338828444480896
# 45795
# lse_loss -1.0516400337219238
# recon_loss 0.21598291397094727
# 45796
# lse_loss -1.0870518684387207
# recon_loss 0.22554288804531097
# 45797
# lse_loss -1.0895752906799316
# recon_loss 0.22483932971954346
# 45798
# lse_loss -1.1224265098571777
# recon_loss 0.22129690647125244
# 45799
# lse_loss -1.0940427780151367
# recon_loss 0.22077833116054535
# 45800
# lse_loss -1.0868945121765137
# recon_loss 0.22419099509716034
# 45801
# lse_loss -1.099494457244873
# recon_loss 0.22113732993602753
# 45802
# lse_loss -1.105818748474121
# recon_loss 0.2218330353498459
# 45803
# lse_loss -1.0665431022644043
# recon_loss 0.22151270508766174
# 45804
# lse_loss -1.070718765258789
# recon_loss 0.23204706609249115
# 45805
# lse_loss -1.1269221305847168
# recon_loss 0.22190183401107788
# 45806
# lse_loss -1.1105875968933105
# recon_loss 0.2239379584789276
# 45807
# lse_loss -1.083366870880127
# recon_loss 0.2236628532409668
# 45808
# lse_loss -1.094353199005127
# recon_loss 0.22488272190093994
# 45809
# lse_loss -1.1109123229980469
# recon_loss 0.21916459500789642
# 45810
# lse_loss -1.1017975807189941
# recon_loss 0.23271726071834564
# 45811
# lse_loss -1.1149563789367676
# recon_loss 0.21962253749370575
# 45812
# lse_loss -1.0809979438781738
# recon_loss 0.2321975827217102
# 45813
# lse_loss -1.1234745979309082
# recon_loss 0.21461766958236694
# 45814
# lse_loss -1.102614402770996
# recon_loss 0.22235900163650513
# 45815
# lse_loss -1.094644546508789
# recon_loss 0.226139098405838
# 45816
# lse_loss -1.0971312522888184
# recon_loss 0.2406887263059616
# 45817
# lse_loss -1.1004977226257324
# recon_loss 0.22682109475135803
# 45818
# lse_loss -1.0942301750183105
# recon_loss 0.2406126707792282
# 45819
# lse_loss -1.0858263969421387
# recon_loss 0.2240682691335678
# 45820
# lse_loss -1.0636687278747559
# recon_loss 0.22393956780433655
# 45821
# lse_loss -1.114880084991455
# recon_loss 0.2346189022064209
# 45822
# lse_loss -1.1007423400878906
# recon_loss 0.2202361673116684
# 45823
# lse_loss -1.0825376510620117
# recon_loss 0.2240464687347412
# 45824
# lse_loss -1.0537109375
# recon_loss 0.22202953696250916
# 45825
# lse_loss -1.131378173828125
# recon_loss 0.2241429090499878
# 45826
# lse_loss -1.0757813453674316
# recon_loss 0.22249655425548553
# 45827
# lse_loss -1.1411151885986328
# recon_loss 0.23032818734645844
# 45828
# lse_loss -1.0718293190002441
# recon_loss 0.22292809188365936
# 45829
# lse_loss -1.092115879058838
# recon_loss 0.22944137454032898
# 45830
# lse_loss -1.0759377479553223
# recon_loss 0.22880271077156067
# 45831
# lse_loss -1.099827766418457
# recon_loss 0.24446217715740204
# 45832
# lse_loss -1.11091947555542
# recon_loss 0.23080448806285858
# 45833
# lse_loss -1.1150946617126465
# recon_loss 0.23109766840934753
# 45834
# lse_loss -1.105391025543213
# recon_loss 0.2281922996044159
# 45835
# lse_loss -1.1012187004089355
# recon_loss 0.23023340106010437
# 45836
# lse_loss -1.1095538139343262
# recon_loss 0.2244066447019577
# 45837
# lse_loss -1.092569351196289
# recon_loss 0.22753196954727173
# 45838
# lse_loss -1.1286406517028809
# recon_loss 0.22631990909576416
# 45839
# lse_loss -1.098188877105713
# recon_loss 0.2310229241847992
# 45840
# lse_loss -1.0786328315734863
# recon_loss 0.22012066841125488
# 45841
# lse_loss -1.1108970642089844
# recon_loss 0.22923491895198822
# 45842
# lse_loss -1.0839028358459473
# recon_loss 0.23345038294792175
# 45843
# lse_loss -1.0705351829528809
# recon_loss 0.22260010242462158
# 45844
# lse_loss -1.104433536529541
# recon_loss 0.22843322157859802
# 45845
# lse_loss -1.110145092010498
# recon_loss 0.21773521602153778
