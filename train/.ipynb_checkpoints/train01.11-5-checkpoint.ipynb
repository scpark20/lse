# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="5"
# Out:
# Fri Jan 12 19:46:40 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   25C    P8    13W / 230W |  17558MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   47C    P2    93W / 230W |   4168MiB / 24564MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   44C    P2    96W / 230W |   4166MiB / 24564MiB |     28%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 35%   62C    P2   184W / 230W |   8326MiB / 24564MiB |     54%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   48C    P2   107W / 230W |   4166MiB / 24564MiB |     26%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   47C    P0    83W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   49C    P2   101W / 230W |   4168MiB / 24564MiB |     26%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   47C    P2   100W / 230W |   4168MiB / 24564MiB |     30%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2106188      C   ...onda3/envs/ste/bin/python    17550MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2107530      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   2112999      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   2107604      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    3   N/A  N/A   2113085      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2113172      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A   2107345      C   ...onda3/envs/ste/bin/python     4160MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A   2107447      C   ...onda3/envs/ste/bin/python     4160MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.uniform_lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.004646301269531
# encoder.convs 5.989013671875
# encoder.linear 0.01563262939453125
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.11-5/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 570136
# -rw-rw-r-- 1 scpark scpark  5026164  1월 12 19:46 events.out.tfevents.1705053976.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 19:45 save_50000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 19:37 save_40000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 19:29 save_30000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 19:21 save_20000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 19:14 save_10000
# -rw-rw-r-- 1 scpark scpark 37973949  1월 12 19:06 save_0
# -rw-rw-r-- 1 scpark scpark 13517276  1월 12 19:06 events.out.tfevents.1705046984.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37979957  1월 12 18:59 save_130000
# -rw-rw-r-- 1 scpark scpark 37979957  1월 12 18:50 save_120000
# -rw-rw-r-- 1 scpark scpark 37979957  1월 12 18:42 save_110000
# -rw-rw-r-- 1 scpark scpark 37979957  1월 12 18:33 save_100000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 18:25 save_90000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 18:17 save_80000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 18:08 save_70000
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 18:00 save_60000
# -rw-rw-r-- 1 scpark scpark  2853798  1월 12 17:09 events.out.tfevents.1705045544.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   981572  1월 12 16:45 events.out.tfevents.1705045060.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   510404  1월 12 16:37 events.out.tfevents.1705044791.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  9690866  1월 12 16:33 events.out.tfevents.1705039944.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1699162  1월 12 15:12 events.out.tfevents.1705039065.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1533572  1월 12 14:57 events.out.tfevents.1705038275.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  4910132  1월 12 00:52 events.out.tfevents.1704985950.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1236740  1월 12 00:12 events.out.tfevents.1704985349.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   791876  1월 12 00:02 events.out.tfevents.1704984938.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   392708  1월 11 23:55 events.out.tfevents.1704984728.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1111844  1월 11 22:02 events.out.tfevents.1704977565.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   956624  1월 11 21:52 events.out.tfevents.1704977070.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  5403856  1월 11 21:44 events.out.tfevents.1704974497.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   477776  1월 11 21:01 events.out.tfevents.1704974263.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   914756  1월 11 20:57 events.out.tfevents.1704973804.GPUSVR01

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=1000, sigma=0.10)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000, sigma=1)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 116001
# lse_loss 0.2778211236000061
# recon_loss 0.14461404085159302
# 116002
# lse_loss 0.2741723954677582
# recon_loss 0.14740292727947235
# 116003
# lse_loss 0.3288266658782959
# recon_loss 0.16247780621051788
# 116004
# lse_loss 0.25314080715179443
# recon_loss 0.1584583967924118
# 116005
# lse_loss 0.3623412549495697
# recon_loss 0.14750176668167114
# 116006
# lse_loss 0.20271722972393036
# recon_loss 0.14331679046154022
# 116007
# lse_loss 0.1962890923023224
# recon_loss 0.13682472705841064
# 116008
# lse_loss 0.24081462621688843
# recon_loss 0.1415470689535141
# 116009
# lse_loss 0.43522775173187256
# recon_loss 0.14798015356063843
# 116010
# lse_loss 0.22253195941448212
# recon_loss 0.14513230323791504
# 116011
# lse_loss 0.23068121075630188
# recon_loss 0.14900067448616028
# 116012
# lse_loss 0.2988458275794983
# recon_loss 0.1397475004196167
# 116013
# lse_loss 0.3906359374523163
# recon_loss 0.14157825708389282
# 116014
# lse_loss 0.26497724652290344
# recon_loss 0.14350250363349915
# 116015
# lse_loss 0.24709242582321167
# recon_loss 0.14074575901031494
# 116016
# lse_loss 0.20780332386493683
# recon_loss 0.13626708090305328
# 116017
# lse_loss 0.2222447395324707
# recon_loss 0.13563501834869385
# 116018
# lse_loss 0.3520759344100952
# recon_loss 0.14503608644008636
# 116019
# lse_loss 0.23837070167064667
# recon_loss 0.14463183283805847
# 116020
# lse_loss 0.3209531009197235
# recon_loss 0.13357362151145935
# 116021
# lse_loss 0.26038283109664917
# recon_loss 0.14045995473861694
# 116022
# lse_loss 0.2573550045490265
# recon_loss 0.13855746388435364
# 116023
# lse_loss 0.27150577306747437
# recon_loss 0.13740599155426025
# 116024
# lse_loss 0.27178406715393066
# recon_loss 0.14321041107177734
# 116025
# lse_loss 0.26259645819664
# recon_loss 0.1429259330034256
# 116026
# lse_loss 0.2694229781627655
# recon_loss 0.1389887034893036
# 116027
# lse_loss 0.30061066150665283
# recon_loss 0.14611515402793884
# 116028
# lse_loss 0.292681485414505
# recon_loss 0.15536406636238098
# 116029
# lse_loss 0.2072555422782898
# recon_loss 0.1418759971857071
# 116030
# lse_loss 0.2701384425163269
# recon_loss 0.1464262455701828
# 116031
# lse_loss 0.28798824548721313
# recon_loss 0.13834771513938904
# 116032
# lse_loss 0.15739063918590546
# recon_loss 0.1451449692249298
# 116033
# lse_loss 0.18869097530841827
# recon_loss 0.1397913694381714
# 116034
# lse_loss 0.227484792470932
# recon_loss 0.14259138703346252
# 116035
# lse_loss 0.27659523487091064
# recon_loss 0.14393413066864014
# 116036
# lse_loss 0.1806688904762268
# recon_loss 0.15417811274528503
# 116037
# lse_loss 0.20707370340824127
# recon_loss 0.14301881194114685
# 116038
# lse_loss 0.19745813310146332
# recon_loss 0.13547545671463013
# 116039
# lse_loss 0.32061707973480225
# recon_loss 0.15752120316028595
# 116040
# lse_loss 0.20351076126098633
# recon_loss 0.1360006332397461
