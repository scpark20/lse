# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# Sat Jan 13 22:22:48 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   25C    P8    13W / 230W |  17558MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 35%   57C    P2    97W / 230W |   4906MiB / 24564MiB |     20%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   55C    P2   125W / 230W |   4166MiB / 24564MiB |     23%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 32%   56C    P2   138W / 230W |   8322MiB / 24564MiB |     26%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   48C    P2   107W / 230W |   4166MiB / 24564MiB |     27%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   46C    P2    96W / 230W |   4166MiB / 24564MiB |     27%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   46C    P2    99W / 230W |   4166MiB / 24564MiB |     29%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   44C    P2    81W / 230W |   4166MiB / 24564MiB |     28%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2106188      C   ...onda3/envs/ste/bin/python    17550MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2307797      C   ...onda3/envs/ste/bin/python      394MiB |
# |    1   N/A  N/A   2329884      C   ...onda3/envs/ste/bin/python     4162MiB |
# |    1   N/A  N/A   2330631      C   ...onda3/envs/ste/bin/python      342MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   2329962      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   2329982      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    3   N/A  N/A   2330556      C   ...onda3/envs/ste/bin/python     4156MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2330059      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   2330137      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A   2330213      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A   2330468      C   ...onda3/envs/ste/bin/python     4158MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.uniform_min_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.004646301269531
# encoder.convs 5.989013671875
# encoder.linear 0.01563262939453125
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.11-10/'

# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 0

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=1000, sigma=1e-1)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000, sigma=1e-1)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 12001
# lse_loss 0.01033646147698164
# 12002
# lse_loss 0.011771563440561295
# 12003
# lse_loss 0.010614009574055672
# 12004
# lse_loss 0.012403640896081924
# 12005
# lse_loss 0.010790434665977955
# 12006
# lse_loss 0.01126021333038807
# 12007
# lse_loss 0.011075705289840698
# 12008
# lse_loss 0.010642336681485176
# 12009
# lse_loss 0.011128456331789494
# 12010
# lse_loss 0.01166574563831091
# 12011
# lse_loss 0.010258861817419529
# 12012
# lse_loss 0.009481062181293964
# 12013
# lse_loss 0.011797052808105946
# 12014
# lse_loss 0.011242677457630634
# 12015
# lse_loss 0.013479791581630707
# 12016
# lse_loss 0.013232623226940632
# lse_loss 0.011269370093941689
# 12151
# lse_loss 0.00958422664552927
# 12152
# lse_loss 0.011886854656040668
# 12153
# lse_loss 0.012196949683129787
# 12154
# lse_loss 0.010586551390588284
# 12155
# lse_loss 0.010130347684025764
# 12156
# lse_loss 0.01061992160975933
# 12157
# lse_loss 0.01135418564081192
# 12158
# lse_loss 0.012423548847436905
# 12159
# lse_loss 0.01046199630945921
# 12160
# lse_loss 0.010441988706588745
# 12161
# lse_loss 0.010951612144708633
# 12162
# lse_loss 0.010640806518495083
# 12163
# lse_loss 0.010634194128215313
# 12164
# lse_loss 0.00968372542411089
# 12165
# lse_loss 0.00972140021622181
# 12166
# lse_loss 0.010895941406488419
# 12167
# lse_loss 0.00930138397961855
# 12168
# lse_loss 0.01014407817274332
# 12169
# lse_loss 0.011022835969924927
# 12170
# lse_loss 0.011170677840709686
# 12171
# lse_loss 0.010615319013595581
# 12172
# lse_loss 0.011025585234165192
# 12173
# lse_loss 0.009808823466300964
# 12174
# lse_loss 0.010254534892737865
# 12175
# lse_loss 0.012007428333163261
# 12176
# lse_loss 0.010464445687830448
# 12177
# lse_loss 0.009329683147370815
# 12178
# lse_loss 0.011150015518069267
# 12179
# lse_loss 0.012155482545495033
# 12180
# lse_loss 0.011182889342308044
# 12181
# lse_loss 0.00967980083078146
# 12182
# lse_loss 0.012151602655649185
# 12183
# lse_loss 0.009700202383100986
# 12184
# lse_loss 0.011476864106953144
# 12185
# lse_loss 0.011587287299335003
# 12186
# lse_loss 0.010951433330774307
# 12187
# lse_loss 0.01034198235720396
# 12188
# lse_loss 0.011927245184779167
# 12189
# lse_loss 0.010648135095834732
# 12190
# lse_loss 0.011665279977023602
# 12191
# lse_loss 0.008897400461137295
# 12192
# lse_loss 0.009971232153475285
# 12193
# lse_loss 0.012837141752243042
# 12194
# lse_loss 0.010590997524559498
# 12195
# lse_loss 0.008849486708641052
# 12196
# lse_loss 0.013113286346197128
# 12197
# lse_loss 0.009071169421076775
# 12198
# lse_loss 0.010365181602537632
# 12199
# lse_loss 0.012708199210464954
# 12200
# lse_loss 0.011207056231796741
# 12201
# lse_loss 0.009644432924687862
# 12202
# lse_loss 0.013036532327532768
# 12203
# lse_loss 0.01136957760900259
# 12204
# lse_loss 0.009787149727344513
# 12205
# lse_loss 0.009674496948719025
# 12206
# lse_loss 0.010622506029903889
# 12207
# lse_loss 0.010517900809645653
# 12208
# lse_loss 0.011308838613331318
# 12209
# lse_loss 0.011741604655981064
# 12210
# lse_loss 0.011598187498748302
# 12211
# lse_loss 0.010486500337719917
# 12212
# lse_loss 0.00970819778740406
# 12213
# lse_loss 0.009340118616819382
# 12214
# lse_loss 0.009734096936881542
# 12215
# lse_loss 0.010958299040794373
# 12216
# lse_loss 0.010991101153194904
# 12217
