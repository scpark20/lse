# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="5"
# Out:
# Fri Jan 12 00:35:04 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   25C    P8    14W / 230W |      8MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   44C    P2    78W / 230W |   3910MiB / 24564MiB |     21%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   59C    P2   175W / 230W |   8362MiB / 24564MiB |     53%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   57C    P2   183W / 230W |   8362MiB / 24564MiB |     53%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   57C    P2   186W / 230W |   8362MiB / 24564MiB |     51%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   48C    P2   101W / 230W |   4186MiB / 24564MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   26C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   25C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   1944942      C   ...onda3/envs/ste/bin/python     3902MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   1944283      C   ...onda3/envs/ste/bin/python     4178MiB |
# |    2   N/A  N/A   1948078      C   ...onda3/envs/ste/bin/python     4176MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   1944360      C   ...onda3/envs/ste/bin/python     4178MiB |
# |    3   N/A  N/A   1948157      C   ...onda3/envs/ste/bin/python     4176MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   1944460      C   ...onda3/envs/ste/bin/python     4178MiB |
# |    4   N/A  N/A   1948255      C   ...onda3/envs/ste/bin/python     4176MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   1944544      C   ...onda3/envs/ste/bin/python     4178MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.004646301269531
# encoder.convs 5.989013671875
# encoder.linear 0.01563262939453125
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.11-9/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 80652
# -rw-rw-r-- 1 scpark scpark  1040228  1월 12 00:09 events.out.tfevents.1704985376.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37979741  1월 12 00:09 save_10000
# -rw-rw-r-- 1 scpark scpark 37973949  1월 12 00:03 save_0
# -rw-rw-r-- 1 scpark scpark   833828  1월 12 00:02 events.out.tfevents.1704985071.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   421604  1월 11 23:57 events.out.tfevents.1704984899.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   561380  1월 11 23:54 events.out.tfevents.1704984683.GPUSVR01
# -rw-rw-r-- 1 scpark scpark    63236  1월 11 22:02 events.out.tfevents.1704978112.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1077284  1월 11 22:01 events.out.tfevents.1704977553.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   955364  1월 11 21:52 events.out.tfevents.1704977049.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1662314  1월 11 21:44 events.out.tfevents.1704976175.GPUSVR01

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=10000, sigma=8e-0)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000, sigma=1e-1)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 21001
# lse_loss -4.835471153259277
# recon_loss 0.09889070689678192
# 21002
# lse_loss -4.835022449493408
# recon_loss 0.10919036716222763
# 21003
# lse_loss -4.835299968719482
# recon_loss 0.09941408038139343
# 21004
# lse_loss -4.835168361663818
# recon_loss 0.10549582540988922
# 21005
# lse_loss -4.835066318511963
# recon_loss 0.10001572221517563
# 21006
# lse_loss -4.835238456726074
# recon_loss 0.10674908012151718
# 21007
# lse_loss -4.835143566131592
# recon_loss 0.10235549509525299
# 21008
# lse_loss -4.835371494293213
# recon_loss 0.11045732349157333
# 21009
# lse_loss -4.835231781005859
# recon_loss 0.09895243495702744
# 21010
# lse_loss -4.835721015930176
# recon_loss 0.11118167638778687
# 21011
# lse_loss -4.835322380065918
# recon_loss 0.10557680577039719
# 21012
# lse_loss -4.835231781005859
# recon_loss 0.11297103762626648
# 21013
# lse_loss -4.83489990234375
# recon_loss 0.0996595025062561
# 21014
# lse_loss -4.835341930389404
# recon_loss 0.10187038034200668
# 21015
# lse_loss -4.835596561431885
# recon_loss 0.10373031347990036
# 21016
# lse_loss -4.834996223449707
# recon_loss 0.10410743951797485
# 21017
# lse_loss -4.835319519042969
# recon_loss 0.10643484443426132
# 21018
# lse_loss -4.835244178771973
# recon_loss 0.09450297802686691
# 21019
# lse_loss -4.835063934326172
# recon_loss 0.10695956647396088
# 21020
# lse_loss -4.835226535797119
# recon_loss 0.10502715408802032
# 21021
# lse_loss -4.83548641204834
# recon_loss 0.10399025678634644
# 21022
# lse_loss -4.8349480628967285
# recon_loss 0.10783743858337402
# 21023
# lse_loss -4.835108757019043
# recon_loss 0.10632936656475067
# 21024
# lse_loss -4.835170745849609
# recon_loss 0.10837399959564209
# 21025
# lse_loss -4.835414886474609
# recon_loss 0.09846412390470505
# 21026
# lse_loss -4.835353851318359
# recon_loss 0.10232996940612793
# 21027
# lse_loss -4.83577823638916
# recon_loss 0.10142193734645844
# 21028
# lse_loss -4.835353851318359
# recon_loss 0.09971525520086288
# 21029
# lse_loss -4.8353047370910645
# recon_loss 0.10248969495296478
# 21030
# lse_loss -4.8350419998168945
# recon_loss 0.10747729241847992
# 21031
# lse_loss -4.835241317749023
# recon_loss 0.09573512524366379
# 21032
# lse_loss -4.83498477935791
# recon_loss 0.09876732528209686
# 21033
# lse_loss -4.835347652435303
# recon_loss 0.09848351776599884
# 21034
# lse_loss -4.835479259490967
# recon_loss 0.09679494798183441
# 21035
# lse_loss -4.8352484703063965
# recon_loss 0.09786571562290192
# 21036
# lse_loss -4.835256099700928
# recon_loss 0.10743914544582367
# 21037
# lse_loss -4.835356712341309
# recon_loss 0.11277920007705688
# 21038
# lse_loss -4.835206031799316
# recon_loss 0.09855266660451889
# 21039
# lse_loss -4.835186004638672
# recon_loss 0.09842047095298767
# 21040
# lse_loss -4.834913730621338
# recon_loss 0.10078869760036469
# 21041
# lse_loss -4.835470199584961
# recon_loss 0.09476395696401596
# 21042
# lse_loss -4.8351874351501465
# recon_loss 0.0987710952758789
# 21043
# lse_loss -4.835297584533691
# recon_loss 0.10161443799734116
# 21044
# lse_loss -4.8350067138671875
# recon_loss 0.10179387032985687
# 21045
# lse_loss -4.835081100463867
# recon_loss 0.094638392329216
# 21046
# lse_loss -4.835249900817871
# recon_loss 0.09349974989891052
# 21047
# lse_loss -4.835098743438721
# recon_loss 0.1079857349395752
# 21048
# lse_loss -4.835416793823242
# recon_loss 0.10768884420394897
# 21049
# lse_loss -4.835205554962158
# recon_loss 0.10533121228218079
# 21050
# lse_loss -4.835002422332764
# recon_loss 0.10631291568279266
# 21051
# lse_loss -4.835121154785156
# recon_loss 0.10036303102970123
# 21052
# lse_loss -4.834813117980957
# recon_loss 0.09491090476512909
# 21053
# lse_loss -4.835395336151123
# recon_loss 0.10828891396522522
# 21054
# lse_loss -4.835500717163086
# recon_loss 0.09567805379629135
# 21055
# lse_loss -4.835206985473633
# recon_loss 0.10727259516716003
# 21056
# lse_loss -4.835273742675781
# recon_loss 0.10851436853408813
# 21057
# lse_loss -4.835634231567383
# recon_loss 0.09771250188350677
# 21058
# lse_loss -4.835403919219971
# recon_loss 0.10418792068958282
# 21059
# lse_loss -4.835003852844238
# recon_loss 0.09982433170080185
# 21060
# lse_loss -4.834944248199463
# recon_loss 0.10472725331783295
# 21061
# lse_loss -4.835211753845215
# recon_loss 0.10863890498876572
# 21062
# lse_loss -4.835305690765381
# recon_loss 0.10141347348690033
# 21063
# lse_loss -4.835176467895508
# recon_loss 0.10416704416275024
# 21064
# lse_loss -4.834924697875977
# recon_loss 0.09996706247329712
# 21065
# lse_loss -4.835192680358887
# recon_loss 0.10166369378566742
# 21066
# lse_loss -4.835244178771973
# recon_loss 0.10921846330165863
# 21067
# lse_loss -4.834895133972168
# recon_loss 0.09150674939155579
# 21068
# lse_loss -4.834956169128418
# recon_loss 0.10150542110204697
# 21069
# lse_loss -4.835128307342529
# recon_loss 0.10934676975011826
# 21070
# lse_loss -4.835162162780762
# recon_loss 0.09943553805351257
# 21071
# lse_loss -4.83519172668457
# recon_loss 0.10652707517147064
# 21072
# lse_loss -4.835583686828613
# recon_loss 0.10040001571178436
# 21073
# lse_loss -4.834757328033447
# recon_loss 0.09532514214515686
# 21074
# lse_loss -4.83525276184082
# recon_loss 0.10723689198493958
# 21075
# lse_loss -4.8351359367370605
# recon_loss 0.09778062999248505
# 21076
# lse_loss -4.8351545333862305
# recon_loss 0.10623064637184143
# 21077
# lse_loss -4.835219383239746
# recon_loss 0.1003677248954773
# 21078
# lse_loss -4.835261821746826
# recon_loss 0.09945051372051239
# 21079
# lse_loss -4.835353374481201
# recon_loss 0.10339262336492538
# 21080
# lse_loss -4.8352837562561035
# recon_loss 0.10224545001983643
# 21081
# lse_loss -4.835370063781738
# recon_loss 0.09587904810905457
# 21082
# lse_loss -4.834963321685791
# recon_loss 0.09536342322826385
# 21083
# lse_loss -4.835204601287842
# recon_loss 0.10088838636875153
# 21084
# lse_loss -4.8352742195129395
# recon_loss 0.09980877488851547
# 21085
# lse_loss -4.835197925567627
# recon_loss 0.09588073194026947
# 21086
# lse_loss -4.835535049438477
# recon_loss 0.10318398475646973
# 21087
# lse_loss -4.83502197265625
# recon_loss 0.09633944928646088
# 21088
# lse_loss -4.835396766662598
# recon_loss 0.095847487449646
# 21089
# lse_loss -4.835154056549072
# recon_loss 0.10890400409698486
# 21090
# lse_loss -4.835165977478027
# recon_loss 0.10305643081665039
# 21091
# lse_loss -4.835144996643066
# recon_loss 0.10218900442123413
# 21092
# lse_loss -4.835309028625488
# recon_loss 0.09818460792303085
# 21093
# lse_loss -4.835434913635254
# recon_loss 0.10602375119924545
# 21094
# lse_loss -4.835370063781738
# recon_loss 0.0992000550031662
# 21095
# lse_loss -4.835262298583984
# recon_loss 0.09415572136640549
# 21096
# lse_loss -4.8354692459106445
# recon_loss 0.10354000329971313
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 4>()
#       1 from IPython import display
#       3 while True:
# ----> 4     for batch in train_loader:
#       5         print(step)
#       7         data = preprocess(batch)
#
# File ~/anaconda3/envs/ste/lib/python3.9/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/ste/lib/python3.9/site-packages/torch/utils/data/dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/ste/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/ste/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/ste/lib/python3.9/site-packages/torchvision/datasets/mnist.py:142, in MNIST.__getitem__(self, index)
#     138 img, target = self.data[index], int(self.targets[index])
#     140 # doing this so that it is consistent with all other datasets
#     141 # to return a PIL Image
# --> 142 img = Image.fromarray(img.numpy(), mode="L")
#     144 if self.transform is not None:
#     145     img = self.transform(img)
#
# File ~/anaconda3/envs/ste/lib/python3.9/site-packages/PIL/Image.py:2943, in fromarray(obj, mode)
#    2904 def fromarray(obj, mode=None):
#    2905     """
#    2906     Creates an image memory from an object exporting the array interface
#    2907     (using the buffer protocol).
#    (...)
#    2941     .. versionadded:: 1.1.6
#    2942     """
# -> 2943     arr = obj.__array_interface__
#    2944     shape = arr["shape"]
#    2945     ndim = len(shape)
#
# KeyboardInterrupt:
