# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Sat Jan 13 22:22:45 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   25C    P8    17W / 230W |  17558MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 35%   60C    P2   132W / 230W |   4564MiB / 24564MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   56C    P2   125W / 230W |   8286MiB / 24564MiB |     23%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 32%   55C    P2   110W / 230W |   4532MiB / 24564MiB |     37%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   48C    P2   105W / 230W |   4166MiB / 24564MiB |     29%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   46C    P2    97W / 230W |   4166MiB / 24564MiB |     28%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   46C    P2    99W / 230W |   4166MiB / 24564MiB |     29%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   42C    P2    65W / 230W |    928MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2106188      C   ...onda3/envs/ste/bin/python    17550MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   2307797      C   ...onda3/envs/ste/bin/python      394MiB |
# |    1   N/A  N/A   2329884      C   ...onda3/envs/ste/bin/python     4162MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   2328571      C   ...onda3/envs/ste/bin/python     4120MiB |
# |    2   N/A  N/A   2329962      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   2329982      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    3   N/A  N/A   2330556      C   ...onda3/envs/ste/bin/python      366MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2330059      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   2330137      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A   2330213      C   ...onda3/envs/ste/bin/python     4158MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A   2330468      C   ...onda3/envs/ste/bin/python      920MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.uniform_lse_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.004646301269531
# encoder.convs 5.989013671875
# encoder.linear 0.01563262939453125
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.11-9/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 0

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=1000, sigma=0.496)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=1000, sigma=1e-1)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = torch.randn(10, hp.z_dim).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 142001
# lse_loss -3.5575504302978516
# recon_loss 0.09282144159078598
# 142002
# lse_loss -3.602727174758911
# recon_loss 0.0927523672580719
# 142003
# lse_loss -3.564823865890503
# recon_loss 0.09130428731441498
# 142004
# lse_loss -3.590458869934082
# recon_loss 0.08921419084072113
# 142005
# lse_loss -3.5639967918395996
# recon_loss 0.09109243750572205
# 142006
# lse_loss -3.5450897216796875
# recon_loss 0.09193329513072968
# 142007
# lse_loss -3.6084518432617188
# recon_loss 0.0827459841966629
# 142008
# lse_loss -3.56193470954895
# recon_loss 0.08706840127706528
# 142009
# lse_loss -3.577507972717285
# recon_loss 0.09395532310009003
# 142010
# lse_loss -3.575218915939331
# recon_loss 0.1048772782087326
# 142011
# lse_loss -3.597353458404541
# recon_loss 0.09580044448375702
# 142012
# lse_loss -3.580760955810547
# recon_loss 0.09692643582820892
# 142013
# lse_loss -3.597289800643921
# recon_loss 0.0908430814743042
# 142014
# lse_loss -3.5839409828186035
# recon_loss 0.0927891954779625
# 142015
# lse_loss -3.558522939682007
# recon_loss 0.09098395705223083
# 142016
# lse_loss -3.5789783000946045
# recon_loss 0.09960951656103134
# 142017
# lse_loss -3.5241596698760986
# recon_loss 0.10099687427282333
# 142018
# lse_loss -3.5778260231018066
# recon_loss 0.09518709033727646
# 142019
# lse_loss -3.5756828784942627
# recon_loss 0.09269531816244125
# 142020
# lse_loss -3.5819644927978516
# recon_loss 0.09192114323377609
# 142021
# lse_loss -3.5635883808135986
# recon_loss 0.0928943008184433
# 142022
# lse_loss -3.5850670337677
# recon_loss 0.09999305009841919
# 142023
# lse_loss -3.530801296234131
# recon_loss 0.09616957604885101
# 142024
# lse_loss -3.585883855819702
# recon_loss 0.09156613051891327
# 142025
# lse_loss -3.5937442779541016
# recon_loss 0.08671002089977264
# 142026
# lse_loss -3.5614287853240967
# recon_loss 0.09777067601680756
# 142027
# lse_loss -3.572072744369507
# recon_loss 0.09078159928321838
# 142028
# lse_loss -3.575662851333618
# recon_loss 0.09269797056913376
# 142029
# lse_loss -3.5533063411712646
# recon_loss 0.08750172704458237
# 142030
# lse_loss -3.5413401126861572
# recon_loss 0.09026394784450531
# 142031
# lse_loss -3.6025168895721436
# recon_loss 0.08669226616621017
# 142032
# lse_loss -3.56758451461792
# recon_loss 0.09428896754980087
# 142033
# lse_loss -3.553504705429077
# recon_loss 0.08815248310565948
# 142034
# lse_loss -3.555842638015747
# recon_loss 0.09158235043287277
# 142035
# lse_loss -3.5287768840789795
# recon_loss 0.09441845864057541
# 142036
# lse_loss -3.595869302749634
# recon_loss 0.09285998344421387
# 142037
# lse_loss -3.5346198081970215
# recon_loss 0.09118738025426865
# 142038
# lse_loss -3.5698771476745605
# recon_loss 0.08829417079687119
# 142039
# lse_loss -3.58056902885437
# recon_loss 0.09267599880695343
# 142040
# lse_loss -3.5821022987365723
# recon_loss 0.09504921734333038
# 142041
# lse_loss -3.576528310775757
# recon_loss 0.08514788001775742
# 142042
# lse_loss -3.544452667236328
# recon_loss 0.09282293170690536
# 142043
# lse_loss -3.5899620056152344
# recon_loss 0.08952824771404266
# 142044
# lse_loss -3.559168577194214
# recon_loss 0.0927882045507431
# 142045
# lse_loss -3.557461977005005
# recon_loss 0.09595593065023422
# 142046
# lse_loss -3.569321393966675
# recon_loss 0.09497858583927155
# 142047
# lse_loss -3.5442419052124023
# recon_loss 0.09386074542999268
# 142048
# lse_loss -3.550217628479004
# recon_loss 0.09525300562381744
# 142049
# lse_loss -3.5717930793762207
# recon_loss 0.09146922826766968
# 142050
# lse_loss -3.5560455322265625
# recon_loss 0.0927385613322258
# 142051
# lse_loss -3.57234263420105
# recon_loss 0.09372465312480927
# 142052
# lse_loss -3.5727388858795166
# recon_loss 0.09098613262176514
# 142053
# lse_loss -3.5881552696228027
# recon_loss 0.09463926404714584
# 142054
# lse_loss -3.5732951164245605
# recon_loss 0.08979590982198715
# 142055
# lse_loss -3.561211585998535
# recon_loss 0.09038513898849487
# 142056
# lse_loss -3.566723108291626
# recon_loss 0.08513210713863373
# 142057
# lse_loss -3.5594799518585205
# recon_loss 0.09049942344427109
# 142058
# lse_loss -3.5552799701690674
# recon_loss 0.09394790232181549
# 142059
# lse_loss -3.578080654144287
# recon_loss 0.09617143124341965
# 142060
# lse_loss -3.5715606212615967
# recon_loss 0.08584971725940704
# 142061
# lse_loss -3.556103229522705
# recon_loss 0.093196801841259
# 142062
# lse_loss -3.578378200531006
# recon_loss 0.09269371628761292
# 142063
# lse_loss -3.5583837032318115
# recon_loss 0.09821732342243195
# 142064
# lse_loss -3.522437572479248
# recon_loss 0.09241965413093567
# 142065
# lse_loss -3.5483341217041016
# recon_loss 0.10464414209127426
# 142066
# lse_loss -3.553006887435913
# recon_loss 0.08757048845291138
# 142067
# lse_loss -3.5791962146759033
# recon_loss 0.09391721338033676
# 142068
# lse_loss -3.570237874984741
# recon_loss 0.0942884013056755
# 142069
# lse_loss -3.5812418460845947
# recon_loss 0.0989636778831482
# 142070
# lse_loss -3.592128038406372
# recon_loss 0.09461133927106857
# 142071
# lse_loss -3.5422866344451904
# recon_loss 0.09399665892124176
# 142072
# lse_loss -3.5898640155792236
# recon_loss 0.0898301750421524
# 142073
# lse_loss -3.5753135681152344
# recon_loss 0.09714123606681824
# 142074
# lse_loss -3.584920883178711
# recon_loss 0.09252556413412094
# 142075
# lse_loss -3.51712965965271
# recon_loss 0.09174197912216187
# 142076
# lse_loss -3.567044496536255
# recon_loss 0.08649760484695435
