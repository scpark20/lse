# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Thu Jan 11 23:00:54 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   26C    P8    13W / 230W |      6MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   51C    P0    80W / 230W |      6MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   26C    P8    15W / 230W |      6MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   41C    P2    65W / 230W |    646MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   29C    P8    16W / 230W |      6MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   28C    P8    17W / 230W |      6MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   27C    P8    18W / 230W |      6MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   28C    P8    16W / 230W |      6MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   1931992      C   ...onda3/envs/ste/bin/python      638MiB |
# |    4   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      4537      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Model Parts

# %%
from model.main.enc_latent_dec import Model
from model.encoder.conv2d_encoder import Encoder
from model.latent_layer.uniform_min_sqrt_latent_layer import LatentLayer
from model.decoder.conv2d_decoder import Decoder

from tensorboardX import SummaryWriter
from util.util import *

# %% [markdown]
# ### Model Init.

# %%
from easydict import EasyDict
hp = EasyDict()
hp.size = 64
hp.in_dim = 1
hp.out_dim = 1
hp.z_dim = 2
hp.h_dims = [32, 64, 128, 256, 512]

# %%
step = 0
device = 'cuda:0'

model = Model(Encoder(**hp), LatentLayer(**hp), Decoder(**hp))
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)

for name, module in model.named_modules():
    if len(name.split('.')) <= 2 and len(name) > 0:
        print(name, get_size(module))
        
print('done')
# Out:
# encoder 6.004646301269531
# encoder.convs 5.989013671875
# encoder.linear 0.01563262939453125
# latent_layer 0.0
# decoder 6.044322967529297
# decoder.linear 0.0234375
# decoder.convs 5.9820556640625
# decoder.out_conv 0.038829803466796875
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lse/train01.11-14_1/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, net_g, _, opt_g, _ = load(save_dir, 0, model, optimizer)
# Out:
# total 78932
# -rw-rw-r-- 1 scpark scpark   362756  1월 11 23:00 events.out.tfevents.1704981515.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37973949  1월 11 22:58 save_0
# -rw-rw-r-- 1 scpark scpark   191876  1월 11 22:58 events.out.tfevents.1704981441.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   827396  1월 11 22:57 events.out.tfevents.1704981149.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1136516  1월 11 22:52 events.out.tfevents.1704980751.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 37979741  1월 11 22:51 save_10000
# -rw-rw-r-- 1 scpark scpark   297188  1월 11 22:45 events.out.tfevents.1704980641.GPUSVR01
# -rw-rw-r-- 1 scpark scpark  1180868  1월 11 22:43 events.out.tfevents.1704980225.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   858212  1월 11 22:37 events.out.tfevents.1704979910.GPUSVR01

# %% [markdown]
# ### Dataset

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transformations applied on each image
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize the image to 32x32
    transforms.ToTensor(),         # Convert the image to a PyTorch tensor
    transforms.Normalize((0.5), (0.5)) 
])

# Load the MNIST dataset
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create data loaders
train_loader = DataLoader(mnist_trainset, batch_size=64, shuffle=True)
test_loader = DataLoader(mnist_testset, batch_size=2048, shuffle=True)
print('done')
# Out:
# done

# %% [markdown]
# ### Preprocess

# %%
def preprocess(batch):
    x, t = batch
    data = {}
    data['x'] = x.to(device)
    data['t'] = t.to(device)
    return data

# %% [markdown]
# ### Train

# %%
def plot(x):
    _x = x.data.cpu().numpy()
    plt.figure(figsize=[18, 4])
    for i in range(10):
        plt.subplot(1, 10, i+1)
        plt.imshow(_x[i, 0])
        plt.xticks([])
        plt.yticks([])
    plt.show()
    
# borrowed from https://gist.github.com/jakevdp/91077b0cae40f8f8244a
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
from IPython import display

while True:
    for batch in train_loader:
        print(step)
        
        data = preprocess(batch)
        
        # Forward
        model.train()
        model.zero_grad()
        data = model(data, M=10000, sigma=1e-1)
        
        # Backward
        loss = 0
        for key in data.keys():
            if 'loss' in key:
                loss = loss + data[key]
                writer.add_scalar(key, data[key].item(), step)
                print(key, data[key].item())
        loss.backward()
        optimizer.step()
        
        if step % 1000 == 0:
            import matplotlib.pyplot as plt
            display.clear_output()
            
            batch = next(iter(test_loader))
            data = preprocess(batch)
            
            model.eval()
            with torch.no_grad():
                data = model(data, M=10000, sigma=1e-1)
            
            plot(data['x'])
            plot(data['y'])
            
            with torch.no_grad():
                z = (torch.rand(10, hp.z_dim)*2-1).to(device)
                y = model.sample(z)
                plot(y)
                
            import matplotlib.pyplot as plt
            _z = data['z'].data.cpu().numpy()
            plt.scatter(_z[:, 0], _z[:, 1], c=data['t'].data.cpu().numpy(), cmap=discrete_cmap(10, 'jet'))
            plt.grid()
            plt.colorbar()
            plt.show()
        
        if step % 10000 == 0:
            save(save_dir, step, model, optimizer)
                
        step += 1
# Out:
# 32001
# lse_loss 0.11812691390514374
# recon_loss 0.11756777763366699
# 32002
# lse_loss 0.12669800221920013
# recon_loss 0.11824476718902588
# 32003
# lse_loss 0.12798871099948883
# recon_loss 0.12830476462841034
# 32004
# lse_loss 0.11918896436691284
# recon_loss 0.10884962975978851
# 32005
# lse_loss 0.1350259780883789
# recon_loss 0.11080937832593918
# 32006
# lse_loss 0.12772880494594574
# recon_loss 0.09681114554405212
# 32007
# lse_loss 0.1333688199520111
# recon_loss 0.11660996079444885
# 32008
# lse_loss 0.13522595167160034
# recon_loss 0.12049122154712677
# 32009
# lse_loss 0.12458346784114838
# recon_loss 0.11433073878288269
# 32010
# lse_loss 0.12158350646495819
# recon_loss 0.11944016814231873
# 32048
# lse_loss 0.1250382363796234
# recon_loss 0.1074235662817955
# 32049
# lse_loss 0.12016568332910538
# recon_loss 0.11331403255462646
# 32050
# lse_loss 0.12802280485630035
# recon_loss 0.09968044608831406
# 32051
# lse_loss 0.13203760981559753
# recon_loss 0.10245587676763535
# 32052
# lse_loss 0.12413600832223892
# recon_loss 0.10679306089878082
# 32053
# lse_loss 0.12138769030570984
# recon_loss 0.12068327516317368
# 32054
# lse_loss 0.12279562652111053
# recon_loss 0.11395784467458725
# 32055
# lse_loss 0.12224183976650238
# recon_loss 0.1089186891913414
# 32056
# lse_loss 0.12326459586620331
# recon_loss 0.10621076822280884
# 32057
# lse_loss 0.12996657192707062
# recon_loss 0.09839236736297607
# 32058
# lse_loss 0.13007742166519165
# recon_loss 0.10482887923717499
# 32059
# lse_loss 0.13142375648021698
# recon_loss 0.10613521933555603
# 32060
# lse_loss 0.1254088580608368
# recon_loss 0.1201195940375328
# 32061
# lse_loss 0.12294229120016098
# recon_loss 0.11462758481502533
# 32062
# lse_loss 0.12984555959701538
# recon_loss 0.10763414949178696
# 32063
# lse_loss 0.12439309805631638
# recon_loss 0.11154582351446152
# 32064
# lse_loss 0.12012222409248352
# recon_loss 0.11705581843852997
# 32065
# lse_loss 0.12588341534137726
# recon_loss 0.1101180911064148
# 32066
# lse_loss 0.1218186765909195
# recon_loss 0.11261575669050217
# 32067
# lse_loss 0.14092370867729187
# recon_loss 0.09707053750753403
# 32068
# lse_loss 0.1239238977432251
# recon_loss 0.10480447858572006
# 32069
# lse_loss 0.13024865090847015
# recon_loss 0.1066039651632309
# 32070
# lse_loss 0.13081131875514984
# recon_loss 0.11105237901210785
# 32071
# lse_loss 0.1266748011112213
# recon_loss 0.10968826711177826
# 32072
# lse_loss 0.12453533709049225
# recon_loss 0.09640252590179443
# 32073
# lse_loss 0.12636767327785492
# recon_loss 0.11679365485906601
# 32074
# lse_loss 0.124897800385952
# recon_loss 0.1170526072382927
# 32075
# lse_loss 0.12792131304740906
# recon_loss 0.09728765487670898
# 32076
# lse_loss 0.13227608799934387
# recon_loss 0.11596723645925522
# 32077
# lse_loss 0.12657882273197174
# recon_loss 0.10918372124433517
# 32078
# lse_loss 0.12857043743133545
# recon_loss 0.10857753455638885
# 32079
# lse_loss 0.13293541967868805
# recon_loss 0.11068110167980194
# 32080
# lse_loss 0.12359828501939774
# recon_loss 0.10695310682058334
# 32081
# lse_loss 0.1230219230055809
# recon_loss 0.09684078395366669
# 32082
# lse_loss 0.12448495626449585
# recon_loss 0.12575052678585052
# 32083
# lse_loss 0.13811440765857697
# recon_loss 0.1151624470949173
# 32084
# lse_loss 0.13360849022865295
# recon_loss 0.10925893485546112
# 32085
# lse_loss 0.12487353384494781
# recon_loss 0.10199722647666931
# 32086
# lse_loss 0.1302802711725235
# recon_loss 0.12110686302185059
# 32087
# lse_loss 0.13446451723575592
# recon_loss 0.10952728241682053
# 32088
# lse_loss 0.12599050998687744
# recon_loss 0.10458220541477203
# 32089
# lse_loss 0.1273140162229538
# recon_loss 0.11429192125797272
# 32090
# lse_loss 0.12885771691799164
# recon_loss 0.10308806598186493
# 32091
# lse_loss 0.1369936168193817
# recon_loss 0.1254705786705017
# 32092
# lse_loss 0.11916040629148483
# recon_loss 0.10289790481328964
# 32093
# lse_loss 0.12519508600234985
# recon_loss 0.09686362743377686
# 32094
# lse_loss 0.131400465965271
# recon_loss 0.11138825118541718
# 32095
# lse_loss 0.12622752785682678
# recon_loss 0.11045344918966293
# 32096
# lse_loss 0.13563227653503418
# recon_loss 0.11327057331800461
# 32097
# lse_loss 0.12420712411403656
# recon_loss 0.10835085809230804
# 32098
# lse_loss 0.1264091581106186
# recon_loss 0.1108931228518486
# 32099
# lse_loss 0.1352357566356659
# recon_loss 0.11264966428279877
# 32100
# lse_loss 0.12733903527259827
# recon_loss 0.10896444320678711
# 32101
# lse_loss 0.12179074436426163
# recon_loss 0.10421042889356613
# 32102
# lse_loss 0.13592202961444855
# recon_loss 0.114150270819664
# 32103
# lse_loss 0.12603828310966492
# recon_loss 0.12194818258285522
# 32104
# lse_loss 0.13063301146030426
# recon_loss 0.11563929170370102
# 32105
# lse_loss 0.11863788962364197
# recon_loss 0.10853831470012665
# 32106
# lse_loss 0.12291336059570312
# recon_loss 0.10776150226593018
# 32107
# lse_loss 0.1309538036584854
# recon_loss 0.11226581782102585
# 32108
# lse_loss 0.11942972987890244
# recon_loss 0.10967390984296799
# 32109
# lse_loss 0.13431067764759064
# recon_loss 0.11388151347637177
# 32110
# lse_loss 0.12790246307849884
# recon_loss 0.111542247235775
# 32111
# lse_loss 0.12375478446483612
# recon_loss 0.09824427217245102
# 32112
# lse_loss 0.13324765861034393
# recon_loss 0.11312428116798401
# 32113
# lse_loss 0.12417393177747726
# recon_loss 0.09606502950191498
# 32114
# lse_loss 0.12421704828739166
# recon_loss 0.1090545505285263
# 32115
# lse_loss 0.12439963221549988
# recon_loss 0.11685699224472046
# 32116
# lse_loss 0.12900270521640778
# recon_loss 0.10754632949829102
# 32117
# lse_loss 0.12810124456882477
# recon_loss 0.09816407412290573
# 32118
# lse_loss 0.12487315386533737
# recon_loss 0.11072035878896713
# 32119
# lse_loss 0.13671302795410156
# recon_loss 0.114651620388031
# KeyboardInterrupt

# %%
torch.__version__
